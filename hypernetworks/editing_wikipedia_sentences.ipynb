# %% [markdown]
# First, run
# download_wikipedia.ipynb
# to get the file
# wikipedia_three_sentences.csv
#
# Then, we do our processing here
#
# random note: #could upgrade to use a 4090 or A6000

# %%
stopping_index=8
num_editing_heads = 768*2 #more seems to be better for this #per sid's suggestion: can add more heads in every layer. This is probably a really great suggestion
editor_channel_width = 768 * 2
max_grad_clip = 4.0
chop_layer = 8
lr = 4e-4
edit_dampening_factor=1e-4 #usually 1e-4
lam = .01 #100 was too big!!

# %% [markdown]
# notes from Sid: SAE vs principal components
# -you could try to work on the SAE's???
# -get discrete targets
# [I wouldn't be surprised at all if this helped a lot]
#
#
# -Next deliverables:

# %%
#batch['tokenized_first_sentence'][30].size(), batch['tokenized_next_50_tokens'][30].size()

# %%
# Trying out the editor hypernetwork on the dune dataset
import wandb

wandb.init(
    # set the wandb project where this run will be logged
    project="hypernetworks",
    config={"targetmodel": "gpt2", "editormodel": "gpt2"},
)
# Copy this below where needed!
# run.log_model(path="<path-to-model>", name="<name>")

# wandb.log({"acc": acc, "loss": loss})

# wandb.finish()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: michaelbsklar (michaelsklar). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/ubuntu/share/hypernetworks/wandb/run-20240503_091846-0ca284pl</code>
# Syncing run <strong><a href='https://wandb.ai/michaelsklar/hypernetworks/runs/0ca284pl' target="_blank">glad-rain-315</a></strong> to <a href='https://wandb.ai/michaelsklar/hypernetworks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/michaelsklar/hypernetworks' target="_blank">https://wandb.ai/michaelsklar/hypernetworks</a>
#  View run at <a href='https://wandb.ai/michaelsklar/hypernetworks/runs/0ca284pl' target="_blank">https://wandb.ai/michaelsklar/hypernetworks/runs/0ca284pl</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/michaelsklar/hypernetworks/runs/0ca284pl?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# CUDA_LAUNCH_BLOCKING=1
#os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
# Set torch default device
import torch
torch.set_default_device("cuda")

# %%
import transformers
from transformers import GPT2LMHeadModel, GPT2Tokenizer, GPT2Config, GPT2Model
from transformers.models.gpt2.modeling_gpt2 import GPT2Attention
import torch
from torch import compile
import torch.nn as nn
from torch import optim
from torch.utils.data import Dataset, DataLoader
import transformers
from tqdm import tqdm
import pandas as pd
import yaml
import contextlib
import os
import time

# %%
def add_cross_attention_to_layer(block, config):
    block.crossattention = GPT2Attention(config, is_cross_attention=True)
    block.ln_cross_attn = nn.LayerNorm(
        normalized_shape=768, eps=config.layer_norm_epsilon
    )
    original_query_weights = block.attn.c_attn.weight[:, :768]
    original_keys_values = block.attn.c_attn.weight[:, 768:]
    original_query_bias = block.attn.c_attn.bias[:768]
    original_keys_values_bias = block.attn.c_attn.bias[768:]
    with torch.no_grad():
        # Initialize the new layer with these parameters
        block.crossattention.q_attn.weight = nn.Parameter(original_query_weights)
        block.crossattention.q_attn.bias = nn.Parameter(original_query_bias)
        block.crossattention.c_attn.weight = nn.Parameter(original_keys_values)
        block.crossattention.c_attn.bias = nn.Parameter(original_keys_values_bias)
    return

# %% [markdown]
# Now, we stick on the "reverse attention" module at the end!
# This is a customized attention head that reads from the editor model, and writes to the target model's activations

# %%
class Editor_Attention(nn.Module):
    def __init__(self, config):
        super().__init__()

        #Controls whether the head will do a global softmax in all positions & layers
        #If True, the attn is global and will sum to 1
        #If False, the attn is a logistic fxn independently for every layer & token
        #I suspect we will also want to penalize the intervention norm
        self.num_editing_heads = config.num_editing_heads #should default to 1, but we're going to test adding more
        self.edit_channel_width = config.edit_channel_width
        if self.edit_channel_width % self.num_editing_heads != 0:
            print("Error: config hidden size is not divisible by num_editing_heads")
        self.head_dim = self.edit_channel_width // self.num_editing_heads
        self.embed_dim = config.hidden_size

        max_positions = config.max_position_embeddings #does this do anything? can try killing this later
        self.register_buffer(
            "bias",
            torch.tril(
                torch.ones((max_positions, max_positions), dtype=torch.bool)
            ).view(1, 1, max_positions, max_positions),
            persistent=False,
        )
        self.register_buffer("masked_bias", torch.tensor(-1e4), persistent=False)

        # We compute Q and K as a single nn.linear; but will later break apart into subcomponents

        ## Before modification to a variable channel-width
        # self.q_attn = nn.Linear(self.embed_dim, self.embed_dim)
        # self.k_attn = nn.Linear(self.embed_dim, self.embed_dim)
        # self.v_attn = nn.Linear(self.embed_dim, self.embed_dim)
        # self.out_proj = nn.Linear(self.embed_dim, self.embed_dim) 
        
        
        self.q_attn = nn.Linear(self.embed_dim, self.edit_channel_width)
        self.k_attn = nn.Linear(self.embed_dim, self.edit_channel_width)
        self.v_attn = nn.Linear(self.embed_dim, self.edit_channel_width)
        self.out_proj = nn.Linear(self.edit_channel_width, self.embed_dim) 

    def _split_heads(self, x):
        """Split the last dimension into (num_heads, head_dim)."""
        new_shape = x.size()[:-1] + (self.num_editing_heads, self.head_dim)
        return x.view(*new_shape)
    
    def _new_reverse_attn(self, query, key, value, attention_mask=None, head_mask=None):
        # Assume that we are doing softmax attention

        # Project and split the query, key, value tensors
        split_query = self._split_heads(query)  
        split_key = self._split_heads(key)
        split_value = self._split_heads(value)
        
        #Double-application (is this actually good/better for some reason?)
        #self._split_heads(self.q_attn(query))
        #self._split_heads(self.k_attn(key))
        #self._split_heads(self.v_attn(value))

        if split_query.dim() != 4:
            print("Error: Expected query to be 4D tensor, but got something else!")
        if split_key.dim() != 3:
            print("Error: Expected key to be 3D tensor, but got something else!")
        if split_value.dim() != 3:
            print("Error: Expected value to be 3D tensor, but got something else!")

        # Query should be shaped as (batch_index, sequence_index, head_index, head_dim)
        # Key and value should be shaped as (batch_index, head_index, head_dim)
    
        KQ_weights = torch.matmul(split_query.permute(0,2,1,3),split_key.unsqueeze(-1)).squeeze(-1)

        # Then we take the softmax within the positional divisions
        softmaxed_weights = nn.functional.softmax(KQ_weights, dim=-1)
        
        # Adjusting value selection for head dimension
        attn_output = torch.matmul(softmaxed_weights.unsqueeze(-1), split_value.unsqueeze(-2))

        #combine heads: change 50, 8, 104, 96 to 50, 104, 768
        #first, permute
        attn_output = attn_output.permute(0,2,1,3)
        #combin heads x head_dims
        attn_output = attn_output.reshape(-1,attn_output.size(1),attn_output.size(2)*attn_output.size(3))
        # now project back
        projected_output = self.out_proj(attn_output)
    
        return projected_output, softmaxed_weights

    def _reverse_attn(self, query, key, value, attention_mask=None, head_mask=None):

        if key.dim() == 4:
            K_reduced = key[
                :, :, -1, :
            ]  # R# Check: that the second dimension of K is only a single element when we have batching
            KQ_weights = torch.bmm(K_reduced, query.transpose(1, 2))
            logistic_weights = torch.atan(KQ_weights)
            attn_output = torch.bmm(
                logistic_weights.transpose(1, 2), value[:, :, -1, :] #we take the editor output only over the final token position
            )

        if key.dim() == 3:
            QK_weights = torch.matmul(query, key.transpose(-1, -2))
            logistic_weights = torch.atan(QK_weights)
            attn_output = torch.matmul(logistic_weights, value)

        return attn_output, logistic_weights


    def forward(
        self,
        editor_hidden_states,
        target_hidden_states,
        attention_mask=None,
        output_attentions=False,
    ):

        # Here, the query is the target hidden encoder, the key is the editor, and the value is the editor
        query = self.q_attn(target_hidden_states)
        if editor_hidden_states.dim() == 3:
            key = self.k_attn(
                # I don't quite understand why sometimes editor_hidden_states is 4 dimensional, sometimes 3
                #seems like it's sometimes 20, 1, 4, 768 and sometimes 20, 4, 768. what gives?
                editor_hidden_states[:, -1, :]
            )  # Pull only the final token position
            value = self.v_attn(
                # [:, 0, :1, :]
                editor_hidden_states[:, -1, :]
            )  # Pull only the final token position

        if editor_hidden_states.dim() == 4:
            key = self.k_attn(
                editor_hidden_states[:, 0, -1, :]
            )  # Pull only the final token position
            value = self.v_attn(
                # [:, 0, :1, :]
                editor_hidden_states[:, 0, -1, :]
            )  # Pull only the final token position

        attn_output, attn_weights = self._new_reverse_attn(query, key, value)

        if output_attentions:
            return attn_output, attn_weights
        else:
            return attn_output

# %%
import types
from typing import Optional, Tuple, Union


def new_forward(
    self,
    input_ids: Optional[torch.LongTensor] = None,
    past_key_values: Optional[Tuple[Tuple[torch.Tensor]]] = None,
    attention_mask: Optional[torch.FloatTensor] = None,
    token_type_ids: Optional[torch.LongTensor] = None,
    position_ids: Optional[torch.LongTensor] = None,
    head_mask: Optional[torch.FloatTensor] = None,
    inputs_embeds: Optional[torch.FloatTensor] = None,
    encoder_hidden_states: Optional[torch.Tensor] = None,
    encoder_attention_mask: Optional[torch.FloatTensor] = None,
    # labels: Optional[torch.LongTensor] = None,
    use_cache: Optional[bool] = None,
    output_attentions: Optional[bool] = None,
    output_hidden_states: Optional[bool] = None,
    return_dict: Optional[bool] = None,
) -> Union[Tuple]:
    r"""
    labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
        Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
        `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
        are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
    """

    transformer_outputs = self.transformer(
        input_ids,
        past_key_values=past_key_values,
        attention_mask=attention_mask,
        token_type_ids=token_type_ids,
        position_ids=position_ids,
        head_mask=head_mask,
        inputs_embeds=inputs_embeds,
        encoder_hidden_states=encoder_hidden_states,
        encoder_attention_mask=encoder_attention_mask,
        use_cache=use_cache,
        output_attentions=output_attentions,
        output_hidden_states=output_hidden_states,
        return_dict=return_dict,
    )
    hidden_states = transformer_outputs[0]

    # Set device for model parallelism
    if self.model_parallel:
        torch.cuda.set_device(self.transformer.first_device)
        hidden_states = hidden_states.to(self.lm_head.weight.device)

    # lm_logits = self.lm_head(hidden_states)
    reverse_attention_output = self.lm_head(
        hidden_states, encoder_hidden_states, output_attentions=output_attentions
    )

    return reverse_attention_output

# %%
def replace_linear_final_layer_with_bespoke_reverse_attention(model):
    model.lm_head = Editor_Attention(config=model.config)
    model.forward = new_forward.__get__(model, GPT2LMHeadModel)
    return

# %%
@contextlib.contextmanager
def add_fwd_hooks(module_hooks):
    """
    Context manager for temporarily adding forward hooks to a model.

    Parameters
    ----------
    module_hooks
        A list of pairs: (module, fnc) The function will be registered as a
            forward hook on the module
    """
    try:
        handles = []
        for mod, hk in module_hooks:
            handles.append(mod.register_forward_hook(hk))
        yield
    finally:
        for h in handles:
            h.remove()

# %%
def assign_layer_indices(model):
    """
    Assigns a custom attribute 'layer_index' to each transformer layer in the GPT-2 model.
    This function iterates over the transformer blocks and assigns an index to each.
    """
    model.transformer.wte.layer_index = 0
    for i, layer in enumerate(model.transformer.h):
        layer.layer_index = i + 1


# Usage:
# assign_layer_indices(target_model)

# %%
def concat_and_pad(A, B):
    batch_size, n_tokens_A = A.size()
    n_tokens_B = B.size(1)

    #Find the lengths in A and B
    lengths_A = torch.sum(A != 50256, dim=1)
    lengths_B = torch.sum(B != 50256, dim=1)

    #iniitalize empty tensor
    result = torch.full((batch_size, max(lengths_A + lengths_B),), 50256)

    #Concatenate A[i] and B[i] a
    for i in range(batch_size):
        result[i, : lengths_A[i]] = A[i, : lengths_A[i]]
        result[i, lengths_A[i] : lengths_A[i] + lengths_B[i]] = B[i, : lengths_B[i]]

    # # Concatenate A and B along dimension 1
    # concatenated = torch.cat((A, B), dim=1)
    
    # # Find the number of non-zero elements in each row of concatenated tensor
    # lengths = torch.sum(concatenated != 50256, dim=1)
    
    # # Create a mask to identify the non-zero elements in concatenated tensor
    # mask = torch.arange(n_tokens_A + n_tokens_B).expand(batch_size, n_tokens_A + n_tokens_B) < lengths.unsqueeze(1)
    
    # # Create a new tensor with the same shape as concatenated tensor
    # result = torch.full_like(concatenated, 50256)
    
    # # Move the non-zero elements to the left and zero elements to the right
    # result[mask] = concatenated[mask]

    return result

# %%
def check_nan_gradients(model):
    for name, param in model.named_parameters():
        if param.grad is not None and torch.isnan(param.grad).any():
            print(f"NaN values found in gradient of parameter: {name}")
            return True
    return False

# %%
#@torch.compile #Apparently this fails when used inside jupyter notebooks but is fine if i make dedicated scripts
class EditorHypernetwork(nn.Module):
    # Separating the editor config file, from its base model's configurations
    def __init__(self,         
        num_editing_heads=32,
        edit_channel_width=768, #controls dimensionality given to attention heads in the last layer of the editor
        use_layerwise_embeddings=True,
        chop_editor_at_layer = None,
        edit_dampening_factor=.001,#tuning parameter to help the edits not be initialized too large
        kill_token_zero = False, #multiplies edits to token pos zero by zero
        ):

        super().__init__()

        # Construct Editor Model
        # Load the configuration from the YAML file
        # with open(editor_yaml_file_path, 'r') as file:
        #     self.config = yaml.safe_load(file)
        self.editor_model = GPT2LMHeadModel.from_pretrained(
            "gpt2"
        ).cuda().eval()  # have recently added .cuda() so it uses the gpu

        # Add cross-attention to each layer
        self.editor_model.config.add_cross_attention = True
        self.editor_model.config.num_editing_heads = num_editing_heads
        self.editor_model.config.chop_layer = chop_editor_at_layer
        self.editor_model.config.kill_token_zero = kill_token_zero
        self.editor_model.config.edit_channel_width = edit_channel_width
        
        if chop_editor_at_layer is None:
            chop_editor_at_layer = 12

        for i in range(chop_editor_at_layer):
            add_cross_attention_to_layer(
                self.editor_model.transformer.h[i], self.editor_model.config
            )
        
        #Delete extra layers beyond the chop_layer
        self.editor_model.transformer.h = self.editor_model.transformer.h[:chop_editor_at_layer]

        # Replace the final linear layer with special reverse attention output
        self.editor_model.lm_head = Editor_Attention(config=self.editor_model.config)
        self.editor_model.forward = new_forward.__get__(
            self.editor_model, GPT2LMHeadModel
        )
        self.editor_model.cuda()

        # Construct Target Model
        self.target_model = transformers.AutoModelForCausalLM.from_pretrained(
            "gpt2"
        ).cuda().eval()
        for param in self.target_model.parameters():
            param.requires_grad = False
        assign_layer_indices(self.target_model)

        self.target_model.cuda()

        # Add module for layerwise embeddings
        if use_layerwise_embeddings:
            self.use_layerwise_embeddings = True
            self.layerwise_embeddings = torch.randn(13, 768, requires_grad=True).cuda()
        else:
            self.use_layerwise_embeddings = False
            self.layerwise_embeddings = 0

        self.edit_dampening_factor = edit_dampening_factor

        self.residual_cache = None
        self.opt = None
        self.lossfn = None
        self.lam = None
        self.penalty_loss= None
        self.training_loss = None

    # Gets the hidden states from the target model, if necessary
    def run_target_model_for_encoded_hidden_states(self, target_ids):
        with torch.no_grad():
            outputs = self.target_model(target_ids, output_hidden_states=True)
            hidden_states = outputs.hidden_states
            return hidden_states

    def forward(
        self,
        editor_input_ids,
        target_input_ids,
        target_hidden_states=None,
        output_target_hidden_states=False,
        output_edited_hidden_states=False,
        output_edit_vectors=False,
        output_editor_attention=False,
        stopping_index=None,
        batch_edit_vectors=None,
    ):

        # Run target model for encoded hidden states
        if target_hidden_states is None:
            target_hidden_states = torch.stack(
                self.run_target_model_for_encoded_hidden_states(
                    target_input_ids.to("cuda")
                ), #seems to break while we are passing thru batch_size=1; the last (12th =) has different dimensions
                dim=2,
            )
        # dimensions of target_hidden_states:
        # batch_size, token_sequence_length, num_layers = 13, resid_width = 768

        # If we are stopping editing at stopping_index, then we eliminate target_hidden_states beyond that index
        if stopping_index is not None:
            target_hidden_states = target_hidden_states[
                :, :stopping_index, :, :
            ].clone()

        # Normalize along the last dimension
        normalization_factors = target_hidden_states.norm(dim=-1, keepdim=True)
        target_hidden_states = target_hidden_states / normalization_factors

        # Error catching:
        if batch_edit_vectors is not None:
            if output_edit_vectors or output_editor_attention:
                return "Error: Inputting your own batch_edit_vectors means the model does not construct the outputs you are requesting"

        # Run editor model, get edit vectors
        if batch_edit_vectors is None:
            if self.use_layerwise_embeddings:
                # Now, add in the layerwise embeddings
                embedded_hidden_states = target_hidden_states + self.layerwise_embeddings[None, None, :, :]

                collapsed_target_hidden_states = embedded_hidden_states.reshape(
                    target_hidden_states.shape[0],
                    target_hidden_states.shape[1] * target_hidden_states.shape[2],
                    target_hidden_states.shape[3],
                )
            else:
                collapsed_target_hidden_states = target_hidden_states.reshape(
                    target_hidden_states.shape[0],
                    target_hidden_states.shape[1] * target_hidden_states.shape[2],
                    target_hidden_states.shape[3],
                )
            
            editor_output = self.editor_model(
                editor_input_ids.to("cuda"),
                encoder_hidden_states=collapsed_target_hidden_states,
                output_attentions=output_editor_attention,
            )
            # Multiply the outputs by normalization factors
            if output_editor_attention:
                temp_edit_vectors = editor_output[0]
                # Might want to reshape this too but whatever
                batch_editor_attention = editor_output[1]
            else:
                temp_edit_vectors = editor_output
            
            #Renormalize to the scale of the target hidden states
            #and reshape to proper dimensions
            batch_edit_vectors = self.edit_dampening_factor * normalization_factors * temp_edit_vectors.reshape(
                    temp_edit_vectors.shape[0], stopping_index, 13, 768
                )
            
        # If we are stopping editing at stopping_index,
        # this pads batch_edit_vectors with 0's to the right of the edited positions
        if stopping_index is not None:
            batch_edit_vectors = torch.cat(
                (
                    batch_edit_vectors,
                    torch.zeros(
                        batch_edit_vectors.shape[0],
                        target_input_ids.shape[1] - stopping_index,
                        13,
                        768,
                    ),
                ),
                dim=1,
            )

        # Run target model with edit vectors. This adds the edit vectors to the given hidden state at the specified batch index, position, and layer
        def edit_add(module, input, output):
            layer_index = module.layer_index
            output[0][:] = output[0] + batch_edit_vectors[:, :, layer_index, :]
            if self.editor_model.config.kill_token_zero == True:
                output[0][:, 0, :] = 0

        def embedding_edit_add(module, input, output):
            output[:] = output + batch_edit_vectors[:, :, 0, :]
            if self.editor_model.config.kill_token_zero == True:
                output[:, 0, :] = 0

        # Now editing the target model
        hooks1 = [(self.target_model.transformer.wte, embedding_edit_add)]
        hooks2 = [(self.target_model.transformer.h[L], edit_add) for L in range(12)]
        hooks = hooks1 + hooks2
        with add_fwd_hooks(hooks):
            # THIS IS THE LINE WHERE THE MODEL IS CALLED (AND THE EDITOR IS CALLED AT
            # THE END OF `layer` AS A SIDE EFFECT)
            target_result = self.target_model(
                target_input_ids.to("cuda"),
                output_hidden_states=output_edited_hidden_states,
            )

        logits = target_result.logits

        output = {}
        output["logits"] = logits
        if output_target_hidden_states:
            output["target_hidden_states"] = (
                target_hidden_states * normalization_factors
            )
        if output_edited_hidden_states:
            output["edited_hidden_states"] = target_result.hidden_states
        if output_edit_vectors:
            output["edit_vectors"] = batch_edit_vectors
        if output_editor_attention:
            output["editor_attention"] = batch_editor_attention
        return output

    # Generate text using the target model, with a new edit application at every step.
    # This is a very slow way to generate text.
    # If you only want to edit first k tokens, use the forward pass instead with stopping_index = k
    def inspect_batch_prediction_ouptuts(self, batch):
        with torch.no_grad():
            batch_size = len(batch["tokenized_first_sentence"])
            self.editor_inputs = batch["tokenized_first_sentence"][i].unsqueeze(0)
            self.target_inputs = batch["tokenized_next_50_tokens"][i].unsqueeze(0)
            self.prediction = self.forward(
                self.editor_inputs,
                self.target_inputs,
                stopping_index=stopping_index,
                output_target_hidden_states=False,
                output_edited_hidden_states=False,
                output_edit_vectors=False,
                output_editor_attention=False,
            )
            #compute most likely tokens from the logits
            predicted_ids = [torch.argmax(pred, dim=-1) for pred in self.prediction["logits"]]
            #convert the token ids to strings
            predicted_strings = [tokenizer.decode(pred) for pred in predicted_ids]
            return predicted_strings

    def evaluate_KL_test_loss_nogradient(self,dataloader, f_data_to_soft_labels, stopping_index=8):
        with torch.no_grad():
            sum_weighted_losses = 0.0
            total_samples = 0
            for batch in dataloader:
                current_batch_size = len(batch["tokenized_first_sentence"])
                self.editor_inputs = batch["tokenized_first_sentence"].squeeze(1)
                self.target_inputs = batch["tokenized_next_50_tokens"].squeeze(1)
                self.prediction = self.forward( 
                    self.editor_inputs,
                    self.target_inputs,
                    stopping_index=stopping_index
                )
                log_prob_predictions = torch.nn.functional.log_softmax(
                    self.prediction["logits"][
                        :, :, :
                    ].reshape(-1, 50257),
                    dim=1,
                )
                # Now we must compute the soft labels! This is outsourced to the user-provided function + teacher_model
                self.soft_labels = f_data_to_soft_labels(
                    batch["tokenized_first_sentence"],
                    batch["tokenized_next_50_tokens"],
                    num_predictions_max=50
                )
                mask = (batch["tokenized_next_50_tokens"] != 50256).reshape(-1)
                self.loss = torch.nn.functional.kl_div(log_prob_predictions[mask,:], self.soft_labels[mask,:], reduction = 'batchmean')
                # Weight the loss by current batch size and update the sum of weighted losses
                sum_weighted_losses += self.loss.item() * current_batch_size
                total_samples += current_batch_size
            weighted_average_loss = sum_weighted_losses / total_samples
        return weighted_average_loss

    def evaluate_crossentropy_test_loss_nogradient(self,dataloader, stopping_index=8):
        #this function is not being maintained
        with torch.no_grad():
            sum_weighted_losses = 0.0
            total_samples = 0
            for batch in dataloader:
                #current_batch_size = len(batch["tokenized_first_sentence"])
                self.editor_inputs = batch["tokenized_first_sentence"].squeeze(1)
                self.target_inputs = batch["tokenized_next_50_tokens"].squeeze(1)
                self.prediction = self.forward( #check the batch size
                    self.editor_inputs,
                    self.target_inputs,
                    stopping_index=stopping_index
                )
                log_prob_predictions = torch.nn.functional.log_softmax(
                    self.prediction["logits"][
                        :, stopping_index:, :
                    ].reshape(-1, 50257),
                    dim=1,
                )

                # Create a mask to exclude padded tokens
                target_labels = self.target_inputs[:, stopping_index].shape(-1) #this line got screwwed up
                mask = (target_labels != 50256)  # Assuming padded tokens are represented by 0

                # Compute the cross-entropy loss with masking
                criterion = torch.nn.CrossEntropyLoss(reduction='none')
                loss = criterion(log_prob_predictions, target_labels)
                current_mask_sum = mask.sum()
                loss = (loss * mask).sum() / current_mask_sum

                # Weight the loss by current batch size and update the sum of weighted losses
                sum_weighted_losses += loss * current_mask_sum
                total_tokens += curr_mask_sum
            weighted_average_loss = sum_weighted_losses / total_tokens
        return weighted_average_loss

    def train(
        self,
        train_loader,
        test_loader=None,
        stopping_index = 8,
        epochs=1,
        KL_divergence_loss=False,
        lam = 0, #20000
        lam_testing_penalty = 0, #100000
        f_data_to_soft_labels=None,
        checkpoint_interval=60, #save checkpoint every 60 minutes
    ):
        self.opt = optim.AdamW(self.parameters(), lr= lr, weight_decay=.01) #usually: lr = 5e-5. 1e-3 worked well!

        if KL_divergence_loss:
            self.lossfn = nn.KLDivLoss(reduction = 'batchmean')
        else:
            self.lossfn = nn.CrossEntropyLoss()
        
        self.epoch_index = -1

        for epoch in range(epochs):
            self.epoch_index += 1
            # Create a tqdm progress bar
            with tqdm(
                total=len(train_loader), desc=f"Epoch {epoch + 1}/{epochs}", unit="batch"
            ) as pbar:
                num_datapoints_in_epoch=0
                epoch_train_loss = 0
                epoch_gradient_norm = 0
                # Train loop
                self.batch_index = -1 #index of first batch will be 0
                
                for batch in train_loader: #not sure what this does for fractional batches. meh whatev
                    self.batch_index += 1
                    self.batch = batch
                    current_batch_size = len(batch["tokenized_next_50_tokens"])
                    num_datapoints_in_epoch += current_batch_size
                    self.opt.zero_grad()

                    # Forward pass
                    self.prediction = self.forward(
                        batch["tokenized_first_sentence"],
                        batch["tokenized_next_50_tokens"],
                        stopping_index=stopping_index,
                        output_target_hidden_states=True,
                        output_edited_hidden_states=True,
                        output_edit_vectors=True,
                    )

                    # Compute the penalty (edit size relative to the hidden state)
                    self.lam = lam
                    edit_ratio = self.prediction['edit_vectors'].norm(dim=-1)[:,:stopping_index]/self.prediction['target_hidden_states'].norm(dim=-1)
                    self.per_datapoint_penalty_loss = self.lam * torch.sum(edit_ratio,dim=[1,2])
                    self.penalty_loss = torch.mean(self.per_datapoint_penalty_loss)
                    
                    # Compute the data loss
                    if KL_divergence_loss:
                        log_prob_predictions = torch.nn.functional.log_softmax(
                            self.prediction["logits"][:, :, :
                            ].reshape(-1, 50257),
                            dim=1,
                            )
                        # Now we must compute the soft labels! This is outsourced to the user-provided function + teacher_model
                        self.soft_labels = f_data_to_soft_labels(
                            batch["tokenized_first_sentence"],
                            batch["tokenized_next_50_tokens"],
                            num_predictions_max=50
                        )
                        #check that the mask makes sense!
                        mask = (batch["tokenized_next_50_tokens"] != 50256).reshape(-1)
                        self.prediction_loss = self.lossfn(log_prob_predictions[mask, :], self.soft_labels[mask,:])
                        #NOTE: currently I am letting the loss predict on tokens inside the editing window
                        #I didn't do this in the previous testing! Nor is it the case in crossentropy
                    
                    else: 
                        log_prob_predictions = torch.nn.functional.log_softmax(
                            self.prediction["logits"][:, stopping_index
                            ].reshape(-1, 50257),
                            dim=1,
                            )
                        # Create a mask to exclude padded tokens
                        #NOTE: here we are disallowing prediction on the first stopping_indexens. 
                        #Code is currently formatted such that this is not the case for KL
                        target_labels = batch["tokenized_next_50_tokens"][:, stopping_index:].reshape(-1)
                        mask = (target_labels != 50256)
                        # Compute the cross-entropy loss with masking
                        criterion = torch.nn.CrossEntropyLoss(reduction='none')
                        loss = criterion(log_prob_predictions, target_labels.long())
                        current_mask_sum = mask.sum()
                        self.prediction_loss = (loss * mask).sum() / current_mask_sum

                    

                    # Compute the total loss and backpropagate 
                    self.training_loss = self.prediction_loss + self.penalty_loss
                    self.training_loss.backward()
                    nn.utils.clip_grad_norm_(self.parameters(), max_grad_clip) #just implemented this! dunno if a cap of 1 to large, so I'm messing with reducing it

                    #Check for nan gradients 
                    # if check_nan_gradients(self):                   
                    #     break

                    #Backwards step
                    self.opt.step()

                    #metrics
                    epoch_train_loss += self.training_loss.item()*current_batch_size
                    gradients = [p.grad.view(-1) for p in self.parameters() if p.grad is not None]
                    all_gradients = torch.cat(gradients)
                    gradient_norm = torch.norm(all_gradients).item()
                    epoch_gradient_norm += gradient_norm*current_batch_size
                    wandb.log({"train_batch_total_loss": self.training_loss.item(),
                               "train_batch_prediction_loss": self.prediction_loss.item(),
                                "train_batch_penalty_loss": self.penalty_loss,
                                "train_batch_gradient_norm": gradient_norm,
                               })

                    # Update progress bar
                    pbar.update(1) #note: this was incorrectly displaying before!

                    # Check if it's time to save a checkpoint
                    current_time = time.time()
                    # first loop initialization
                    if self.batch_index == 0 and self.epoch_index == 0:
                        last_checkpoint_time = -100000

                    if current_time - last_checkpoint_time >= checkpoint_interval * 60:
                        # Save the checkpoint
                        torch.save(self.state_dict(), f"checkpoint_epoch_{epoch}_batch_{pbar.n}.pt")
                        last_checkpoint_time = current_time
                        #announce checkpoint save
                        print("Checkpoint saved at epoch", epoch, "batch", pbar.n)
                    
                ####END BATCH LOOP   
                #########################
            
                #epoch loss
                # epoch_test_prediction_loss = self.evaluate_crossentropy_test_loss_nogradient(
                #     test_loader,
                #     stopping_index
                #     batch_size
                # )
                if KL_divergence_loss:
                    epoch_test_prediction_loss = self.evaluate_KL_test_loss_nogradient(
                        dataloader=test_loader,
                        f_data_to_soft_labels= f_data_to_soft_labels, 
                        stopping_index= stopping_index
                    )
                
            
                # # Calculate and accumulate gradient norm for logging
                # gradients = [p.grad.view(-1) for p in self.parameters() if p.grad is not None]
                # all_gradients = torch.cat(gradients)
                # gradient_norm = torch.norm(all_gradients).item()
                # epoch_gradient_norm += gradient_norm

                wandb.log({"epoch_train_total_loss": epoch_train_loss /num_datapoints_in_epoch,
                            "test_prediction_loss": epoch_test_prediction_loss,
                            "gradient_norm": epoch_gradient_norm /num_datapoints_in_epoch
                            })  
            # Save the final model
            torch.save(self, "final_model.pt")

# %%
#####DIVISION!
#DATASET CONSTRUCTION BELOW

# %%
tokenizer = transformers.GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token
model = transformers.GPT2LMHeadModel.from_pretrained("gpt2")
for param in model.parameters():
    param.requires_grad = False
model.config.pad_token_id = model.config.eos_token_id

# %%
# # Read the CSV file into a DataFrame
import pandas as pd
import os
from datasets import Dataset
from transformers import GPT2Tokenizer
from torch.utils.data import DataLoader

csv_dir = 'wikipedia_three_sentences.csv'
dataframe_dir = 'wikipedia_df.pt'

def tokenize_followup(row):
    # Compose second_sentences and third_sentences
    followup_text = row['second_sentences'] + ' ' + row['third_sentences']
    
    # Select the first 500 characters
    followup_text = followup_text[:500]
    
    # Tokenize the followup text
    tokenized_followup = tokenizer.encode(followup_text)
    
    # Check if the resulting tokenized list is still less than 50 tokens
    if len(tokenized_followup) < 50:
        # Pad with token 50256 to reach a length of 50 tokens
        tokenized_followup = tokenized_followup + [50256] * (50 - len(tokenized_followup))
    
    return tokenized_followup


def create_dataframe_from_csv(csv_dir):
    df = pd.read_csv(csv_dir)

    # # Printng out examples of longest and shortest entries
    # # Iterate over each column
    # for column in df.columns:
    #     print(f"Column: {column}")
        
    #     # Find the 10 longest entries in the column
    #     longest_entries = df[column].astype(str).apply(len).nlargest(10)
    #     print("Longest entries:")
    #     for index, length in longest_entries.items():
    #         print(f"Length: {length}, Entry: {df.loc[index, column]}")
        
    #     # Find the 10 shortest entries in the column
    #     shortest_entries = df[column].astype(str).apply(len).nsmallest(10)
    #     print("Shortest entries:")
    #     for index, length in shortest_entries.items():
    #         print(f"Length: {length}, Entry: {df.loc[index, column]}")
        
    #     print()


    #Length of the dataframe to start
    # print(f"Length of dataframe: {len(df)}")
    # df.columns
    # Filter the dataset based on sentence length

    df['first_sentence_length'] = df['first_sentences'].apply(lambda x: len(x))
    df['second_sentence_length'] = df['second_sentences'].apply(lambda x: len(x))
    df['third_sentence_length'] = df['third_sentences'].apply(lambda x: len(x))

    df_filtered = df[
        (df['first_sentence_length'] >= 5) &
        (df['second_sentence_length'] >= 10) &
        (df['first_sentence_length'] <= 100)
    ]
    # print(f"Length of filtered dataframe: {len(df_filtered)}")

    from transformers import GPT2Tokenizer
    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
    df_filtered['tokenized_first_sentence'] = df_filtered.apply(lambda row: tokenizer.encode(row['first_sentences'], add_special_tokens=False), axis=1)
    df_filtered['tokenized_next_50_tokens'] = df_filtered.apply(lambda row: tokenize_followup(row), axis = 1)
    return df_filtered

if os.path.exists('wikipedia_df.pt'):
    df = pd.read_pickle('wikipedia_df.pt')
else: #save dataset
    df = create_dataframe_from_csv(csv_dir)
    df.to_pickle('wikipedia_df.pt')

# %%
def collate_fn(batch):
    res = {}
    for k in batch[0].keys():
        if k != '__index_level_0__':
            els = [x[k] for x in batch]
            max_length = max(len(x) for x in els)
            if k == 'tokenized_next_50_tokens':
                max_length = 50
                for i in range(len(els)):
                    if len(els[i]) > 50:
                        els[i] = els[i][:50]
            # for x in els:
            #     x += [0] * (max_length - len(x))
            #res[k] = torch.cat([y , torch.zeros(max_length - len(x))],for y in els)
            #res[k]=torch.tensor([x + [0] * (max_length( - len(x)) for x in els], dtype=torch.long)
            res[k]=torch.stack([ torch.cat((torch.tensor(x),torch.full((max_length - len(x),),50256))) for x in els]).int()
    return res

# %%
#Convert 2 columns to Dataset and train-test split
dataset = Dataset.from_pandas(df[['tokenized_first_sentence', 'tokenized_next_50_tokens']]).shuffle(seed=42)
test_ratio = .08
temp = dataset.train_test_split(test_size=test_ratio,seed=42)
temp
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokenized_first_sentence', 'tokenized_next_50_tokens', '__index_level_0__'],
#         num_rows: 987633
#     })
#     test: Dataset({
#         features: ['tokenized_first_sentence', 'tokenized_next_50_tokens', '__index_level_0__'],
#         num_rows: 85882
#     })
# })

# %%
batch_size=32 #50 or so
data_loader = DataLoader(temp["train"], batch_size=batch_size, collate_fn = collate_fn)#batch_size, collate_fn=collate_fn)
test_data_loader = DataLoader(temp["test"], batch_size=batch_size, collate_fn = collate_fn)#batch_size, collate_fn=collate_fn)

# # Now you can iterate over data_loader in your training loop
# j=0
# for batch in data_loader:
#     j=j+1
# print(j)
# #Good! we have all the data now

# %%
dataset, data_loader.batch_size
# Out:
# (Dataset({
#      features: ['tokenized_first_sentence', 'tokenized_next_50_tokens', '__index_level_0__'],
#      num_rows: 1073515
#  }),
#  32)

# %%
data_loader

# %%
# for batch in data_loader:
#     temp = batch
#     break
# temp.keys()

# %%
# for batch in data_loader:
#     temp = batch
#     break
# # temp["tokenized_next_50_tokens"]

# %%
def f_data_to_soft_labels(A, B, num_predictions_max = 50):
    with torch.no_grad():
        # Compute number of nonzero elements in each row of A and B
        lengths_A = torch.sum(A != 50256, dim=1)
        lengths_B = torch.sum(B != 50256, dim=1)
        # Concatenate A and B along dimension 1
        data = concat_and_pad(A, B) 
        logits = model(data).logits
        predictions = torch.nn.functional.softmax(logits, dim=2)

        #Create an empty tensor to store the predictions
        shape=( len(lengths_A), num_predictions_max, 50257)
        hold_output = torch.full(shape, torch.nan)

        # Extract the predictions corresponding to B
        for i in range(len(lengths_A)):
            hold_output[i, :lengths_B[i], :] = predictions[i, lengths_A[i]:lengths_A[i] + lengths_B[i], :]

        return hold_output.reshape(-1, 50257) #returns

# %%
hypernetwork = EditorHypernetwork(
    edit_dampening_factor = edit_dampening_factor, #1/10000, 
    use_layerwise_embeddings=False,
    num_editing_heads=num_editing_heads,
    edit_channel_width=editor_channel_width,
    chop_editor_at_layer=chop_layer,
)

# %%
i = 0
for batch in data_loader:
    if i == 18:
        temp = batch
        break
    i += 1
temp["tokenized_next_50_tokens"].shape
# Out:
# torch.Size([32, 50])

# %%
#current problem: 1728/ 30864 
hypernetwork.train(
    train_loader=data_loader,
    test_loader=test_data_loader,
    stopping_index=stopping_index,
    epochs=200,
    lam = lam, #10000,#20000
    lam_testing_penalty = 0,
    KL_divergence_loss=True,
    f_data_to_soft_labels = f_data_to_soft_labels,
)
# Out:
# Epoch 1/200:   0%|          | 0/30864 [00:00<?, ?batch/s]We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# You may ignore this warning if your `pad_token_id` (50256) is identical to the `bos_token_id` (50256), `eos_token_id` (50256), or the `sep_token_id` (None), and your input is not padded.
# Epoch 1/200:   0%|          | 1/30864 [00:01<13:54:06,  1.62s/batch]
# Checkpoint saved at epoch 0 batch 1
# Epoch 1/200:   3%|▎         | 799/30864 [11:30<7:12:52,  1.16batch/s]

# %% [markdown]
# Let's now look at some outputs!

# %%
hypernetwork = EditorHypernetwork(
    edit_dampening_factor = edit_dampening_factor, #1/10000, 
    use_layerwise_embeddings=False,
    num_editing_heads=num_editing_heads,
    edit_channel_width=editor_channel_width,
    chop_editor_at_layer=chop_layer, #currently set to 6 for current 8840.pt checkpoint
)
#state_dict = torch.load("checkpoint_epoch_0_batch_29105.pt")
#state_dict = torch.load("temp.pt")
hypernetwork.load_state_dict(state_dict)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 9
#       1 hypernetwork = EditorHypernetwork(
#       2     edit_dampening_factor = edit_dampening_factor, #1/10000,
#       3     use_layerwise_embeddings=False,
#    (...)
#       6     chop_editor_at_layer=chop_layer, #currently set to 6 for current 8840.pt checkpoint
#       7 )
#       8 #state_dict = torch.load("checkpoint_epoch_0_batch_29105.pt")
# ----> 9 state_dict = torch.load("temp.pt")
#      10 hypernetwork.load_state_dict(state_dict)
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995 if 'encoding' not in pickle_load_args.keys():
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
#    1002         # reset back to the original position.
#    1003         orig_position = opened_file.tell()
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:445, in _open_file_like(name_or_buffer, mode)
#     443 def _open_file_like(name_or_buffer, mode):
#     444     if _is_path(name_or_buffer):
# --> 445         return _open_file(name_or_buffer, mode)
#     446     else:
#     447         if 'w' in mode:
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:426, in _open_file.__init__(self, name, mode)
#     425 def __init__(self, name, mode):
# --> 426     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp.pt'

# %%
data_loader

# %%
for batch in data_loader:
    temp = batch
    break
#hypernetwork.inspect_batch_prediction_ouptuts(temp)

# %%
get_batch_index = 0
for batch in test_data_loader:
    get_batch_index += 1
    if get_batch_index == 18:
        temp = batch
        result = hypernetwork.forward(
            editor_input_ids=batch["tokenized_first_sentence"],
            target_input_ids=batch["tokenized_next_50_tokens"],
            stopping_index=stopping_index,
            output_target_hidden_states=True,
            output_edited_hidden_states=True,
            output_edit_vectors=True,
            output_editor_attention=True,
        )
        break

# %%
#predicted_strings=hypernetwork.inspect_batch_prediction_ouptuts(temp)

# %%
y = 0
for i in df["tokenized_first_sentence"]:
    temp2 = i
    y = y + 1
    if(y ==100):
        break

#temp2


# TODO from Karel:
# run some ablations: what layer do we edit. What happens when we regularize l1 and l2 of the intervention?

# %%
# hypernetwork.evaluate_KL_test_loss_nogradient(data_loader, f_data_to_soft_labels, stopping_index=stopping_index)
# #hypernetwork.inspect_batch_prediction_ouptuts(temp)
result= hypernetwork.forward(
    editor_input_ids=temp["tokenized_first_sentence"],
    target_input_ids=temp["tokenized_next_50_tokens"],
    stopping_index=stopping_index,
    output_target_hidden_states=True,
    output_edited_hidden_states=True,
    output_edit_vectors=True,
    output_editor_attention=True,
)
#compute most likely tokens from the logits
predicted_ids = [torch.argmax(pred, dim=-1) for pred in result["logits"]]
#convert the token ids to strings
predicted_strings = [tokenizer.decode(pred) for pred in predicted_ids]

#Compute the most likely tokens from running gpt2 on the target_input_ids
gpt2_result = model(temp["tokenized_next_50_tokens"].cuda())
gpt2_predicted_ids = [torch.argmax(pred, dim=-1) for pred in gpt2_result["logits"]]

#add in also a gpt2 which has access to the first string
gpt2_full_result = model(concat_and_pad(temp["tokenized_first_sentence"],temp["tokenized_next_50_tokens"]).cuda())
gpt2_full_predicted_ids = [torch.argmax(pred, dim=-1) for pred in gpt2_full_result["logits"]]

#Note: thee is a possible "cheating" thing here, but it's not really being "trained to cheat" per se

# %%
#batch

# %%
#compare against the actual strings from the batch
for i in range(len(predicted_strings)):
    print("Preceding string: ", tokenizer.decode(temp["tokenized_first_sentence"][i]))
    print("Actual string:    ", tokenizer.batch_decode(temp["tokenized_next_50_tokens"][i]))
    print("GPT2 full argmax:       ", tokenizer.batch_decode(gpt2_full_predicted_ids[i][torch.sum(temp["tokenized_first_sentence"][i] != 50256):]))
    print("Edited-Model argmax:    ", tokenizer.batch_decode(predicted_ids[i]))
    print("GPT2 target-only argmax:", tokenizer.batch_decode(gpt2_predicted_ids[i]))
    print("\n")
# Out:
# Preceding string:  Kočani medieval towers are located in Kocani, North Macedonia.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['They', ' were', ' probably', ' built', ' in', ' the', ' second', ' half', ' of', ' the', ' 17', 'th', ' century', ',', ' when', ' the', ' city', ' was', ' under', ' Ottoman', ' administration', '.', ' Impact', ' in', ' construction', ' had', ' ori', 'ental', ' architecture', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' are', ' built', ' built', ' in', ' the', ' late', ' half', ' of', ' the', ' 12', 'th', ' century', '.', ' and', ' the', ' city', ' was', ' still', ' the', ' rule', '.', ' The', ' of', ' the', ' is', ' been', 'ental', ' influences', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' are', ' built', ' built', ' in', ' the', ' late', ' half', ' of', ' the', ' 20', 'th', ' century', ',', ' and', ' the', ' city', ' was', ' still', ' the', ' rule', '.', ' The', ' of', ' the', ' of', ' been', 'ental', ' influences', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' are', ' all', ' the', ' in', ' the', ' late', ' half', ' of', ' the', ' 20', 'th', ' century', ',', ' and', ' the', ' first', ' was', ' still', ' the', ' rule', '.', '\n', ' of', ' the', ' is', ' been', 'ental', ' influences', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Victoria Hanley is an American young adult fantasy novelist.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['Her', ' first', ' three', ' books', ',', ' The', ' Se', 'er', ' And', ' The', ' Sword', ',', ' The', ' Healer', "'s", ' Keep', ' and', ' The', ' Light', ' Of', ' The', ' Oracle', ' are', ' companion', ' books', ' to', ' one', ' another', '.', ' Her', ' newest', ' book', ' (', 'released', ' March', ' 2012', ')', ' is', ' the', ' sequel', ' of', ' a', ' series', ',', ' called', ' Indigo', ' Magic', ',', ' published', ' by']
# GPT2 full argmax:        [' first', ' novel', ' novels', ' were', ' The', ' Last', 'eker', ',', ' The', ' Devil', ',', ' were', ' Dark', ',', ' Daughter', ',', ' The', ' Shadow', ',', ' The', ' Moon', ',', ' published', ' works', ' to', ' her', ' another', '.', ' She', ' second', ' novel', ',', 'The', ' in', ' 2017', ')', ' is', ' The', ' first', ' to', ' her', ' trilogy', ' of', ' The', ' The', ',', ',', ' which', ' by', ' Penguin', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' latest', ' novel', ' novels', ',', ' The', ' Last', 'eker', ',', ' The', ' Thief', ',', ' were', ' Dark', ',', ' Daughter', ',', ' The', ' Last', ',', ' The', ' World', ',', ' both', ' works', ' to', ' her', ' another', '.', ' She', ' second', ' book', ',', 'The', ' in', ' 2017', ')', ' is', ' The', ' first', ' to', ' her', ' trilogy', ' of', ' The', ' The', ',', ',', ' which', ' by', ' Penguin']
# GPT2 target-only argmax: [',', ' day', ' years', ' were', ' The', ' Great', 'eker', ' and', ' The', ' Thief', ',', ' were', ' Sword', ' And', ' Daughter', ',', ' The', ' Sword', ',', ' The', ' World', ',', ' both', ' pieces', ' for', ' the', ' another', '.', '\n', ' second', ' book', ',', 'The', ' in', ' 2017', ')', ' is', ' The', ' first', ' to', ' the', ' trilogy', ' of', ' The', ' The', ' Prophe', ',', ' which', ' by', ' the']
#
#
# Preceding string:  Rotten Sound is a Finnish grindcore band from Vaasa, formed in 1993.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' band', ' comprises', ' vocal', 'ist', ' Ke', 'ij', 'o', ' Ni', 'in', 'im', 'aa', ',', ' guitarist', ' M', 'ika', ' A', 'al', 'to', ',', ' bass', 'ist', ' Krist', 'ian', ' To', 'iv', 'ain', 'en', ',', ' and', ' drummer', ' Sam', 'i', ' Lat', 'va', '.', ' The', ' band', ' has', ' released', ' eight', ' studio', ' albums', ' and', ' "', 'earned', ' a', ' reputation', ' for', ' being']
# GPT2 full argmax:        [' band', "'s", ' of', 'ist', ' and', 'iko', 'o', ' K', 'emi', 'aga', 'ä', ',', ' guitarist', ' K', 'ika', ' K', 'oki', 'to', ',', ' bass', 'ist', ' M', 'ian', ' K', 'pp', 'onen', 'en', ',', ' drummer', ' drummer', ' M', 'i', ' K', 'if', '.', ' The', ' band', "'s", ' been', ' several', ' albums', ' albums', ',', ' has', 'The', '"', ' Grammy', ' as', ' being', ' one', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' band', ' is', ' of', 'ist', ' and', 'iko', 'o', ' K', 'emi', 'aga', 'ä', ',', ' guitarist', ' K', 'ika', ' K', 'oki', 'to', ',', ' bass', 'ist', ' M', 'ian', ' K', 'pp', 'onen', 'en', ',', ' drummer', ' drummer', ' M', 'i', ' K', 'if', '.', ' The', ' band', "'s", ' been', ' two', ' albums', ' albums', ',', ' has', 'The', '"', ' Grammy', ' as', ' being', ' one']
# GPT2 target-only argmax: ['\n', "'s", ' of', 'ist', ' and', 'le', 'in', ' K', 'em', 'aga', 'izu', ',', ' guitarist', ' Y', 'iki', ' K', 'oki', 'to', ',', ' bass', 'ist', ' Y', 'ian', ' K', 'pp', 'onen', 'en', ',', ' drummer', ' drummer', ' T', 'i', ' K', 'if', '.', '\n', ' band', ' is', ' been', ' two', ' studio', ' albums', ',', ' is', 'The', '"', ' Grammy', ' as', ' being', ' one']
#
#
# Preceding string:  1172 Äneas  is a large Jupiter trojan from the Trojan camp, approximately  in diameter.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' was', ' discovered', ' on', ' 17', ' October', ' 1930', ',', ' by', ' astronomer', ' Karl', ' Rein', 'm', 'uth', ' at', ' the', ' He', 'idel', 'berg', ' Observatory', ' in', ' southwest', ' Germany', '.', ' The', ' dark', ' D', '-', 'type', ' asteroid', ' is', ' one', ' of', ' the', ' largest', ' Jupiter', ' tro', 'j', 'ans', ' and', ' has', ' a', ' rotation', ' period', ' of', ' 8', '.', '7', ' hours', '.']
# GPT2 full argmax:        [' is', ' discovered', ' by', ' the', ' August', ',', ' by', ' by', ' the', ' and', ' von', 'hardt', 'uth', ',', ' the', ' University', 'idel', 'berg', ' Observatory', ' in', ' Germany', ' Germany', '.', ' It', ' Tro', '-', '-', 'shaped', ' of', ' was', ' about', ' of', ' the', ' most', ' known', ' tro', 'jan', 'ans', ' ever', ' is', ' been', ' mass', ' of', ' of', ' about', '.', '5', ' days', '.', ' It']
# Edited-Model argmax:     [' is', ' discovered', ' by', ' the', 'th', ',', ' by', ' by', ' the', ' and', ' K', 'hardt', 'uth', ',', ' the', ' University', 'idel', 'berg', ' Observatory', '.', ' Germany', ' Germany', '.', ' It', ' first', '-', '-', 'shaped', ' was', ' was', ' about', ' of', ' the', ' most', ' known', '-', 'j', 'ans', ' ever', ' is', ' been', ' mass', ' of', ' of', ' about', '.', '5', ' days', '.', ' It']
# GPT2 target-only argmax: [' is', ' a', ' that', ' the', ' August', ' that', ' that', ' that', ' a', ' and', ' Schwarz', 'hardt', 'uth', ',', ' the', ' University', 'idel', 'berg', ' Observatory', ' in', ' Germany', ' Germany', '.', ' The', ' telescope', ' matter', '-', 'shaped', ' star', ',', ' about', ' of', ' the', ' most', ' known', '-', 'j', 'ans', ' ever', ' is', ' been', ' mass', ' of', ' of', ' about', '.', '5', ' days', '.', '\n']
#
#
# Preceding string:  Hyperbaena allenii is a species of plant in the family Menispermaceae.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' is', ' found', ' in', ' Costa', ' Rica', ' and', ' Panama', '.', ' It', ' is', ' threatened', ' by', ' habitat', ' loss', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' a', ' in', ' the', ' Rica', ',', ' is', '.', ' It', ' is', ' a', ' by', ' the', ' loss', ' and', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' a', ' in', ' the', ' Rica', ',', ' is', '.', ' It', ' is', ' a', ' by', ' the', ' loss', ' and', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' not', ' that', ' the', ' Rica', ',', ' is', ',', '\n', ' is', ' found', ' by', ' the', ' loss', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Silk Degrees is the seventh solo album by Boz Scaggs, released on Columbia Records in February 1976.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' album', ' peaked', ' at', ' No', '.', ' 2', ' and', ' spent', ' 115', ' weeks', ' on', ' the', ' Billboard', ' 200', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' album', ' was', ' at', ' number', '.', ' 1', ' on', ' was', ' the', ' days', ' on', ' the', ' Billboard', ' 200', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' album', ' was', ' at', ' number', '.', ' 1', ' on', ' was', ' the', ' days', ' on', ' the', ' Billboard', ' Hot', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['\n', ' is', ' at', ' No', '.', ' 1', ' on', ' No', ' the', ' days', ' on', ' the', ' Billboard', ' 200', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Cape Cod Bay is a large bay of the Atlantic Ocean adjacent to the U.S.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['state', ' of', ' Massachusetts', '.', ' Me', 'asuring', ' ', ' below', ' a', ' line', ' drawn', ' from', ' Br', 'ant', ' Rock', ' in', ' Marsh', 'field', ' to', ' Race', ' Point', ' in', ' Prov', 'inc', 'et', 'own', ',', ' Massachusetts', ',', ' it', ' is', ' enclosed', ' by', ' Cape', ' Cod', ' to', ' the', ' south', ' and', ' east', ',', ' and', ' Plymouth', ' County', ',', ' Massachusetts', ',', ' to', ' the', ' west']
# GPT2 full argmax:        [' of', ' New', '.', ' It', 'asuring', ' 1', '\xa0', ' the', ' depth', ' of', ' from', ' the', 'idget', 'ford', ',', ' the', ' Bay', ',', ' the', ' Island', ' in', ' the', 'inc', 'et', 'own', ',', ' Massachusetts', ',', ' the', ' is', ' the', ' by', ' a', ' Cod', ' Bay', ' the', ' north', ' and', ' Cape', ' by', ' and', ' is', ' to', ' to', ' Massachusetts', ' to', ' to', ' the', ' north', '.', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' of', ' Florida', '.', ' It', 'asuring', ' 1', '\xa0', ' the', ' depth', ' of', ' by', ' the', 'ack', 'ford', ' to', ' the', ' Island', ',', ' the', ' Island', ' in', ' the', 'inc', 'et', 'own', ',', ' Massachusetts', ',', ' the', ' is', ' the', ' by', ' a', ' Cod', ' and', ' the', ' south', ' and', ' Cape', '.', ' and', ' is', ' to', ' to', ' Massachusetts', ' to', ' to', ' the', ' north', '.']
# GPT2 target-only argmax: ['.', ' the', ',', '\n', 'asuring', ' the', '\xa0', ' the', ' certain', ',', ' from', ' the', 'idget', 'ford', ' to', ' the', 'field', ',', ' the', ' Street', ' in', ' Boston', 'inc', 'et', 'own', ',', ' Massachusetts', ',', ' the', ' is', ' possible', ' by', ' a', ' Cod', ' and', ' the', ' south', '.', ' the', ' of', ' and', ' is', ' to', ' to', ' Massachusetts', ' to', ' to', ' the', ' north', '.']
#
#
# Preceding string:  Navega is the debut album by the Cape Verdean musician Mayra Andrade, released in 2006.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' is', ' sung', ' in', ' Cape', ' Ver', 'de', 'an', ' Cre', 'ole', ' language', '.', ' The', ' title', ' means', ' "', 'S', 'ail', '"', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' a', ' by', ' a', ' Ver', 'de', 'an', ',', 'ole', ',', '.', '\n', ' song', ' of', ' "', 'The', 'ail', 'or', ' in', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' a', ' by', ' a', ' Town', 'de', ',', ',', 'ole', ',', '.', '\n', ' song', ' of', ' "', 'The', 'ail', 'or', ' in', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' not', ' by', ' the', ' Town', 'de', ',', ',', 'ole', ',', '.', '\n', ' song', ' of', ' "', 'The', 'ongs', 'or', ' in', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  "Why Don't You Love Me" is a song by American singer and guitarist Hank Williams.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' song', ' reached', ' number', ' one', ' on', ' the', ' U', '.', 'S', '.', ' Country', ' &', ' Western', ' chart', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' song', ' is', ' No', ' one', ' on', ' the', ' Billboard', '.', 'S', '.', ' Billboard', ' Songs', ' Rock', ' Songs', ' in', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' song', ' is', ' No', ' one', ' on', ' the', ' Billboard', '.', 'S', '.', ' Billboard', ' Songs', ' Pop', ' Songs', ' in', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['\n', ' is', ' No', ' one', ' on', ' the', ' Billboard', '.', 'S', '.', ' Billboard', ' Songs', ' Pop', ' Songs', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Xirovouni () is a former municipality in the Arta regional unit, Epirus, Greece.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['Since', ' the', ' 2011', ' local', ' government', ' reform', ' it', ' is', ' part', ' of', ' the', ' municipality', ' Art', 'a', ',', ' of', ' which', ' it', ' is', ' a', ' municipal', ' unit', '.', ' The', ' municipal', ' unit', ' has', ' an', ' area', ' of', ' 123', '.', '6', '34', ' km', '2', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' the', ' beginning', ' elections', ' elections', ' elections', ',', ' has', ' now', ' of', ' the', ' "', ' of', 'a', ',', ' which', ' which', ' the', ' is', ' a', ' part', ' unit', '.', '\n', ' municipality', ' unit', ' is', ' a', ' office', ' of', ' 1', ' square', '5', ' hectares', ' square', '²', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' the', ' beginning', ' elections', ' elections', ' elections', ',', ' has', ' the', ' of', ' the', ' Greek', ' of', 'em', 'ş', ' which', ' which', ' the', ' is', ' a', ' part', ' corporation', '.', ' The', ' municipality', ' government', ' is', ' a', ' office', ' of', ' about', '.', '5', ' hectares', ' square', '²', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' the', ' first', ' election', ' elections', ' elections', ',', ' was', ' now', ' of', ' the', ' government', "'s", 'illery', 'ş', ' which', ' which', ' the', ' is', ' the', ' part', ' corporation', ',', '\n', ' municipality', ' government', ' is', ' a', ' office', ' of', ' about', ' square', '5', ' hectares', ' hectares', '²', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Mark Salter (born 16 March 1980) is an English footballer, who played as a forward.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['He', ' played', ' in', ' the', ' Football', ' League', ' for', ' S', 'out', 'hend', ' United', ',', ' when', ' he', ' signed', ' from', ' From', 'e', ' Town', ' in', ' 2002', '.', ' He', ' was', ' released', ' by', ' S', 'out', 'hend', ' at', ' the', ' end', ' of', ' the', ' 2002', '–', '03', ' season', ' and', ' joined', ' Bath', ' City', ' for', ' the', ' following', ' season', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' for', ' the', ' Premier', ' League', ' for', ' the', 'alf', 'hend', ' United', ',', ' where', ' he', ' was', ' for', ' Manchester', 'e', '.', '.', ' the', '.', ' He', ' has', ' a', ' from', ' S', 'out', 'hend', ' in', ' the', ' end', ' of', ' the', ' season', '-', '03', ' season', ',', ' was', ' the', ' in', ' in', ' the', ' next', ' season', '.', ' He', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' for', ' the', ' Premier', ' League', ' for', ' the', 'out', 'hend', ' United', ',', ' where', ' he', ' was', ' for', ' Manchester', 'e', '.', '.', ' the', '.', ' He', ' was', ' a', ' by', ' S', 'out', 'hend', ' in', ' the', ' end', ' of', ' the', ' season', '-', '03', ' season', ',', ' was', ' the', ' in', ' in', ' the', ' next', ' season', '.', ' He', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' the', ' first', ' League', ' for', ' the', 'alf', 'hend', ' United', ',', ' where', ' he', ' was', ' for', ' Southampton', 'e', ' in', ' in', ' the', '.', '\n', ' has', ' a', ' by', ' S', 'out', 'hend', ' in', ' the', ' end', ' of', ' the', ' season', '-', '03', ' season', ',', ' spent', ' the', ' in', ' in', ' £', ' next', ' season', '.', '\n', 'The', 'The', 'The']
#
#
# Preceding string:  Meet Me at the Go-Go is a compilation album originally released on July 7, 2003.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' compilation', ' consist', ' of', ' eleven', ' previously', ' released', ' songs', ' by', ' prominent', ' Washington', ',', ' D', '.', 'C', '.-', 'based', ' go', '-', 'go', ' bands', '.', ' The', ' album', ' was', ' compiled', ' by', ' Snow', 'boy', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' album', ' album', ' of', ' a', ' tracks', ' released', ' songs', ',', ' the', ' members', ',', ' D', '.', 'C', '.-', 'based', ' artists', '-', 'go', ' artists', ',', ' The', ' album', ' was', ' released', ' by', ' the', 'y', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' album', ' album', ' of', ' a', ' tracks', ' released', ' tracks', ',', ' the', ' artists', ',', ' D', '.', 'C', '.', 'based', ' artists', '-', 'go', ' artists', ',', ' The', ' album', ' was', ' released', ' by', ' the', 'y', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['\n', ' of', ' of', ' a', ' chapters', ' released', ' songs', ',', ' the', ' artists', ',', ' D', '.', 'C', '.', 'based', ' artists', '-', 'go', ' artists', ',', '\n', ' first', ' is', ' released', ' by', ' the', 'y', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  1985 saw many sequels and prequels in video games, such as Super Mario Bros.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['and', ' Kung', ' Fu', ',', ' along', ' with', ' new', ' titles', ' such', ' as', ' Commando', ',', ' Duck', ' Hunt', ',', ' Gauntlet', ',', ' Ghosts', " '", 'n', ' Gob', 'lins', ',', ' Grad', 'ius', ',', ' Hang', '-', 'On', ',', ' Space', ' Har', 'rier', ' and', ' The', ' Way', ' of', ' the', ' Expl', 'oding', ' Fist', '.', ' The', ' year', "'s", ' highest', '-', 'gross', 'ing', ' arcade']
# GPT2 full argmax:        [' Super', ' Fu', ' Panda', ' and', ' with', ' the', ' games', ' such', ' as', ' Super', ',', ' Super', ' Hunt', ',', ' and', ',', ' and', ',', 'n', "'", 'lins', ',', ' and', 'uation', ',', ' and', 'man', 'On', ',', ' and', ' Invaders', 'rier', ',', ' more', ' Legend', ' of', ' the', ' Samurai', 'orers', ' Man', '.', '\n', ' first', ' 2000', ' biggest', ' gross', 'gross', 'ing', ' video', ' game', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' the', ' Fu', ' Panda', ' and', ' with', ' the', ' characters', ' such', ' as', ' The', ',', ' The', ' Hunt', ',', ' and', ',', ' and', ',', 'n', "'", 'lins', ',', ' and', 'uation', ',', ' and', 'man', 'On', ',', ' and', ' Invaders', 'rier', ',', ' more', ' Legend', ' of', ' the', ' Warrior', 'orers', ' Man', '.', '\n', ' game', ' was', ' biggest', ' gross', 'gross', 'ing', ' game', ' game']
# GPT2 target-only argmax: [',', ' Fu', ')', ' and', ' with', ' the', ' characters', ' like', ' as', ' The', ',', ' The', ' Hunt', ',', ' and', ',', ' and', ',', 'n', "'", 'lins', ',', ' and', 'uation', ',', ' and', 'man', 'On', ',', ' and', ' Invaders', 'rier', ',', ' more', ' Last', ' of', ' the', ' Warrior', 'orers', ' Dragon', '.', '\n', ' game', ' is', ' biggest', ' gross', 'gross', 'ing', ' film', ' game']
#
#
# Preceding string:  Jordan Belchos (born June 22, 1989) is a Canadian speed skater.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['He', ' primarily', ' sk', 'ates', ' in', ' the', ' long', ' distances', ' of', ' 1500', ' m', ',', ' 5000', ' m', ' and', ' 10', ' 000', ' m', ',', ' as', ' well', ' as', ' the', ' mass', ' start', ' event', '.', ' He', ' won', ' medals', ' at', ' the', ' World', ' Cup', ' level', ' and', ' finished', ' third', ' at', ' the', ' 2012', '–', '13', ' IS', 'U', ' Speed', ' Sk', 'ating', ' Mass', ' Start']
# GPT2 full argmax:        [' is', ' plays', 'ates', ' in', ' the', ' snow', ' jump', ',', ' the', 'm', ' and', ' 1500', ' m', ',', ' 1000', ',', ' m', '.', ' and', ' well', ' as', ' in', ' long', ' of', ' and', '.', ' He', ' is', ' the', ' in', ' the', ' World', ' Championships', ' in', ',', ' the', ' second', ' in', ' the', ' World', ' World', '13', ' World', 'F', ' World', ' World', 'ating', ' Championships', ' Start', '.', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' plays', 'ates', ' in', ' the', ' snow', ' jump', ',', ' the', 'm', ' and', ' 1500', ' m', ',', ' 1000', ',', ' m', '.', ' and', ' well', ' as', ' in', ' long', ' of', ' and', '.', ' He', ' is', ' the', ' in', ' the', ' World', ' Championships', ' in', ',', ' the', ' second', ' in', ' the', ' World', ' World', '13', ' World', 'F', ' World', ' World', 'ating', ' Championships', ' Start', '.']
# GPT2 target-only argmax: [' is', ' works', 'ated', ' with', ' the', ' middle', '-', ',', ' the', 'm', ',', ' and', ' m', ',', ' 1000', ',', ' m', '.', ' and', ' well', ' as', ' in', ' long', ' of', ' and', '.', ' He', ' is', ' the', ' in', ' the', ' World', ' Championships', ' in', ',', ' the', ' second', ' in', ' the', ' World', ' Olympics', '13', ' World', 'F', ' World', ' World', 'ating', ' Championships', ' Start', ' event']
#
#
# Preceding string:  Hasle Church (Danish: Hasle Kirke) is a church located in Hasle Parish in Aarhus, Denmark.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' church', ' is', ' located', ' 3', ' km', '.', ' west', ' of', ' A', 'ar', 'hus', ' city', ' centre', ' and', ' north', ' of', ' �', '�', 'by', 'h', 'ø', 'j', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' church', ' is', ' located', ' in', ' km', ' from', ' from', ' of', ' the', 'ar', 'hus', ',', ' center', '.', ' is', ' of', ' the', '�', 'land', 'g', 'ö', 'y', '.', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' church', ' is', ' located', ' in', ' km', ' from', ' from', ' of', ' the', 'ar', 'hus', ',', ',', '.', ' is', ' of', ' the', '�', 'land', 'g', 'ä', 'y', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['\n', "'s", ' a', ' in', ' miles', ' from', ' from', ' of', ' the', 'ar', 'hus', ',', ',', '.', ' is', ' of', ' the', '�', 'land', 'l', 'ö', 'y', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Ring 2 is a ring road that surrounds the most central part of Copenhagen, Denmark.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' is', ' part', ' of', ' the', ' Danish', ' national', ' road', ' network', '.', ' The', ' total', ' length', ' of', ' the', ' road', ' is', ' about', ' 26', '\xa0', 'km', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' a', ' of', ' the', ' Copenhagen', ' National', ' park', ' network', ',', ' It', ' road', ' length', ' of', ' the', ' road', ' is', ' about', ' 1', ' km', 'km', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' a', ' of', ' the', ' "', ' National', ' park', ' network', ',', ' It', ' road', ' length', ' of', ' the', ' road', ' is', ' about', ' 1', ' km', 'km', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' not', ' of', ' the', ' process', ' government', ' identity', ' race', ',', '\n', ' Danish', ' number', ' of', ' the', ' road', ' is', ' about', ' 1', ' km', 'km', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  The Birmingham Bulls are an American football team based in Birmingham, United Kingdom.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['They', ' play', ' their', ' home', ' games', ' at', ' Kings', ' Norton', ' RFC', ' in', ' Hop', 'wood', '.', ' They', ' are', ' a', ' member', ' of', ' the', ' NFC', ' Division', ' Two', ' South', ' in', ' the', ' BA', 'FA', ' National', ' Le', 'agues', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' are', ' on', ' home', ' games', ' at', ' the', ' Cross', ' Stadium', ' Stadium', ' Birmingham', 'ew', ',', '\n', ' are', ' also', ' member', ' of', ' the', ' Football', ' North', ' I', ' club', ' Division', ' the', ' United', ' Football', ' Football', ' Football', 'agues', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' are', ' in', ' home', ' games', ' at', ' the', ' Park', ' Stadium', ' in', ' the', 'ew', ',', ' They', ' play', ' also', ' team', ' of', ' the', ' Football', ' North', ' I', ' club', ' Division', ' the', ' USA', ' Football', ' Football', ' Football', 'agues', '.', '<|endoftext|>', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' are', ' a', ' best', ' games', ' at', ' the', ' Park', ' and', ',', ' the', 'ew', ',', '\n', ' play', ' also', ' very', ' of', ' the', ' North', ' North', ' I', ' team', '.', ' the', ' North', 'HL', '.', ' Football', 'agues', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Kyle Baillie (born April 7, 1991) is a Canadian rugby union player.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['He', ' plays', ' as', ' a', ' flank', 'er', ' or', ' lock', ' for', ' the', ' Canadian', ' national', ' team', ' and', ' the', ' Toronto', ' Arrows', ' of', ' Major', ' League', ' Rugby', ' (', 'ML', 'R', ').', ' He', ' previously', ' played', ' for', ' N', 'OL', 'A', ' Gold', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' for', ' a', ' fullback', 'er', ' for', ' forward', '.', ' the', ' Canadian', ' National', ' team', '.', ' is', ' Canadian', ' Argon', '.', ' the', ' League', ' Soccer', '.', 'ML', 'R', ').', ' He', ' is', ' played', ' for', ' the', 'ipp', 'A', ' in', ' Coast', ' Ba', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' for', ' a', ' fullback', 'er', ' for', ' forward', ' for', ' the', ' New', ' National', ' team', '.', ' is', ' U', ' Argon', '.', ' the', ' Junior', ' Soccer', '.', 'ML', 'R', ').', ' He', ' is', ' played', ' for', ' the', 'ipp', 'A', ' in', ' Coast', ' He', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' a', ' man', 'er', ',', ' a', ',', ' the', ' wing', ' national', ' team', '.', ' is', ' U', ' FC', '.', ' the', ' League', ' Soccer', '.', 'ML', 'R', ').', ' He', ' is', ' played', ' for', ' the', 'ipp', 'A', ' in', ' Coast', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Port Austin Township is a civil township of Huron County in the U.S.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['state', ' of', ' Michigan', '.', ' ', ' The', ' population', ' was', ' 1', ',', '591', ' at', ' the', ' 2000', ' census', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' of', ' Texas', '.', ' It', '\xa0', ' township', ' is', ' estimated', ',', '8', ' in', ' the', ' time', ' census', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' of', ' Michigan', '.', ' It', '\xa0', ' township', ' is', ' estimated', ',', '8', ' in', ' the', ' end', ' census', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['.', ' the', ',', '\n', '\xa0', ' state', ' of', ' estimated', ',', '8', ',', ' the', ' time', ' census', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Kim Jae-yeon (Korean: 김재연, born 30 October 1980) is a South Korean politician and former activist.
# Actual string:     ['She', ' is', ' currently', ' serving', ' as', ' the', ' Permanent', ' President', ' of', ' the', ' Progressive', ' Party', ' since', ' 2020', '.', ' She', ' was', ' also', ' the', ' former', ' Member', ' of', ' the', ' National', ' Assembly', ' from', ' 2012', ' to', ' 2014', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' a', ' a', ' as', ' a', ' South', ' Representative', ' of', ' the', ' Korean', ' Party', ' of', ' 2010', '.', '\n', ' is', ' elected', ' the', ' first', ' President', ' of', ' Parliament', ' National', ' Assembly', ' from', ' 2010', ' to', ' 2015', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' a', ' a', ' as', ' the', ' president', ' Representative', ' of', ' the', ' Korean', ' Party', ' of', ' 2012', '.', '\n', ' is', ' elected', ' the', ' first', ' President', ' of', ' Parliament', ' National', ' Assembly', ' from', ' 2010', ' to', ' 2015', '.', '<|endoftext|>', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [',', ' a', ' in', ' a', ' a', ' director', ' Representative', ' of', ' the', ' United', ' Party', ' of', ' 2010', '.', '\n', ' is', ' elected', ' the', ' first', ' President', ' of', ' Parliament', ' House', ' Assembly', ' from', ' the', ' to', ' 2015', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  The Netherlands sent competitors to the 2018 Winter Paralympics in Pyeongchang, South Korea.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     [' Four', ' people', ' competed', ' in', ' para', '-', 's', 'now', 'boarding', '.', ' ', ' Five', ' people', ' competed', ' in', ' para', '-', 'al', 'pine', ' skiing', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' teams', ' were', ' in', ' the', '-', 'ath', 'port', 'boarding', ',', '\n', '\xa0', ' people', ' competed', ' in', ' snow', '-', 's', 'pine', ' skiing', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' of', ' were', ' in', ' the', '-', 'r', 'port', 'boarding', ',', '\n', '\xa0', ' of', ' competed', ' in', ' the', '-', 's', 'pine', ' skiing', '.', ' ', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [',', ' were', ' in', ' the', '-', 'r', 'port', 'boarding', ',', '\n', '\xa0', ' people', ' competed', ' in', ' the', '-', 's', 'pine', ' skiing', '.', ' ', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Cassipourea eketensis is a species of plant in the Rhizophoraceae family.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' is', ' endemic', ' to', ' Nigeria', '.', ' ', ' It', ' is', ' threatened', ' by', ' habitat', ' loss', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' a', ' to', ' the', ',', ' It', '\xa0', ' is', ' a', ' by', ' the', ' loss', ' and', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' a', ' to', ' the', ',', ' It', '\xa0', ' is', ' a', ' by', ' the', ' loss', ' and', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' not', ' to', ' the', ',', ' It', '\xa0', ' is', ' endemic', ' by', ' the', ' loss', ',', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Markia hystrix is a species of katydid in the subfamily Phaneropterinae.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' occurs', ' in', ' South', ' America', '.', ' ', ' A', ' common', ' name', ' for', ' it', ' is', ' lic', 'hen', ' k', 'at', 'yd', 'id', ' because', ' it', ' lives', ' surrounded', ' by', ' Us', 'nea', ' lic', 'hen', ' on', ' which', ' it', ' sust', 'ains', ' itself', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' in', ' the', ' America', ',', ' It', '\xa0', ' species', ' name', ' for', ' this', ' is', ' Hy', 'hen', '.', 'at', 'yd', 'id', '.', ' it', ' is', ' in', ' by', ' lic', 'ur', '.', 'hen', 'ii', ' the', ' it', ' grows', 'ains', ' its', '.', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# ...
# GPT2 full argmax:        ['ur', ' is', ' is', ' located', ' in', ' the', ' road', 'anga', ' from', ' the', 'ra', '.', '\n', '\xa0', ' villages', ' villages', ' are', ' located', ' inhabited', ' Gh', 'ur', ' and', 'G', 'ra', ' and', ' the', ' locals', ' and', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     ['ur', ' is', ' is', ' located', ' in', ' the', ' border', 'anges', ' from', ' the', 'bil', 'j', ' It', '\xa0', ' villages', ' villages', ' are', ' located', ' inhabited', ' G', 'ur', ' and', 'K', 'ra', ' and', ' the', ' locals', ' and', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['.', 'ango', ' in', ' a', ' in', ' the', ' river', 'anges', ' from', ' the', 'bil', 'j', '\n', '\xa0', ' villages', ' villages', ' are', ' located', ' inhabited', ' G', 'ur', ' and', 'K', 'ra', ' and', ' the', ' locals', ' and', ' ', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  WCLN-FM (105.7 FM) is a radio station broadcasting a Contemporary Christian Music format.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['Lic', 'ensed', ' to', ' R', 'enn', 'ert', ',', ' North', ' Carolina', ',', ' United', ' States', ',', ' it', ' serves', ' the', ' greater', ' F', 'ayette', 'ville', ',', ' North', ' Carolina', ' area', '.', ' The', ' station', ' is', ' currently', ' owned', ' by', ' Gr', 'ander', ' Vision', ' Media', ',', ' LLC', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        ['ensed', ' by', ' the', 'CA', 'ie', 'own', ' the', ' Carolina', ',', ' on', ' States', '.', ' and', ' is', ' as', ' public', ' Raleigh', 'ayette', 'ville', ' area', ' North', ' Carolina', ' area', '.', ' The', ' station', ' is', ' located', ' broadcasting', ' by', ' the', 'ady', ' Music', ' Radio', ',', ' LLC', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     ['ensed', ' by', ' the', 'CA', 'ert', 's', ' the', ' Carolina', ',', ' the', ' States', '.', ' and', ' is', ' as', ' public', ' Raleigh', 'ayette', 'ville', ' area', ' North', ' Carolina', ' area', '.', ' The', ' station', ' is', ' located', ' broadcasting', ' by', ' the', 'ady', ' Music', ' Radio', ',', ' LLC', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['.', ' to', ' operate', '.', 'ie', 's', ' the', ' Carolina', ',', ' and', ' States', '\n', '\n', ' is', ' as', ' public', ' good', '.', 'ville', ' area', ' North', ' Carolina', ' area', '.', '\n', ' company', ' is', ' located', ' operated', ' by', ' the', 'ady', ',', ',', ',', ' LLC', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Klĭtôrĭs (Greek: Key) is the fifth studio album by Nigerian singer Brymo.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' was', ' released', ' independently', ' on', ' May', ' 9', ',', ' 2016', ',', ' and', ' made', ' available', ' for', ' pre', '-', 'order', ' on', ' iTunes', ' prior', ' to', ' its', ' release', '.', ' The', ' album', ' comprises', ' 11', ' tracks', ' and', ' was', ' preceded', ' by', ' the', ' lead', ' single', ' "', 'Happy', ' Memories', '".', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' was', ' released', ' in', ' in', ' the', ' 15', ',', ' 2014', '.', ' and', ' was', ' its', ' for', ' free', '-', 'order', ' on', ' May', ' on', ' to', ' its', ' release', ' on', '\n', ' album', ' was', ' a', ' tracks', ',', ' features', ' released', ' by', ' a', ' album', ' single', ' "', 'I', ' Birthday', '".', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' was', ' released', ' in', ' in', ' the', ' 1', ',', ' 2014', '.', ' and', ' was', ' its', ' for', ' free', '-', 'order', ' on', ' May', ' on', ' to', ' its', ' release', ' on', '\n', ' album', ' was', ' a', ' tracks', ',', ' features', ' released', ' by', ' a', ' album', ' single', ' "', 'I', ' Birthday', '".', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' in', ' by', ' the', ' 1', ',', ' 2016', '.', ' and', ' was', ' available', ' to', ' free', '-', 'order', ' on', ' the', '.', ' to', ' its', ' release', '.', '\n', ' game', ' was', ' a', ' tracks', ',', ' features', ' released', ' by', ' "', ' album', ' single', ' "', 'I', ' Birthday', '".', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Thrinax radiata, the Florida thatch palm, is a medium to slow growing palm in the family Arecaceae.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' is', ' native', ' to', ' many', ' Caribbean', ' islands', ',', ' Central', ' America', ',', ' and', ' far', ' southern', ' Florida', '.', ' Its', ' natural', ' habitat', ' is', ' sandy', ',', ' cal', 'care', 'ous', ' soil', ' in', ' coastal', ' areas', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' a', ' to', ' the', ' tropical', ' islands', ' and', ' including', ' America', ',', ' and', ' the', ' north', ' Asia', '.', ' It', ' roots', ' habitat', ' is', ' in', ',', ' sandy', 'mer', 'ous', ',', ',', ' the', ' areas', ',', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' a', ' to', ' the', ' tropical', ' islands', ',', ' including', ' America', ',', ' and', ' the', '-', ' Asia', '.', ' It', ' native', ' habitat', ' is', ' in', ',', ' sandy', 'mer', 'ous', ',', ',', ' the', ' areas', ',', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' not', 'ly', ' the', ' countries', ' islands', ',', ' including', ' America', ',', ' and', ' the', '-', ' Africa', '.', '\n', ' native', ' habitat', ' is', ' the', ',', ' rocky', 'mer', 'ous', ',', ',', ' the', ' areas', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Hyposmocoma iodes is a species of moth of the family Cosmopterigidae.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' was', ' first', ' described', ' by', ' Lord', ' W', 'als', 'ingham', ' in', ' 1907', '.', ' It', ' is', ' endemic', ' to', ' the', ' Hawaiian', ' island', ' of', ' Mol', 'ok', 'ai', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' first', ' described', ' in', ' the', ' H', '.', 'ingham', ' in', ' 18', '.', ' It', ' is', ' a', ' to', ' the', ' eastern', ' Islands', ' of', ' Kau', 'ok', 'ai', ' and', '<|endoftext|>', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' first', ' described', ' in', ' the', ' H', '.', 'ingham', ' in', ' 18', '.', ' It', ' is', ' a', ' to', ' the', ' eastern', ' Islands', ' of', ' Kau', 'ok', 'ai', ',', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' reported', ' by', ' the', ' Justice', 'ig', 'ingham', ' in', ' 18', ',', '\n', ' was', ' a', ' to', ' the', ' North', ' Islands', ' of', ' Kau', 'ok', 'ai', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Bartley–Tweed Farm is a historic farm located near Newark, New Castle County, Delaware.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' property', ' includes', ' three', ' contributing', ' buildings', ':', ' a', ' st', 'ucc', 'o', 'ed', ' stone', ' and', ' brick', ' house', ',', ' a', ' frame', ' bank', ' barn', ' built', ' about', ' 18', '35', ',', ' and', ' a', ' late', ' 19', 'th', '-', 'century', ' frame', ' carriage', ' house', ' /', ' gran', 'ary', '.', ' ', ' The', ' stone', ' section', ' of', ' the', ' house', ' dates', ' to', ' the']
# GPT2 full argmax:        [' farm', ' is', ' a', ' large', ' farms', ',', ' a', ' barn', 'ables', 'o', ' house', ' barn', ' building', ' a', ' building', ',', ' a', ' barn', ' house', ',', ',', ' in', ' 18', '75', ',', ' and', ' a', ' barn', ' 1800', 'th', ' century', 'century', ' barn', ' house', ' house', '.', ' barn', 'ary', '.', ' The', '\xa0', ' property', ' house', ' is', ' the', ' house', ' is', ' back', ' the', ' early', 'The', 'The']
# Edited-Model argmax:     [' farm', ' is', ' a', ' large', ' properties', ',', ' a', ' farm', 'ables', 'o', ' house', ' building', ' building', ' a', ' building', ',', ' a', ' large', ' house', ',', ',', ' in', ' 18', ' years', ',', ' and', ' a', ' barn', ' 19', 'th', ' century', 'century', ' brick', ' house', ' house', '.', ' barn', 'ary', '.', ' The', '\xa0', ' property', ' house', ' is', ' the', ' house', ' is', ' back', ' the', ' early']
# GPT2 target-only argmax: ['\n', ' is', ' a', ' bedrooms', ' properties', ',', ' a', ' restaurant', 'ucc', 'o', '-', ' building', ' building', ' a', ' building', ',', ' a', ' large', ' house', ',', ',', ' in', ' a', ' years', ',', ' and', ' a', ' large', ' 19', 'th', ' century', 'century', ' brick', ' house', ' house', '.', ' barn', 'ary', '.', '\n', '\xa0', ' house', ' house', ' is', ' the', ' house', ' is', ' from', ' the', ' early']
#
#
# Preceding string:  James Robinson (22 November 1813–4 March 1862) was a British dentist and anaesthetist.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['On', ' 19', ' December', ' 18', '46', ',', ' he', ' became', ' the', ' first', ' person', ' to', ' carry', ' out', ' general', ' ana', 'esthesia', ' in', ' Britain', ' when', ' he', ' administered', ' ether', ' to', ' a', ' patient', ' undergoing', ' a', ' tooth', ' extraction', '.', ' The', ' next', ' year', ',', ' he', ' published', ' A', ' Treat', 'ise', ' on', ' the', ' In', 'hal', 'ation', ' of', ' the', ' V', 'ap', 'our']
# GPT2 full argmax:        [' the', ' November', ' 18', '13', ',', ' Robinson', ' was', ' the', ' first', ' British', ' to', ' be', ' out', ' a', ' ana', 'esthesia', ' in', ' the', '.', ' he', ' was', ' a', ' to', ' a', ' patient', ' who', ' ana', ' severe', ' extraction', '.', ' He', ' patient', ' day', ',', ' he', ' was', ' a', ' Treat', 'ise', ' on', ' the', ' Use', 'juries', 'ation', ' of', ' the', ' Ear', 'ascular', 'our', ' of', 'The']
# Edited-Model argmax:     [' 18', ' October', ' 18', '59', ',', ' he', ' was', ' the', ' first', ' person', ' to', ' be', ' out', ' a', ' surgery', 'esthesia', ' in', ' the', '.', ' he', ' was', ' a', ' to', ' a', ' patient', ' who', ' ana', ' severe', ' extraction', '.', ' He', ' procedure', ' day', ',', ' he', ' was', ' a', ' Treat', 'ise', ' on', ' the', ' Use', 'juries', 'ation', ' of', ' the', ' Ear', 'ascular', 'our', ' of']
# GPT2 target-only argmax: [' the', ' August', ',', '48', ',', ' the', ' was', ' the', ' first', ' man', ' to', ' be', ' a', ' a', ' strikes', 'esthesia', ' in', ' the', '.', ' he', ' was', ' a', ' to', ' a', ' patient', ' who', ' ana', ' severe', ' extraction', '.', '\n', ' patient', ' day', ',', ' he', ' was', ' a', ' Treat', 'ise', ' on', ' the', ' Use', 'vis', 'ation', ' of', ' the', ' Sick', 'ascular', 'our', ' of']
#
#
# Preceding string:  The 2019 Russian Figure Skating Championships () were held from 19 to 23 December 2018 in Saransk.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['Med', 'als', ' were', ' awarded', ' in', ' the', ' disciplines', ' of', ' men', "'s", ' singles', ',', ' ladies', "'", ' singles', ',', ' pair', ' skating', ',', ' and', ' ice', ' dancing', '.', ' The', ' results', ' were', ' among', ' the', ' criteria', ' used', ' to', ' select', ' Russia', "'s", ' teams', ' to', ' the', ' 2019', ' European', ' Championships', ' and', ' 2019', ' World', ' Championships', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        ['als', ' were', ' awarded', ' by', ' the', ' following', ' of', ' skating', "'s", ' and', ',', ' women', "'", ' and', ',', ' and', 'ings', ',', ' and', ' men', ' hockey', '.', ' The', ' 2018', ' of', ' announced', ' the', ' best', ' for', ' to', ' determine', ' the', "'s", ' top', ' for', ' compete', ' 2018', ' Sochi', ' Championships', '.', ' the', ' World', ' Championships', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     ['als', ' were', ' awarded', ' to', ' the', ' following', ' of', ' gymn', "'s", ' and', ',', ' women', "'", ' singles', ',', ' men', 'ings', ',', ' and', ' men', ' hockey', '.', ' The', ' winners', ' were', ' announced', ' the', ' best', ' for', ' to', ' determine', ' the', "'s", ' top', ' for', ' compete', ' 2014', ' Winter', ' Championships', '.', ' the', ' World', ' Championships', '.', '\n', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['.', ':', ' not', ' to', ' the', ' form', ' of', ' medicine', "'s", ' and', ',', ' women', "'", ' singles', ',', ' and', 'ings', ',', ' and', ' women', ' hockey', '.', '\n', ' awards', ' were', ' published', ' the', ' best', ' for', ' to', ' determine', ' the', "'s", ' top', ' for', ' compete', ' World', ' World', ' Championships', '.', ' the', ' World', ' Championships', '.', '\n', 'The', 'The', 'The', 'The', 'The']

# %%
#decoding the first element of batch
tokenizer.decode(batch["tokenized_next_50_tokens"][0]), tokenizer.decode(batch["tokenized_next_50_tokens"][0]), tokenizer.decode(batch["tokenized_first_sentence"][0][0]), tokenizer.decode(batch["tokenized_first_sentence"][0][1])
# Out:
# ('They were probably built in the second half of the 17th century, when the city was under Ottoman administration. Impact in construction had oriental architecture..<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>',
#  'They were probably built in the second half of the 17th century, when the city was under Ottoman administration. Impact in construction had oriental architecture..<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>',
#  'Ko',
#  'č')

# %%
result["edit_vectors"].shape, result['editor_attention'].shape
# Out:
# (torch.Size([32, 50, 13, 768]), torch.Size([32, 1536, 104]))

# %%
edit_tensor.shape
# Out:
# torch.Size([50, 13, 768])

# %%
#This block calculates edit norm relative to the size of the current activations
import matplotlib.pyplot as plt
import numpy as np
for batch_index in range(min(20,len(batch["tokenized_next_50_tokens"]))):

    #The tensor norm comes in an 8x13 matrix
    edit_tensor = result["edit_vectors"][batch_index].to("cpu")
    edit_tensor[:stopping_index,:, :] = edit_tensor[:stopping_index,:,:]/result["target_hidden_states"][batch_index].norm(dim=2, keepdim=True) .to("cpu")
    edit_tensor_norm = edit_tensor.norm(dim=2).flip(1)

    # is this any better??
    # attention_matrix = result['editor_attention'][batch_index].reshape(104).to("cpu").reshape(13,8).permute(1,0)

    # Detach and convert to numpy
    edit_tensor_norm = edit_tensor_norm.detach().numpy()[0:stopping_index, :]

    # Create the heatmap
    fig, ax = plt.subplots()
    heatmap = ax.imshow(edit_tensor_norm.transpose(), cmap="hot")

    # Color the heatmap according to the entry sizes
    heatmap.set_clim(vmin=np.min(0), vmax=np.max(edit_tensor_norm))
    cbar = plt.colorbar(heatmap)
    cbar.set_label("Entry Sizes")

    # Add labels to the x and y axes
    ax.set_yticks(np.arange(13))
    ax.set_xticks(np.arange(8))
    #ax.set_yticklabels(np.arange(13))
    ax.set_yticklabels(np.arange(12,-1,-1))
    ax.set_xticklabels(np.arange(8))

    # Rotate the x-axis labels
    #plt.xticks(rotation=90)

    # Add a title
    plt.title("Edit / Target Norm Heatmap")

    # Show the plot
    plt.show()

    print(tokenizer.batch_decode(batch["tokenized_next_50_tokens"][batch_index][0:8]))
    print(tokenizer.batch_decode(batch["tokenized_first_sentence"][batch_index]))
# Out:
# ['They', ' were', ' probably', ' built', ' in', ' the', ' second', ' half']
# ['Ko', 'č', 'ani', ' medieval', ' towers', ' are', ' located', ' in', ' K', 'oc', 'ani', ',', ' North', ' Macedonia', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['Her', ' first', ' three', ' books', ',', ' The', ' Se', 'er']
# ['Victoria', ' Han', 'ley', ' is', ' an', ' American', ' young', ' adult', ' fantasy', ' novelist', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['The', ' band', ' comprises', ' vocal', 'ist', ' Ke', 'ij', 'o']
# ['R', 'otten', ' Sound', ' is', ' a', ' Finnish', ' grind', 'core', ' band', ' from', ' Va', 'asa', ',', ' formed', ' in', ' 1993', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['It', ' was', ' discovered', ' on', ' 17', ' October', ' 1930', ',']
# ['11', '72', ' �', '�', 'ne', 'as', ' ', ' is', ' a', ' large', ' Jupiter', ' tro', 'jan', ' from', ' the', ' Trojan', ' camp', ',', ' approximately', ' ', ' in', ' diameter', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['It', ' is', ' found', ' in', ' Costa', ' Rica', ' and', ' Panama']
# ['Hyper', 'ba', 'ena', ' all', 'en', 'ii', ' is', ' a', ' species', ' of', ' plant', ' in', ' the', ' family', ' Men', 'is', 'perm', 'aceae', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['The', ' album', ' peaked', ' at', ' No', '.', ' 2', ' and']
# ['Sil', 'k', ' Deg', 'rees', ' is', ' the', ' seventh', ' solo', ' album', ' by', ' Bo', 'z', ' Sc', 'agg', 's', ',', ' released', ' on', ' Columbia', ' Records', ' in', ' February', ' 1976', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['state', ' of', ' Massachusetts', '.', ' Me', 'asuring', ' ', ' below']
# ['C', 'ape', ' Cod', ' Bay', ' is', ' a', ' large', ' bay', ' of', ' the', ' Atlantic', ' Ocean', ' adjacent', ' to', ' the', ' U', '.', 'S', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['It', ' is', ' sung', ' in', ' Cape', ' Ver', 'de', 'an']
# ['N', 'ave', 'ga', ' is', ' the', ' debut', ' album', ' by', ' the', ' Cape', ' Ver', 'de', 'an', ' musician', ' May', 'ra', ' And', 'rade', ',', ' released', ' in', ' 2006', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['The', ' song', ' reached', ' number', ' one', ' on', ' the', ' U']
# ['"', 'Why', ' Don', "'t", ' You', ' Love', ' Me', '"', ' is', ' a', ' song', ' by', ' American', ' singer', ' and', ' guitarist', ' Hank', ' Williams', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['Since', ' the', ' 2011', ' local', ' government', ' reform', ' it', ' is']
# ['X', 'iro', 'v', 'oun', 'i', ' ()', ' is', ' a', ' former', ' municipality', ' in', ' the', ' Art', 'a', ' regional', ' unit', ',', ' E', 'pir', 'us', ',', ' Greece', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['He', ' played', ' in', ' the', ' Football', ' League', ' for', ' S']
# ['Mark', ' Sal', 'ter', ' (', 'born', ' 16', ' March', ' 1980', ')', ' is', ' an', ' English', ' footballer', ',', ' who', ' played', ' as', ' a', ' forward', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['The', ' compilation', ' consist', ' of', ' eleven', ' previously', ' released', ' songs']
# ['Meet', ' Me', ' at', ' the', ' Go', '-', 'Go', ' is', ' a', ' compilation', ' album', ' originally', ' released', ' on', ' July', ' 7', ',', ' 2003', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['and', ' Kung', ' Fu', ',', ' along', ' with', ' new', ' titles']
# ['1985', ' saw', ' many', ' sequels', ' and', ' pre', 'qu', 'els', ' in', ' video', ' games', ',', ' such', ' as', ' Super', ' Mario', ' Bros', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['He', ' primarily', ' sk', 'ates', ' in', ' the', ' long', ' distances']
# ['Jordan', ' Bel', 'ch', 'os', ' (', 'born', ' June', ' 22', ',', ' 1989', ')', ' is', ' a', ' Canadian', ' speed', ' sk', 'ater', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['The', ' church', ' is', ' located', ' 3', ' km', '.', ' west']
# ['Has', 'le', ' Church', ' (', 'D', 'anish', ':', ' Has', 'le', ' Kir', 'ke', ')', ' is', ' a', ' church', ' located', ' in', ' Has', 'le', ' Parish', ' in', ' A', 'ar', 'hus', ',', ' Denmark', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['It', ' is', ' part', ' of', ' the', ' Danish', ' national', ' road']
# ['Ring', ' 2', ' is', ' a', ' ring', ' road', ' that', ' surrounds', ' the', ' most', ' central', ' part', ' of', ' Copenhagen', ',', ' Denmark', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['They', ' play', ' their', ' home', ' games', ' at', ' Kings', ' Norton']
# ['The', ' Birmingham', ' Bulls', ' are', ' an', ' American', ' football', ' team', ' based', ' in', ' Birmingham', ',', ' United', ' Kingdom', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['He', ' plays', ' as', ' a', ' flank', 'er', ' or', ' lock']
# ['Kyle', ' Ba', 'ill', 'ie', ' (', 'born', ' April', ' 7', ',', ' 1991', ')', ' is', ' a', ' Canadian', ' rugby', ' union', ' player', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['state', ' of', ' Michigan', '.', ' ', ' The', ' population', ' was']
# ['Port', ' Austin', ' Township', ' is', ' a', ' civil', ' township', ' of', ' Hur', 'on', ' County', ' in', ' the', ' U', '.', 'S', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['She', ' is', ' currently', ' serving', ' as', ' the', ' Permanent', ' President']
# ['Kim', ' Jae', '-', 'ye', 'on', ' (', 'K', 'orean', ':', ' ', '�', '�', '�', '�', '�', '�', '�', '�', '�', ',', ' born', ' 30', ' October', ' 1980', ')', ' is', ' a', ' South', ' Korean', ' politician', ' and', ' former', ' activist', '.']

# %%
##### IGNORE BELOW! Old code!

# %%
import matplotlib.pyplot as plt
import numpy as np
for batch_index in range(min(10,len(batch["tokenized_next_50_tokens"]))):

    #The tensor norm comes in an 8x13 matrix
    edit_tensor = result["edit_vectors"][batch_index].to("cpu")
    edit_tensor_norm = edit_tensor.norm(dim=2)

    # is this any better??
    # attention_matrix = result['editor_attention'][batch_index].reshape(104).to("cpu").reshape(13,8).permute(1,0)

    # Detach and convert to numpy
    edit_tensor_norm = edit_tensor_norm.detach().numpy()[0:stopping_index, :]

    # Create the heatmap
    fig, ax = plt.subplots()
    heatmap = ax.imshow(edit_tensor_norm, cmap="hot")

    # Color the heatmap according to the entry sizes
    heatmap.set_clim(vmin=np.min(0), vmax=np.max(edit_tensor_norm))
    cbar = plt.colorbar(heatmap)
    cbar.set_label("Entry Sizes")

    # Add labels to the x and y axes
    ax.set_xticks(np.arange(13))
    ax.set_yticks(np.arange(8))
    ax.set_xticklabels(np.arange(13))
    ax.set_yticklabels(np.arange(8))

    # Rotate the x-axis labels
    plt.xticks(rotation=90)

    # Add a title
    plt.title("Edit Norm Heatmap")

    # Show the plot
    plt.show()

    print(tokenizer.batch_decode(batch["tokenized_next_50_tokens"][batch_index][0:8]))
# Out:
# ['In', ' the', ' bicycle', ',', ' she', ' hum', 'med', ' along']
# ['In', ' the', ' cozy', ' library', ',', ' a', ' bird', ' lover']
# ['B', 'ene', 'ath', ' the', ' cat', 'lit', ' sky', ',']
# ['Under', ' the', ' tall', ' ocean', ',', ' birds', ' sang', ' joy']
# ['A', ' slice', ' of', ' computer', ' can', ' bright', 'en', ' any']
# ['A', ' loyal', ' chair', ' always', ' waits', ' by', ' the', ' door']
# ['On', ' the', ' ocean', ' rack', ' by', ' the', ' door', '.']
# ['Under', ' the', ' old', ' oak', ' star', ',', ' we', ' gathered']
# ['A', ' delicious', ' flower', ' awaited', ' her', ' at', ' home', '.']
# ['In', ' a', ' shiny', ' red', ' flower', ',', ' we', ' raced']

# %%
import matplotlib.pyplot as plt
import numpy as np
stopping_index = 8

for head_index in range(min(hypernetwork.editor_model.config.num_editing_heads,10)):
    for batch_index in range(3):

        # Reshape the tensor into an 8x13 matrix
        attention_matrix = result["editor_attention"][batch_index][head_index].reshape(8, 13).to("cpu")

        # is this any better??
        # attention_matrix = result['editor_attention'][batch_index].reshape(104).to("cpu").reshape(13,8).permute(1,0)

        # Detach and convert to numpy
        attention_matrix = attention_matrix.detach().numpy()

        # Create the heatmap
        fig, ax = plt.subplots()
        heatmap = ax.imshow(attention_matrix, cmap="hot")

        # Color the heatmap according to the entry sizes
        heatmap.set_clim(vmin=np.min(attention_matrix), vmax=np.max(attention_matrix))
        cbar = plt.colorbar(heatmap)
        cbar.set_label("Entry Sizes")

        # Add labels to the x and y axes
        ax.set_xticks(np.arange(13))
        ax.set_yticks(np.arange(8))
        ax.set_xticklabels(np.arange(13))
        ax.set_yticklabels(np.arange(8))

        # Rotate the x-axis labels
        plt.xticks(rotation=90)

        # Add a title
        plt.title("Editor Attention Heatmap")

        # Show the plot
        plt.show()


        print(tokenizer.batch_decode(batch["result_text"][batch_index]))
        print(tokenizer.batch_decode(batch["editor_tokens"][batch_index][8:]))
# Out:
# ['In', ' the', ' bicycle', ',', ' she', ' hum', 'med', ' along', ',', ' and', ' then', ' she', ' turned', ' to', ' the', ' driver', '.', '\n', '\n', '"', 'I', "'m", ' not']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 43
#      39 plt.show()
#      42 print(tokenizer.batch_decode(batch["result_text"][batch_index]))
# ---> 43 print(tokenizer.batch_decode(batch["editor_tokens"][batch_index][8:]))
#
# KeyError: 'editor_tokens'

# %%
# torch.norm(
#     result["edit_vectors"][batch_index][:stopping_index, :, :].to("cpu"), dim=[0, 2]
# )  # looks better now!

# %% [markdown]
# Notes: It seems, currently, like we are not giving sufficient incentive to intervene at the lowest possible layer

# %%
result["edit_vectors"].shape
# Out:
# torch.Size([160, 23, 13, 768])

# %%
edit_tensor = result["edit_vectors"][batch_index].reshape(8, 13, -1).to("cpu")
edit_tensor_norm = edit_tensor.norm(dim=2)
edit_tensor_norm.shape
# Out:
# torch.Size([8, 13])

# %%
edited_states = torch.stack(result['edited_hidden_states'],dim = 2)
edited_states.shape
# Out:
# torch.Size([160, 23, 13, 768])

# %%
for i in range(8):
    print(edited_states[0][i][0].norm())
# Out:
# tensor(10.1000, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.7675, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.8729, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(10.8826, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.3322, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.1028, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.0002, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.3511, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)

# %%
print(
    torch.norm(result['target_hidden_states'][0][6][0]),
    torch.norm(result['target_hidden_states'][0][0][0]),
    edited_states[0][6][0].norm(),
    edited_states[0][2][0].norm()
)
# Out:
# tensor(5.0002, device='cuda:0') tensor(10.1001, device='cuda:0') tensor(5.0002, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>) tensor(5.8729, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)

# %%
# torch.save(hypernetwork.state_dict(), "/root/aiplay-1/hypernetworks/hypernetwork.pth")
