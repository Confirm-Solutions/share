# %% [markdown]
# First, run
# download_wikipedia.ipynb
# to get the file
# wikipedia_three_sentences.csv
#
# Then, we do our processing here
#
# random note: #could upgrade to use a 4090 or A6000

# %%
stopping_index=8
num_editing_heads = 768*2 #more seems to be better for this #per sid's suggestion: can add more heads in every layer. This is probably a really great suggestion
editor_channel_width = 768 * 2
max_grad_clip = 4.0
chop_layer = 8
lr = 4e-4
edit_dampening_factor=1e-4

# %% [markdown]
# notes from Sid: SAE vs principal components
# -you could try to work on the SAE's???
# -get discrete targets
# [I wouldn't be surprised at all if this helped a lot]
#
#
# -Next deliverables:

# %%
#batch['tokenized_first_sentence'][30].size(), batch['tokenized_next_50_tokens'][30].size()

# %%
# Trying out the editor hypernetwork on the dune dataset
import wandb

wandb.init(
    # set the wandb project where this run will be logged
    project="hypernetworks",
    config={"targetmodel": "gpt2", "editormodel": "gpt2"},
)
# Copy this below where needed!
# run.log_model(path="<path-to-model>", name="<name>")

# wandb.log({"acc": acc, "loss": loss})

# wandb.finish()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: michaelbsklar (michaelsklar). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/ubuntu/share/hypernetworks/wandb/run-20240502_083519-igzwdeug</code>
# Syncing run <strong><a href='https://wandb.ai/michaelsklar/hypernetworks/runs/igzwdeug' target="_blank">hardy-sun-307</a></strong> to <a href='https://wandb.ai/michaelsklar/hypernetworks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/michaelsklar/hypernetworks' target="_blank">https://wandb.ai/michaelsklar/hypernetworks</a>
#  View run at <a href='https://wandb.ai/michaelsklar/hypernetworks/runs/igzwdeug' target="_blank">https://wandb.ai/michaelsklar/hypernetworks/runs/igzwdeug</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/michaelsklar/hypernetworks/runs/igzwdeug?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# CUDA_LAUNCH_BLOCKING=1
#os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
# Set torch default device
import torch
torch.set_default_device("cuda")

# %%
import transformers
from transformers import GPT2LMHeadModel, GPT2Tokenizer, GPT2Config, GPT2Model
from transformers.models.gpt2.modeling_gpt2 import GPT2Attention
import torch
from torch import compile
import torch.nn as nn
from torch import optim
from torch.utils.data import Dataset, DataLoader
import transformers
from tqdm import tqdm
import pandas as pd
import yaml
import contextlib
import os
import time

# %%
def add_cross_attention_to_layer(block, config):
    block.crossattention = GPT2Attention(config, is_cross_attention=True)
    block.ln_cross_attn = nn.LayerNorm(
        normalized_shape=768, eps=config.layer_norm_epsilon
    )
    original_query_weights = block.attn.c_attn.weight[:, :768]
    original_keys_values = block.attn.c_attn.weight[:, 768:]
    original_query_bias = block.attn.c_attn.bias[:768]
    original_keys_values_bias = block.attn.c_attn.bias[768:]
    with torch.no_grad():
        # Initialize the new layer with these parameters
        block.crossattention.q_attn.weight = nn.Parameter(original_query_weights)
        block.crossattention.q_attn.bias = nn.Parameter(original_query_bias)
        block.crossattention.c_attn.weight = nn.Parameter(original_keys_values)
        block.crossattention.c_attn.bias = nn.Parameter(original_keys_values_bias)
    return

# %% [markdown]
# Now, we stick on the "reverse attention" module at the end!
# This is a customized attention head that reads from the editor model, and writes to the target model's activations

# %%
class Editor_Attention(nn.Module):
    def __init__(self, config):
        super().__init__()

        #Controls whether the head will do a global softmax in all positions & layers
        #If True, the attn is global and will sum to 1
        #If False, the attn is a logistic fxn independently for every layer & token
        #I suspect we will also want to penalize the intervention norm
        self.num_editing_heads = config.num_editing_heads #should default to 1, but we're going to test adding more
        self.edit_channel_width = config.edit_channel_width
        if self.edit_channel_width % self.num_editing_heads != 0:
            print("Error: config hidden size is not divisible by num_editing_heads")
        self.head_dim = self.edit_channel_width // self.num_editing_heads
        self.embed_dim = config.hidden_size

        max_positions = config.max_position_embeddings #does this do anything? can try killing this later
        self.register_buffer(
            "bias",
            torch.tril(
                torch.ones((max_positions, max_positions), dtype=torch.bool)
            ).view(1, 1, max_positions, max_positions),
            persistent=False,
        )
        self.register_buffer("masked_bias", torch.tensor(-1e4), persistent=False)

        # We compute Q and K as a single nn.linear; but will later break apart into subcomponents

        ## Before modification to a variable channel-width
        # self.q_attn = nn.Linear(self.embed_dim, self.embed_dim)
        # self.k_attn = nn.Linear(self.embed_dim, self.embed_dim)
        # self.v_attn = nn.Linear(self.embed_dim, self.embed_dim)
        # self.out_proj = nn.Linear(self.embed_dim, self.embed_dim) 
        
        
        self.q_attn = nn.Linear(self.embed_dim, self.edit_channel_width)
        self.k_attn = nn.Linear(self.embed_dim, self.edit_channel_width)
        self.v_attn = nn.Linear(self.embed_dim, self.edit_channel_width)
        self.out_proj = nn.Linear(self.edit_channel_width, self.embed_dim) 

    def _split_heads(self, x):
        """Split the last dimension into (num_heads, head_dim)."""
        new_shape = x.size()[:-1] + (self.num_editing_heads, self.head_dim)
        return x.view(*new_shape)
    
    def _new_reverse_attn(self, query, key, value, attention_mask=None, head_mask=None):
        # Assume that we are doing softmax attention

        # Project and split the query, key, value tensors
        split_query = self._split_heads(query)  
        split_key = self._split_heads(key)
        split_value = self._split_heads(value)
        
        #Double-application (is this actually good/better for some reason?)
        #self._split_heads(self.q_attn(query))
        #self._split_heads(self.k_attn(key))
        #self._split_heads(self.v_attn(value))

        if split_query.dim() != 4:
            print("Error: Expected query to be 4D tensor, but got something else!")
        if split_key.dim() != 3:
            print("Error: Expected key to be 3D tensor, but got something else!")
        if split_value.dim() != 3:
            print("Error: Expected value to be 3D tensor, but got something else!")

        # Query should be shaped as (batch_index, sequence_index, head_index, head_dim)
        # Key and value should be shaped as (batch_index, head_index, head_dim)
    
        KQ_weights = torch.matmul(split_query.permute(0,2,1,3),split_key.unsqueeze(-1)).squeeze(-1)

        # Then we take the softmax within the positional divisions
        softmaxed_weights = nn.functional.softmax(KQ_weights, dim=-1)
        
        # Adjusting value selection for head dimension
        attn_output = torch.matmul(softmaxed_weights.unsqueeze(-1), split_value.unsqueeze(-2))

        #combine heads: change 50, 8, 104, 96 to 50, 104, 768
        #first, permute
        attn_output = attn_output.permute(0,2,1,3)
        #combin heads x head_dims
        attn_output = attn_output.reshape(-1,attn_output.size(1),attn_output.size(2)*attn_output.size(3))
        # now project back
        projected_output = self.out_proj(attn_output)
    
        return projected_output, softmaxed_weights

    def _reverse_attn(self, query, key, value, attention_mask=None, head_mask=None):

        if key.dim() == 4:
            K_reduced = key[
                :, :, -1, :
            ]  # R# Check: that the second dimension of K is only a single element when we have batching
            KQ_weights = torch.bmm(K_reduced, query.transpose(1, 2))
            logistic_weights = torch.atan(KQ_weights)
            attn_output = torch.bmm(
                logistic_weights.transpose(1, 2), value[:, :, -1, :] #we take the editor output only over the final token position
            )

        if key.dim() == 3:
            QK_weights = torch.matmul(query, key.transpose(-1, -2))
            logistic_weights = torch.atan(QK_weights)
            attn_output = torch.matmul(logistic_weights, value)

        return attn_output, logistic_weights


    def forward(
        self,
        editor_hidden_states,
        target_hidden_states,
        attention_mask=None,
        output_attentions=False,
    ):

        # Here, the query is the target hidden encoder, the key is the editor, and the value is the editor
        query = self.q_attn(target_hidden_states)
        if editor_hidden_states.dim() == 3:
            key = self.k_attn(
                # I don't quite understand why sometimes editor_hidden_states is 4 dimensional, sometimes 3
                #seems like it's sometimes 20, 1, 4, 768 and sometimes 20, 4, 768. what gives?
                editor_hidden_states[:, -1, :]
            )  # Pull only the final token position
            value = self.v_attn(
                # [:, 0, :1, :]
                editor_hidden_states[:, -1, :]
            )  # Pull only the final token position

        if editor_hidden_states.dim() == 4:
            key = self.k_attn(
                editor_hidden_states[:, 0, -1, :]
            )  # Pull only the final token position
            value = self.v_attn(
                # [:, 0, :1, :]
                editor_hidden_states[:, 0, -1, :]
            )  # Pull only the final token position

        attn_output, attn_weights = self._new_reverse_attn(query, key, value)

        if output_attentions:
            return attn_output, attn_weights
        else:
            return attn_output

# %%
import types
from typing import Optional, Tuple, Union


def new_forward(
    self,
    input_ids: Optional[torch.LongTensor] = None,
    past_key_values: Optional[Tuple[Tuple[torch.Tensor]]] = None,
    attention_mask: Optional[torch.FloatTensor] = None,
    token_type_ids: Optional[torch.LongTensor] = None,
    position_ids: Optional[torch.LongTensor] = None,
    head_mask: Optional[torch.FloatTensor] = None,
    inputs_embeds: Optional[torch.FloatTensor] = None,
    encoder_hidden_states: Optional[torch.Tensor] = None,
    encoder_attention_mask: Optional[torch.FloatTensor] = None,
    # labels: Optional[torch.LongTensor] = None,
    use_cache: Optional[bool] = None,
    output_attentions: Optional[bool] = None,
    output_hidden_states: Optional[bool] = None,
    return_dict: Optional[bool] = None,
) -> Union[Tuple]:
    r"""
    labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
        Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
        `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
        are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
    """

    transformer_outputs = self.transformer(
        input_ids,
        past_key_values=past_key_values,
        attention_mask=attention_mask,
        token_type_ids=token_type_ids,
        position_ids=position_ids,
        head_mask=head_mask,
        inputs_embeds=inputs_embeds,
        encoder_hidden_states=encoder_hidden_states,
        encoder_attention_mask=encoder_attention_mask,
        use_cache=use_cache,
        output_attentions=output_attentions,
        output_hidden_states=output_hidden_states,
        return_dict=return_dict,
    )
    hidden_states = transformer_outputs[0]

    # Set device for model parallelism
    if self.model_parallel:
        torch.cuda.set_device(self.transformer.first_device)
        hidden_states = hidden_states.to(self.lm_head.weight.device)

    # lm_logits = self.lm_head(hidden_states)
    reverse_attention_output = self.lm_head(
        hidden_states, encoder_hidden_states, output_attentions=output_attentions
    )

    return reverse_attention_output

# %%
def replace_linear_final_layer_with_bespoke_reverse_attention(model):
    model.lm_head = Editor_Attention(config=model.config)
    model.forward = new_forward.__get__(model, GPT2LMHeadModel)
    return

# %%
@contextlib.contextmanager
def add_fwd_hooks(module_hooks):
    """
    Context manager for temporarily adding forward hooks to a model.

    Parameters
    ----------
    module_hooks
        A list of pairs: (module, fnc) The function will be registered as a
            forward hook on the module
    """
    try:
        handles = []
        for mod, hk in module_hooks:
            handles.append(mod.register_forward_hook(hk))
        yield
    finally:
        for h in handles:
            h.remove()

# %%
def assign_layer_indices(model):
    """
    Assigns a custom attribute 'layer_index' to each transformer layer in the GPT-2 model.
    This function iterates over the transformer blocks and assigns an index to each.
    """
    model.transformer.wte.layer_index = 0
    for i, layer in enumerate(model.transformer.h):
        layer.layer_index = i + 1


# Usage:
# assign_layer_indices(target_model)

# %%
def concat_and_pad(A, B):
    batch_size, n_tokens_A = A.size()
    n_tokens_B = B.size(1)

    #Find the lengths in A and B
    lengths_A = torch.sum(A != 50256, dim=1)
    lengths_B = torch.sum(B != 50256, dim=1)

    #iniitalize empty tensor
    result = torch.full((batch_size, max(lengths_A + lengths_B),), 50256)

    #Concatenate A[i] and B[i] a
    for i in range(batch_size):
        result[i, : lengths_A[i]] = A[i, : lengths_A[i]]
        result[i, lengths_A[i] : lengths_A[i] + lengths_B[i]] = B[i, : lengths_B[i]]

    # # Concatenate A and B along dimension 1
    # concatenated = torch.cat((A, B), dim=1)
    
    # # Find the number of non-zero elements in each row of concatenated tensor
    # lengths = torch.sum(concatenated != 50256, dim=1)
    
    # # Create a mask to identify the non-zero elements in concatenated tensor
    # mask = torch.arange(n_tokens_A + n_tokens_B).expand(batch_size, n_tokens_A + n_tokens_B) < lengths.unsqueeze(1)
    
    # # Create a new tensor with the same shape as concatenated tensor
    # result = torch.full_like(concatenated, 50256)
    
    # # Move the non-zero elements to the left and zero elements to the right
    # result[mask] = concatenated[mask]

    return result

# %%
def check_nan_gradients(model):
    for name, param in model.named_parameters():
        if param.grad is not None and torch.isnan(param.grad).any():
            print(f"NaN values found in gradient of parameter: {name}")
            return True
    return False

# %%
#@torch.compile #Apparently this fails when used inside jupyter notebooks but is fine if i make dedicated scripts
class EditorHypernetwork(nn.Module):
    # Separating the editor config file, from its base model's configurations
    def __init__(self,         
        num_editing_heads=32,
        edit_channel_width=768, #controls dimensionality given to attention heads in the last layer of the editor
        use_layerwise_embeddings=True,
        chop_editor_at_layer = None,
        edit_dampening_factor=.001,#tuning parameter to help the edits not be initialized too large
        kill_token_zero = False, #multiplies edits to token pos zero by zero
        ):

        super().__init__()

        # Construct Editor Model
        # Load the configuration from the YAML file
        # with open(editor_yaml_file_path, 'r') as file:
        #     self.config = yaml.safe_load(file)
        self.editor_model = GPT2LMHeadModel.from_pretrained(
            "gpt2"
        ).cuda().eval()  # have recently added .cuda() so it uses the gpu

        # Add cross-attention to each layer
        self.editor_model.config.add_cross_attention = True
        self.editor_model.config.num_editing_heads = num_editing_heads
        self.editor_model.config.chop_layer = chop_editor_at_layer
        self.editor_model.config.kill_token_zero = kill_token_zero
        self.editor_model.config.edit_channel_width = edit_channel_width
        
        if chop_editor_at_layer is None:
            chop_editor_at_layer = 12

        for i in range(chop_editor_at_layer):
            add_cross_attention_to_layer(
                self.editor_model.transformer.h[i], self.editor_model.config
            )
        
        #Delete extra layers beyond the chop_layer
        self.editor_model.transformer.h = self.editor_model.transformer.h[:chop_editor_at_layer]

        # Replace the final linear layer with special reverse attention output
        self.editor_model.lm_head = Editor_Attention(config=self.editor_model.config)
        self.editor_model.forward = new_forward.__get__(
            self.editor_model, GPT2LMHeadModel
        )
        self.editor_model.cuda()

        # Construct Target Model
        self.target_model = transformers.AutoModelForCausalLM.from_pretrained(
            "gpt2"
        ).cuda().eval()
        for param in self.target_model.parameters():
            param.requires_grad = False
        assign_layer_indices(self.target_model)

        self.target_model.cuda()

        # Add module for layerwise embeddings
        if use_layerwise_embeddings:
            self.use_layerwise_embeddings = True
            self.layerwise_embeddings = torch.randn(13, 768, requires_grad=True).cuda()
        else:
            self.use_layerwise_embeddings = False
            self.layerwise_embeddings = 0

        self.edit_dampening_factor = edit_dampening_factor

        self.residual_cache = None
        self.opt = None
        self.lossfn = None
        self.lam = None
        self.penalty_loss= None
        self.training_loss = None

    # Gets the hidden states from the target model, if necessary
    def run_target_model_for_encoded_hidden_states(self, target_ids):
        with torch.no_grad():
            outputs = self.target_model(target_ids, output_hidden_states=True)
            hidden_states = outputs.hidden_states
            return hidden_states

    def forward(
        self,
        editor_input_ids,
        target_input_ids,
        target_hidden_states=None,
        output_target_hidden_states=False,
        output_edited_hidden_states=False,
        output_edit_vectors=False,
        output_editor_attention=False,
        stop_editing_index=None,
        batch_edit_vectors=None,
    ):

        # Run target model for encoded hidden states
        if target_hidden_states is None:
            target_hidden_states = torch.stack(
                self.run_target_model_for_encoded_hidden_states(
                    target_input_ids.to("cuda")
                ), #seems to break while we are passing thru batch_size=1; the last (12th =) has different dimensions
                dim=2,
            )
        # dimensions of target_hidden_states:
        # batch_size, token_sequence_length, num_layers = 13, resid_width = 768

        # If we are stopping editing at stop_editing_index, then we eliminate target_hidden_states beyond that index
        if stop_editing_index is not None:
            target_hidden_states = target_hidden_states[
                :, :stop_editing_index, :, :
            ].clone()

        # Normalize along the last dimension
        normalization_factors = target_hidden_states.norm(dim=-1, keepdim=True)
        target_hidden_states = target_hidden_states / normalization_factors

        # Error catching:
        if batch_edit_vectors is not None:
            if output_edit_vectors or output_editor_attention:
                return "Error: Inputting your own batch_edit_vectors means the model does not construct the outputs you are requesting"

        # Run editor model, get edit vectors
        if batch_edit_vectors is None:
            if self.use_layerwise_embeddings:
                # Now, add in the layerwise embeddings
                embedded_hidden_states = target_hidden_states + self.layerwise_embeddings[None, None, :, :]

                collapsed_target_hidden_states = embedded_hidden_states.reshape(
                    target_hidden_states.shape[0],
                    target_hidden_states.shape[1] * target_hidden_states.shape[2],
                    target_hidden_states.shape[3],
                )
            else:
                collapsed_target_hidden_states = target_hidden_states.reshape(
                    target_hidden_states.shape[0],
                    target_hidden_states.shape[1] * target_hidden_states.shape[2],
                    target_hidden_states.shape[3],
                )
            
            editor_output = self.editor_model(
                editor_input_ids.to("cuda"),
                encoder_hidden_states=collapsed_target_hidden_states,
                output_attentions=output_editor_attention,
            )
            # Multiply the outputs by normalization factors
            if output_editor_attention:
                temp_edit_vectors = editor_output[0]
                # Might want to reshape this too but whatever
                batch_editor_attention = editor_output[1]
            else:
                temp_edit_vectors = editor_output
            
            #Renormalize to the scale of the target hidden states
            #and reshape to proper dimensions
            batch_edit_vectors = self.edit_dampening_factor * normalization_factors * temp_edit_vectors.reshape(
                    temp_edit_vectors.shape[0], stop_editing_index, 13, 768
                )
            
        # If we are stopping editing at stop_editing_index,
        # this pads batch_edit_vectors with 0's to the right of the edited positions
        if stop_editing_index is not None:
            batch_edit_vectors = torch.cat(
                (
                    batch_edit_vectors,
                    torch.zeros(
                        batch_edit_vectors.shape[0],
                        target_input_ids.shape[1] - stop_editing_index,
                        13,
                        768,
                    ),
                ),
                dim=1,
            )

        # Run target model with edit vectors. This adds the edit vectors to the given hidden state at the specified batch index, position, and layer
        def edit_add(module, input, output):
            layer_index = module.layer_index
            output[0][:] = output[0] + batch_edit_vectors[:, :, layer_index, :]
            if self.editor_model.config.kill_token_zero == True:
                output[0][:, 0, :] = 0

        def embedding_edit_add(module, input, output):
            output[:] = output + batch_edit_vectors[:, :, 0, :]
            if self.editor_model.config.kill_token_zero == True:
                output[:, 0, :] = 0

        # Now editing the target model
        hooks1 = [(self.target_model.transformer.wte, embedding_edit_add)]
        hooks2 = [(self.target_model.transformer.h[L], edit_add) for L in range(12)]
        hooks = hooks1 + hooks2
        with add_fwd_hooks(hooks):
            # THIS IS THE LINE WHERE THE MODEL IS CALLED (AND THE EDITOR IS CALLED AT
            # THE END OF `layer` AS A SIDE EFFECT)
            target_result = self.target_model(
                target_input_ids.to("cuda"),
                output_hidden_states=output_edited_hidden_states,
            )

        logits = target_result.logits

        output = {}
        output["logits"] = logits
        if output_target_hidden_states:
            output["target_hidden_states"] = (
                target_hidden_states * normalization_factors
            )
        if output_edited_hidden_states:
            output["edited_hidden_states"] = target_result.hidden_states
        if output_edit_vectors:
            output["edit_vectors"] = batch_edit_vectors
        if output_editor_attention:
            output["editor_attention"] = batch_editor_attention
        return output

    # Generate text using the target model, with a new edit application at every step.
    # This is a very slow way to generate text.
    # If you only want to edit first k tokens, use the forward pass instead with stop_editing_index = k
    def inspect_batch_prediction_ouptuts(self, batch):
        with torch.no_grad():
            batch_size = len(batch["tokenized_first_sentence"])
            self.editor_inputs = batch["tokenized_first_sentence"][i].unsqueeze(0)
            self.target_inputs = batch["tokenized_next_50_tokens"][i].unsqueeze(0)
            self.prediction = self.forward(
                self.editor_inputs,
                self.target_inputs,
                stop_editing_index=stop_editing_index,
                output_target_hidden_states=False,
                output_edited_hidden_states=False,
                output_edit_vectors=False,
                output_editor_attention=False,
            )
            #compute most likely tokens from the logits
            predicted_ids = [torch.argmax(pred, dim=-1) for pred in self.prediction["logits"]]
            #convert the token ids to strings
            predicted_strings = [tokenizer.decode(pred) for pred in predicted_ids]
            return predicted_strings

    def evaluate_KL_test_loss_nogradient(self,dataloader, f_data_to_soft_labels = None, stop_editing_index=8):
        with torch.no_grad():
            sum_weighted_losses = 0.0
            total_samples = 0
            for batch in dataloader:
                current_batch_size = len(batch["tokenized_first_sentence"])
                self.editor_inputs = batch["tokenized_first_sentence"].squeeze(1)
                self.target_inputs = batch["tokenized_next_50_tokens"].squeeze(1)
                self.prediction = self.forward( #check the batch size
                    self.editor_inputs,
                    self.target_inputs,
                    stop_editing_index=stop_editing_index
                )
                log_prob_predictions = torch.nn.functional.log_softmax(
                    self.prediction["logits"][
                        :, stop_editing_index:, :
                    ].reshape(-1, 50257),
                    dim=1,
                )
                # Now we must compute the soft labels!
                # join the last 50 tokens to the editor inputs
                soft_labels = f_data_to_soft_labels(
                    batch["tokenized_first_sentence"],
                    batch["tokenized_next_50_tokens"],
                    num_predictions_max=50
                )
                mask = (batch["tokenized_next_50_tokens"] != 50256).reshape(-1)
                self.loss = torch.nn.functional.kl_div(log_prob_predictions[mask,:], soft_labels[mask,:], reduction = 'batchmean')
                # Weight the loss by current batch size and update the sum of weighted losses
                sum_weighted_losses += self.loss.item() * current_batch_size
                total_samples += current_batch_size
            weighted_average_loss = sum_weighted_losses / total_samples
        return weighted_average_loss

    def evaluate_crossentropy_test_loss_nogradient(self,dataloader, stop_editing_index=8):
        with torch.no_grad():
            sum_weighted_losses = 0.0
            total_samples = 0
            for batch in dataloader:
                #current_batch_size = len(batch["tokenized_first_sentence"])
                self.editor_inputs = batch["tokenized_first_sentence"].squeeze(1)
                self.target_inputs = batch["tokenized_next_50_tokens"].squeeze(1)
                self.prediction = self.forward( #check the batch size
                    self.editor_inputs,
                    self.target_inputs,
                    stop_editing_index=stop_editing_index
                )
                log_prob_predictions = torch.nn.functional.log_softmax(
                    self.prediction["logits"][
                        :, stop_editing_index:, :
                    ].reshape(-1, 50257),
                    dim=1,
                )

                # Create a mask to exclude padded tokens
                target_labels = self.target_inputs[:, stop_editing_index:].reshape(-1)
                mask = (target_labels != 50256)  # Assuming padded tokens are represented by 0

                # Compute the cross-entropy loss with masking
                criterion = torch.nn.CrossEntropyLoss(reduction='none')
                loss = criterion(log_prob_predictions, target_labels)
                current_mask_sum = mask.sum()
                loss = (loss * mask).sum() / current_mask_sum

                # Weight the loss by current batch size and update the sum of weighted losses
                sum_weighted_losses += loss * current_mask_sum
                total_tokens += curr_mask_sum
            weighted_average_loss = sum_weighted_losses / total_tokens
        return weighted_average_loss

    def train(
        self,
        train_loader,
        test_loader=None,
        stop_editing_index=8,
        epochs=1,
        KL_divergence_loss=False,
        lam = 0, #20000
        lam_testing_penalty = 0, #100000
        f_data_to_soft_labels=None,
        checkpoint_interval=60, #save checkpoint every 60 minutes
    ):
        self.opt = optim.AdamW(self.parameters(), lr= lr, weight_decay=.01) #usually: lr = 5e-5. 1e-3 worked well!

        if KL_divergence_loss:
            self.lossfn = nn.KLDivLoss(reduction = 'batchmean')
        else:
            self.lossfn = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            # Create a tqdm progress bar
            with tqdm(
                total=len(train_loader), desc=f"Epoch {epoch + 1}/{epochs}", unit="batch"
            ) as pbar:
                num_datapoints_in_epoch=0
                epoch_train_loss = 0
                epoch_gradient_norm = 0
                # Train loop
                batch_index = -1 #index of first batch will be 0

                for batch in train_loader: #not sure what this does for fractional batches. meh whatev
                    batch_index += 1
                    self.batch = batch
                    current_batch_size = len(batch["tokenized_next_50_tokens"])
                    num_datapoints_in_epoch += current_batch_size
                    self.opt.zero_grad()

                    # Forward pass
                    self.prediction = self.forward(
                        batch["tokenized_first_sentence"],
                        batch["tokenized_next_50_tokens"],
                        stop_editing_index=stop_editing_index,
                        output_target_hidden_states=True,
                        output_edited_hidden_states=True,
                        output_edit_vectors=True,
                    )

                    # Compute the penalty (edit size relative to the hidden state)
                    self.lam = lam
                    edit_ratio = self.prediction['edit_vectors'].norm(dim=-1)[:,:stop_editing_index,:]/self.prediction['target_hidden_states'].norm(dim=-1)
                    self.per_datapoint_penalty_loss = self.lam * torch.sum(edit_ratio,dim=[1,2])
                    self.penalty_loss = torch.mean(self.per_datapoint_penalty_loss)
                    
                    # Compute the data loss
                    if KL_divergence_loss:
                        log_prob_predictions = torch.nn.functional.log_softmax(
                            self.prediction["logits"][:, :, :
                            ].reshape(-1, 50257),
                            dim=1,
                            )
                        # Now we must compute the soft labels! This is outsourced to the user-provided function, teacher_model
                        self.soft_labels = f_data_to_soft_labels(
                            batch["tokenized_first_sentence"],
                            batch["tokenized_next_50_tokens"],
                            num_predictions_max=50
                        )
                        #check that the mask makes sense!
                        mask = (batch["tokenized_next_50_tokens"] != 50256).reshape(-1)
                        self.prediction_loss = self.lossfn(log_prob_predictions[mask, :], self.soft_labels[mask,:])
                        #NOTE: currently I am letting the loss predict on tokens inside the editing window
                        #I didn't do this in the previous testing! Nor is it the case in crossentropy
                    
                    else: 
                        log_prob_predictions = torch.nn.functional.log_softmax(
                            self.prediction["logits"][:, stop_editing_index:, :
                            ].reshape(-1, 50257),
                            dim=1,
                            )
                        # Create a mask to exclude padded tokens
                        #NOTE: here we are disallowing prediction on the first stop_editing_index tokens. 
                        #Code is currently formatted such that this is not the case for KL
                        target_labels = batch["tokenized_next_50_tokens"][:, stop_editing_index:].reshape(-1)
                        mask = (target_labels != 50256)
                        # Compute the cross-entropy loss with masking
                        criterion = torch.nn.CrossEntropyLoss(reduction='none')
                        loss = criterion(log_prob_predictions, target_labels.long())
                        current_mask_sum = mask.sum()
                        self.prediction_loss = (loss * mask).sum() / current_mask_sum

                    

                    # Compute the total loss and backpropagate 
                    self.training_loss = self.prediction_loss + self.penalty_loss
                    self.training_loss.backward()
                    nn.utils.clip_grad_norm_(self.parameters(), max_grad_clip) #just implemented this! dunno if a cap of 1 to large, so I'm messing with reducing it

                    #Check for nan gradients 
                    # if check_nan_gradients(self):                   
                    #     break

                    #Backwards step
                    self.opt.step()

                    #metrics
                    epoch_train_loss += self.training_loss.item()*current_batch_size
                    gradients = [p.grad.view(-1) for p in self.parameters() if p.grad is not None]
                    all_gradients = torch.cat(gradients)
                    gradient_norm = torch.norm(all_gradients).item()
                    epoch_gradient_norm += gradient_norm*current_batch_size
                    wandb.log({"train_batch_total_loss": self.training_loss.item(),
                               "train_batch_prediction_loss": self.prediction_loss.item(),
                                "train_batch_penalty_loss": self.penalty_loss,
                                "train_batch_gradient_norm": gradient_norm,
                               })

                    # Update progress bar
                    pbar.update(1) #note: this was incorrectly displaying before!

                    # Check if it's time to save a checkpoint
                    current_time = time.time()
                    # first loop initialization
                    if batch_index == 0 and epoch == 0:
                        last_checkpoint_time = -100000

                    if current_time - last_checkpoint_time >= checkpoint_interval * 60:
                        # Save the checkpoint
                        torch.save(self.state_dict(), f"checkpoint_epoch_{epoch}_batch_{pbar.n}.pt")
                        last_checkpoint_time = current_time
                        #announce checkpoint save
                        print("Checkpoint saved at epoch", epoch, "batch", pbar.n)
                    
                ####END BATCH LOOP   
                #########################
            
                #epoch loss
                # epoch_test_prediction_loss = self.evaluate_crossentropy_test_loss_nogradient(
                #     test_loader,
                #     stop_editing_index, 
                #     batch_size
                # )
                if KL_divergence_loss:
                    epoch_test_prediction_loss = self.evaluate_KL_test_loss_nogradient(
                        dataloader=test_loader,
                        f_data_to_soft_labels= f_data_to_soft_labels, 
                        stop_editing_index=stop_editing_index, 
                    )
                
            
                # # Calculate and accumulate gradient norm for logging
                # gradients = [p.grad.view(-1) for p in self.parameters() if p.grad is not None]
                # all_gradients = torch.cat(gradients)
                # gradient_norm = torch.norm(all_gradients).item()
                # epoch_gradient_norm += gradient_norm

                wandb.log({"epoch_train_total_loss": epoch_train_loss /num_datapoints_in_epoch,
                            "test_prediction_loss": epoch_test_prediction_loss,
                            "gradient_norm": epoch_gradient_norm /num_datapoints_in_epoch
                            })  
            # Save the final model
            torch.save(self, "final_model.pt")

# %%
#####DIVISION!
#DATASET CONSTRUCTION BELOW

# %%
tokenizer = transformers.GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token
model = transformers.GPT2LMHeadModel.from_pretrained("gpt2")
for param in model.parameters():
    param.requires_grad = False
model.config.pad_token_id = model.config.eos_token_id

# %%
# # Read the CSV file into a DataFrame
import pandas as pd
import os
from datasets import Dataset
from transformers import GPT2Tokenizer
from torch.utils.data import DataLoader

csv_dir = 'wikipedia_three_sentences.csv'
dataframe_dir = 'wikipedia_df.pt'

def tokenize_followup(row):
    # Compose second_sentences and third_sentences
    followup_text = row['second_sentences'] + ' ' + row['third_sentences']
    
    # Select the first 500 characters
    followup_text = followup_text[:500]
    
    # Tokenize the followup text
    tokenized_followup = tokenizer.encode(followup_text)
    
    # Check if the resulting tokenized list is still less than 50 tokens
    if len(tokenized_followup) < 50:
        # Pad with token 50256 to reach a length of 50 tokens
        tokenized_followup = tokenized_followup + [50256] * (50 - len(tokenized_followup))
    
    return tokenized_followup


def create_dataframe_from_csv(csv_dir):
    df = pd.read_csv(csv_dir)

    # # Printng out examples of longest and shortest entries
    # # Iterate over each column
    # for column in df.columns:
    #     print(f"Column: {column}")
        
    #     # Find the 10 longest entries in the column
    #     longest_entries = df[column].astype(str).apply(len).nlargest(10)
    #     print("Longest entries:")
    #     for index, length in longest_entries.items():
    #         print(f"Length: {length}, Entry: {df.loc[index, column]}")
        
    #     # Find the 10 shortest entries in the column
    #     shortest_entries = df[column].astype(str).apply(len).nsmallest(10)
    #     print("Shortest entries:")
    #     for index, length in shortest_entries.items():
    #         print(f"Length: {length}, Entry: {df.loc[index, column]}")
        
    #     print()


    #Length of the dataframe to start
    # print(f"Length of dataframe: {len(df)}")
    # df.columns
    # Filter the dataset based on sentence length

    df['first_sentence_length'] = df['first_sentences'].apply(lambda x: len(x))
    df['second_sentence_length'] = df['second_sentences'].apply(lambda x: len(x))
    df['third_sentence_length'] = df['third_sentences'].apply(lambda x: len(x))

    df_filtered = df[
        (df['first_sentence_length'] >= 5) &
        (df['second_sentence_length'] >= 10) &
        (df['first_sentence_length'] <= 100)
    ]
    # print(f"Length of filtered dataframe: {len(df_filtered)}")

    from transformers import GPT2Tokenizer
    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
    df_filtered['tokenized_first_sentence'] = df_filtered.apply(lambda row: tokenizer.encode(row['first_sentences'], add_special_tokens=False), axis=1)
    df_filtered['tokenized_next_50_tokens'] = df_filtered.apply(lambda row: tokenize_followup(row), axis = 1)
    return df_filtered

if os.path.exists('wikipedia_df.pt'):
    df = pd.read_pickle('wikipedia_df.pt')
else: #save dataset
    df = create_dataframe_from_csv(csv_dir)
    df.to_pickle('wikipedia_df.pt')

# %%
def collate_fn(batch):
    res = {}
    for k in batch[0].keys():
        if k != '__index_level_0__':
            els = [x[k] for x in batch]
            max_length = max(len(x) for x in els)
            if k == 'tokenized_next_50_tokens':
                max_length = 50
                for i in range(len(els)):
                    if len(els[i]) > 50:
                        els[i] = els[i][:50]
            # for x in els:
            #     x += [0] * (max_length - len(x))
            #res[k] = torch.cat([y , torch.zeros(max_length - len(x))],for y in els)
            #res[k]=torch.tensor([x + [0] * (max_length( - len(x)) for x in els], dtype=torch.long)
            res[k]=torch.stack([ torch.cat((torch.tensor(x),torch.full((max_length - len(x),),50256))) for x in els]).int()
    return res

# %%
#Convert 2 columns to Dataset and train-test split
dataset = Dataset.from_pandas(df[['tokenized_first_sentence', 'tokenized_next_50_tokens']]).shuffle(seed=42)
test_ratio = .08
temp = dataset.train_test_split(test_size=test_ratio,seed=42)
temp
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokenized_first_sentence', 'tokenized_next_50_tokens', '__index_level_0__'],
#         num_rows: 987633
#     })
#     test: Dataset({
#         features: ['tokenized_first_sentence', 'tokenized_next_50_tokens', '__index_level_0__'],
#         num_rows: 85882
#     })
# })

# %%
batch_size=32 #50 or so
data_loader = DataLoader(temp["train"], batch_size=batch_size, collate_fn = collate_fn)#batch_size, collate_fn=collate_fn)
test_data_loader = DataLoader(temp["test"], batch_size=batch_size, collate_fn = collate_fn)#batch_size, collate_fn=collate_fn)

# # Now you can iterate over data_loader in your training loop
# j=0
# for batch in data_loader:
#     j=j+1
# print(j)
# #Good! we have all the data now

# %%
dataset, data_loader.batch_size
# Out:
# (Dataset({
#      features: ['tokenized_first_sentence', 'tokenized_next_50_tokens', '__index_level_0__'],
#      num_rows: 1073515
#  }),
#  32)

# %%
data_loader

# %%
# for batch in data_loader:
#     temp = batch
#     break
# temp.keys()

# %%
# for batch in data_loader:
#     temp = batch
#     break
# # temp["tokenized_next_50_tokens"]

# %%
def f_data_to_soft_labels(A, B, num_predictions_max = 50):
    with torch.no_grad():
        # Compute number of nonzero elements in each row of A and B
        lengths_A = torch.sum(A != 50256, dim=1)
        lengths_B = torch.sum(B != 50256, dim=1)
        # Concatenate A and B along dimension 1
        data = concat_and_pad(A, B) 
        logits = model(data).logits
        predictions = torch.nn.functional.softmax(logits, dim=2)

        #Create an empty tensor to store the predictions
        shape=( len(lengths_A), num_predictions_max, 50257)
        hold_output = torch.full(shape, torch.nan)

        # Extract the predictions corresponding to B
        for i in range(len(lengths_A)):
            hold_output[i, :lengths_B[i], :] = predictions[i, lengths_A[i]:lengths_A[i] + lengths_B[i], :]

        return hold_output.reshape(-1, 50257) #returns

# %%
stop_editing_index = 8
hypernetwork = EditorHypernetwork(
    edit_dampening_factor = edit_dampening_factor, #1/10000, 
    use_layerwise_embeddings=False,
    num_editing_heads=num_editing_heads,
    edit_channel_width=editor_channel_width,
    chop_editor_at_layer=chop_layer,
)

# %%
i = 0
for batch in data_loader:
    if i == 18:
        temp = batch
        break
    i += 1
temp["tokenized_next_50_tokens"].shape
# Out:
# torch.Size([32, 50])

# %%
# #testing the forward pass on temp
# log_prob_predictions = torch.nn.functional.log_softmax(
#     hypernetwork.forward(
#         temp["tokenized_first_sentence"],
#         temp["tokenized_next_50_tokens"],
#         stop_editing_index=stop_editing_index,
#         output_target_hidden_states=True,
#         output_edited_hidden_states=True,
#         output_edit_vectors=True,
#     )["logits"][:, :, :].reshape(-1, 50257),
#     dim=1,
# )
# soft_labels = f_data_to_soft_labels(
#     temp["tokenized_first_sentence"],
#     temp["tokenized_next_50_tokens"],
#     num_predictions_max=50
# )
# mask = (temp["tokenized_next_50_tokens"] != 0).reshape(-1)
# torch.where(torch.isnan(soft_labels)[:,0] & mask)
# tokenizer.decode(temp["tokenized_next_50_tokens"].reshape(-1)[650:700])
# tokenizer.decode(temp["tokenized_next_50_tokens"][12])

# %%
#current problem: 1728/ 30864 
hypernetwork.train(
    train_loader=data_loader,
    test_loader=test_data_loader,
    stop_editing_index=stop_editing_index,
    epochs=200,
    lam = 0,#20000
    lam_testing_penalty = 0,
    KL_divergence_loss=True,
    f_data_to_soft_labels = f_data_to_soft_labels,
)
# Out:
# Epoch 1/200:   0%|          | 0/30864 [00:00<?, ?batch/s]We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# You may ignore this warning if your `pad_token_id` (50256) is identical to the `bos_token_id` (50256), `eos_token_id` (50256), or the `sep_token_id` (None), and your input is not padded.
# Epoch 1/200:   0%|          | 1/30864 [00:02<18:25:08,  2.15s/batch]
# Checkpoint saved at epoch 0 batch 1
# Epoch 1/200:   3%|▎         | 939/30864 [13:30<7:10:18,  1.16batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 #current problem: 1728/ 30864
# ----> 2 hypernetwork.train(
#       3     train_loader=data_loader,
#       4     test_loader=test_data_loader,
#       5     stop_editing_index=stop_editing_index,
#       6     epochs=200,
#       7     lam = 0,#20000
#       8     lam_testing_penalty = 0,
#       9     KL_divergence_loss=True,
#      10     f_data_to_soft_labels = f_data_to_soft_labels,
#      11 )
#
# Cell In[14], line 368, in EditorHypernetwork.train(self, train_loader, test_loader, stop_editing_index, epochs, KL_divergence_loss, lam, lam_testing_penalty, f_data_to_soft_labels, checkpoint_interval)
#     362 log_prob_predictions = torch.nn.functional.log_softmax(
#     363     self.prediction["logits"][:, :, :
#     364     ].reshape(-1, 50257),
#     365     dim=1,
#     366     )
#     367 # Now we must compute the soft labels! This is outsourced to the user-provided function, teacher_model
# --> 368 self.soft_labels = f_data_to_soft_labels(
#     369     batch["tokenized_first_sentence"],
#     370     batch["tokenized_next_50_tokens"],
#     371     num_predictions_max=50
#     372 )
#     373 #check that the mask makes sense!
#     374 mask = (batch["tokenized_next_50_tokens"] != 50256).reshape(-1)
#
# Cell In[25], line 7, in f_data_to_soft_labels(A, B, num_predictions_max)
#       5 lengths_B = torch.sum(B != 50256, dim=1)
#       6 # Concatenate A and B along dimension 1
# ----> 7 data = concat_and_pad(A, B)
#       8 logits = model(data).logits
#       9 predictions = torch.nn.functional.softmax(logits, dim=2)
#
# Cell In[12], line 10, in concat_and_pad(A, B)
#       7 lengths_B = torch.sum(B != 50256, dim=1)
#       9 #iniitalize empty tensor
# ---> 10 result = torch.full((batch_size, max(lengths_A + lengths_B),), 50256)
#      12 #Concatenate A[i] and B[i] a
#      13 for i in range(batch_size):
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/_device.py:77, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#      75 if func in _device_constructors() and kwargs.get('device') is None:
#      76     kwargs['device'] = self.device
# ---> 77 return func(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# Let's now look at some outputs!

# %%
hypernetwork = EditorHypernetwork(
    edit_dampening_factor = edit_dampening_factor, #1/10000, 
    use_layerwise_embeddings=False,
    num_editing_heads=num_editing_heads,
    edit_channel_width=editor_channel_width,
    chop_editor_at_layer=chop_layer, #currently set to 6 for current 8840.pt checkpoint
)
state_dict = torch.load("checkpoint_epoch_0_batch_8840.pt")
hypernetwork.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
data_loader

# %%
for batch in data_loader:
    temp = batch
    break
#hypernetwork.inspect_batch_prediction_ouptuts(temp)

# %%
get_batch_index = 0
for batch in test_data_loader:
    get_batch_index += 1
    if get_batch_index == 18:
        temp = batch
        result = hypernetwork.forward(
            editor_input_ids=batch["tokenized_first_sentence"],
            target_input_ids=batch["tokenized_next_50_tokens"],
            stop_editing_index=stopping_index,
            output_target_hidden_states=True,
            output_edited_hidden_states=True,
            output_edit_vectors=True,
            output_editor_attention=True,
        )
        break

# %%
#predicted_strings=hypernetwork.inspect_batch_prediction_ouptuts(temp)

# %%
y = 0
for i in df["tokenized_first_sentence"]:
    temp2 = i
    y = y + 1
    if(y ==100):
        break

#temp2


# TODO from Karel:
# run some ablations: what layer do we edit. What happens when we regularize l1 and l2 of the intervention?

# %%
# hypernetwork.evaluate_KL_test_loss_nogradient(data_loader, f_data_to_soft_labels, stop_editing_index=stop_editing_index)
# #hypernetwork.inspect_batch_prediction_ouptuts(temp)
result= hypernetwork.forward(
    editor_input_ids=temp["tokenized_first_sentence"],
    target_input_ids=temp["tokenized_next_50_tokens"],
    stop_editing_index=stopping_index,
    output_target_hidden_states=True,
    output_edited_hidden_states=True,
    output_edit_vectors=True,
    output_editor_attention=True,
)
#compute most likely tokens from the logits
predicted_ids = [torch.argmax(pred, dim=-1) for pred in result["logits"]]
#convert the token ids to strings
predicted_strings = [tokenizer.decode(pred) for pred in predicted_ids]

#Compute the most likely tokens from running gpt2 on the target_input_ids
gpt2_result = model(temp["tokenized_next_50_tokens"].cuda())
gpt2_predicted_ids = [torch.argmax(pred, dim=-1) for pred in gpt2_result["logits"]]

#add in also a gpt2 which has access to the first string
gpt2_full_result = model(concat_and_pad(temp["tokenized_first_sentence"],temp["tokenized_next_50_tokens"]).cuda())
gpt2_full_predicted_ids = [torch.argmax(pred, dim=-1) for pred in gpt2_full_result["logits"]]

#Note: thee is a possible "cheating" thing here, but it's not really being "trained to cheat" per se

# %%
#batch

# %%
# Out:
# tensor(10, device='cuda:0')

# %%
#compare against the actual strings from the batch
for i in range(len(predicted_strings)):
    print("Preceding string: ", tokenizer.decode(temp["tokenized_first_sentence"][i]))
    print("Actual string:    ", tokenizer.batch_decode(temp["tokenized_next_50_tokens"][i]))
    print("GPT2 full argmax:       ", tokenizer.batch_decode(gpt2_full_predicted_ids[i][torch.sum(temp["tokenized_first_sentence"][i] != 50256):]))
    print("Edited-Model argmax:    ", tokenizer.batch_decode(predicted_ids[i]))
    print("GPT2 target-only argmax:", tokenizer.batch_decode(gpt2_predicted_ids[i]))
    print("\n")
# Out:
# Preceding string:  Edmund Jenings was a Virginian politician.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['He', ' was', ' President', ' of', ' the', ' Council', ' of', ' Virginia', ' and', ' later', ' became', ' the', ' acting', ' governor', ' from', ' August', ' 23', ',', ' 17', '06', ',', ' to', ' June', ' 10', ',', ' 17', '10', '.', ' The', ' subject', ' continued', ' to', ' serve', ' on', ' His', ' Majesty', "'s", ' Council', ' of', ' Virginia', ' until', ' March', ' of', ' 17', '25', ',', ' just', ' prior', ' to', ' his']
# GPT2 full argmax:        [' was', ' a', ' of', ' the', ' United', ' of', ' the', ' in', ' was', ' Governor', ' Governor', ' Governor', ' Governor', ' of', ' 18', ' 18', ',', ' 18', '76', ' to', ' to', ' August', ' 30', ',', ' 17', '10', '.', ' He', ' first', ' of', ' to', ' be', ' as', ' the', ' Majesty', "'s", ' Cabinet', ' until', ' the', ' until', ' his', ' 17', ' 17', '11', '.', ' when', ' before', ' to', ' the', ' death', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' was', ' elected', ' of', ' the', ' United', ' of', ' the', ' from', ' was', ' President', ' Governor', ' Governor', ' Governor', ' of', ' 18', ' 18', ',', ' 18', '76', ' to', ' to', ' August', ' 30', ',', ' 17', '10', '.', ' He', ' first', ' of', ' to', ' be', ' as', ' the', ' Majesty', "'s", ' Cabinet', ' until', ' Virginia', ' until', ' his', ' 17', ' 17', '11', '.', ' when', ' before', ' to', ' the', ' death']
# GPT2 target-only argmax: [' is', ' a', ' of', ' the', ' United', ' of', ' Europe', ',', ' was', ' the', ' the', ' first', ' president', ' of', ' Virginia', ' to', ',', ' 18', '76', ' to', ' to', ' August', ' 30', ',', ' 17', '10', '.', ' He', ' first', ' of', ' to', ' be', ' as', ' the', ' Majesty', "'s", ' Cabinet', ' until', ' the', ' until', ' his', ' 17', ' 17', '11', ',', ' when', ' before', ' to', ' the', ' death']
#
#
# Preceding string:  Dieppe Park () is a park in Montreal, Quebec, Canada.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' is', ' at', ' the', ' eastern', ' tip', ' of', ' Cit', 'é', ' du', ' Hav', 're', ',', ' in', ' the', ' borough', ' of', ' ', ' V', 'ille', '-', 'Marie', '.', ' Between', ' 1992', ' and', ' 2017', ',', ' it', ' was', ' known', ' as', ' Par', 'c', ' de', ' la', ' Cit', 'é', '-', 'du', '-', 'H', 'av', 're', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' located', ' the', ' intersection', ' end', ' of', ' the', 'é', 'val', ' Qué', 're', ',', ' a', ' the', ' city', ' of', ' Saint', 'ét', 'ille', '-', 'de', ',', ' It', ' the', ' and', ' 1995', ',', ' it', ' was', ' the', ' as', ' the', 'c', ' des', ' la', ' V', 'é', ' du', 'de', '-', 'H', 'av', 're', '.', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' located', ' the', ' heart', ' end', ' of', ' the', 'rus', ' Blanc', ' Qué', 're', ',', ' a', ' the', ' heart', ' of', ' Saint', 'ét', 'ille', '-', 'de', ',', ' It', ' the', ' and', ' 1995', ',', ' the', ' was', ' the', ' as', ' the', 'c', ' de', ' la', ' V', 'é', ' du', 'V', '-', 'H', 'av', 're', '.', ' It', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' not', ' this', ' heart', ' end', ' of', ' the', 'rus', 'val', ' Qué', 're', ',', ' near', ' the', ' city', ' of', ' Saint', 'ét', 'ille', '-', 'de', ',', ' The', ' the', ' and', ' 1996', ',', ' the', ' was', ' the', ' as', ' the', 'c', ' de', ' la', ' V', 'é', ' du', 'du', '-', 'H', 'av', 're', '.', '\n', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Bold Springs is an unincorporated community in Walton County, Georgia, United States.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     [' It', ' is', ' located', ' around', ' Georgia', ' State', ' Route', ' 81', ' and', ' Bold', ' Springs', ' Road', '.', ' Walton', ' County', ' Parks', ' &', ' Recreation', ' operates', ' the', ' ', ' Bold', ' Springs', ' Park', ' in', ' the', ' community', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' located', ' in', ' the', "'s", ' University', ' 1', ' and', ' is', ' Springs', ' Road', '.', '\n', ' County', ' is', ' and', ' Recreation', ' is', ' a', ' park', '\xa0', ' Springs', ' Recreation', '.', ' the', ' area', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' located', ' in', ' the', "'s", ' University', ' 1', ' and', ' is', 'en', ' Road', '.', '\n', ' County', ' is', ' and', ' Recreation', ' is', ' a', ' park', '\xa0', ' Springs', ' Road', '.', ' the', ' area', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' in', ' the', "'s", ' University', ' 1', ' and', ' is', 'en', ' Road', '.', '\n', ' County', ' Sheriff', ' and', ' Recreation', ' is', ' the', ' park', '\xa0', ' Springs', ' Road', '.', ' the', ' area', ' of', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  The Enigma of Kaspar Hauser (; lit.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['Every', ' Man', ' for', ' Himself', ' and', ' God', ' Against', ' All', ')', ' is', ' a', ' 1974', ' West', ' German', ' drama', ' film', ' written', ' and', ' directed', ' by', ' Werner', ' Herz', 'og', ' and', ' starring', ' Bruno', ' Sch', 'le', 'instein', ' (', 'c', 'redited', ' as', ' Bruno', ' S', '.)', ' and', ' Walter', ' Lad', 'eng', 'ast', '.', ' The', ' film', ' closely', ' follows', ' the', ' real', ' story', ' of']
# GPT2 full argmax:        ['man', ' for', ' Himself', ')', ' His', ')', ' the', ' Evil', '\n', ' a', ' book', ' novel', ' Coast', ' film', ' about', ' directed', ' by', ' directed', ' by', ' Kas', ' Herz', 'og', '.', ' starring', ' Michael', ' Heller', 're', 'ic', '.', 'The', 'inem', ' with', ' the', ' Sch', '.', ' and', ' Michael', ' Matth', 'ner', 'a', ' (', ' The', ' film', ' was', ' resembles', ' the', ' life', '-', ' of', ' a', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' man', ' of', ' All', ')', ' His', ' for', ' the', ')', '\n', ' a', ' book', ' book', ' Coast', ' film', ' about', ' directed', ' by', ' directed', ' by', ' the', ' Herz', 'og', '.', ' starring', ' Michael', ' Heller', 're', 'ic', '.', 'The', 'inem', ' with', ' "', ' Sch', '.', ' and', ' Michael', ' Matth', 'ner', 'a', ' (', ' The', ' film', ' was', ' resembles', ' the', ' life', '-', ' of', ' the']
# GPT2 target-only argmax: [',', "'s", ' Himself', '"', ' for', ' for', ' the', ' Evil', '\n', ' a', ' great', ' book', ' Coast', ' film', ' about', ' directed', ' by', ' directed', ' by', ' the', ' Herz', 'og', '.', ' starring', ' Michael', ' Heller', 're', 'ic', '.', 'The', 'redited', ' with', ' the', ' Sch', '.', ' and', ' Michael', ' Matth', 'ner', 'a', ' (', ' The', ' film', ' was', ' follows', ' the', ' life', '-', ' of', ' the']
#
#
# Preceding string:  Canadians, formerly known as BV Landlust, was a Dutch basketball club from Amsterdam.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' team', ' was', ' one', ' of', ' the', ' original', ' twelve', ' teams', ' in', ' the', ' E', 'red', 'iv', 'is', 'ie', '.', ' The', ' team', ' was', ' founded', ' in', ' 1952', ' and', ' played', ' in', ' the', ' E', 'red', 'iv', 'is', 'ie', ' for', ' 42', ' seasons', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' club', ' was', ' founded', ' of', ' the', ' first', ' Dutch', ' teams', ' to', ' the', ' Dutch', 'red', 'iv', 'is', 'ie', ',', ' The', ' team', ' was', ' formed', ' in', ' 18', ' by', ' was', ' in', ' the', ' Dutch', 'red', 'iv', 'is', 'ie', ' until', ' the', ' years', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' team', ' was', ' founded', ' of', ' the', ' first', ' members', ' teams', ' in', ' the', ' league', 'red', 'iv', 'is', 'ie', '.', ' The', ' team', ' was', ' formed', ' in', ' 18', ' by', ' was', ' in', ' the', ' E', 'red', 'iv', 'is', 'ie', ' until', ' the', ' years', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['\n', ' is', ' able', ' of', ' the', ' first', ' members', ' teams', ' to', ' the', ' world', '3', 'iv', 'is', 'ie', ',', '\n', ' team', ' was', ' formed', ' in', ' 18', ' by', ' was', ' in', ' the', ' E', 'red', 'iv', 'is', 'ie', ' for', ' the', ' years', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  The Bringhi or Brengi river is a river in Anantnag, Jammu and Kashmir, India.<|endoftext|><|endoftext|>
# Actual string:     ['It', ' flows', ' for', ' a', ' total', ' of', ' 30', 'km', '(', '18', '.', '64', 'mi', ')', ' before', ' feeding', ' J', 'hel', 'um', ' River', ' at', ' H', 'aji', ' Dan', 'ter', ',', ' An', 'ant', 'n', 'ag', '.', ' It', ' is', ' formed', ' by', ' the', ' conf', 'luence', ' of', ' three', ' streams', ' Now', 'b', 'ugh', ' stream', ',', ' Ah', 'lan', ' Gad', 'ol']
# GPT2 full argmax:        [' is', ' through', ' about', ' short', ' of', ' about', ' km', ' from', '5', ' miles', '5', ' miles', ')', ' and', ' it', ' into', 'ammu', 'um', ',', '.', ' the', 'ary', ' Ali', 'ak', '.', ' J', 'ant', 'n', 'ag', '.', ' It', ' is', ' a', ' by', ' the', ' river', 'luence', ' of', ' the', ' rivers', ',', 'here', 'ari', ' and', ',', ' Now', 'lu', ' river', ' and', ' and', 'The', 'The']
# Edited-Model argmax:     [' is', ' from', ' over', ' total', ' of', ' about', ' km', ' and', '3', ' miles', '5', ' miles', ')', ' and', ' it', ' into', 'ammu', 'um', ',', '.', ' the', 'ary', ' Ali', 'ak', '.', ' which', 'and', 'n', 'ag', ',', ' It', ' is', ' a', ' by', ' the', ' river', 'luence', ' of', ' the', ' rivers', ',', 'here', ' and', ' and', ',', ' Now', 'im', ' stream', ' and', ' and']
# GPT2 target-only argmax: [' is', ' from', ' a', ' while', ' of', ' $', ' minutes', '.', '3', ' miles', '5', ' miles', ')', ' and', ' it', ' into', 'ell', 'um', ',', '.', ' the', 'ain', ' Ali', 'ak', '.', ' which', 'j', 'n', 'ag', ',', '\n', ' is', ' a', ' by', ' the', ' river', 'luence', ' of', ' the', ' rivers', ',', 'ak', ' and', ' and', ',', ' H', 'u', ' stream', ' and', ' and']
#
#
# Preceding string:  Henry J.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['Fin', 'kel', ' (', 'born', ' April', ' 20', ',', ' 1942', ')', ' is', ' an', ' American', ' basketball', ' player', ' whose', ' professional', ' career', ' lasted', ' from', ' 1966', ' to', ' 1975', '.', ' Selected', ' by', ' the', ' Los', ' Angeles', ' Lakers', ' in', ' second', ' round', ' of', ' the', ' 1966', ' NBA', ' draft', ' he', ' remained', ' with', ' the', ' team', ' through', ' 1966', '–', '67', ',', ' then', ' played', ' with']
# GPT2 full argmax:        ['ley', 'stein', '19', ' 18', ' 18', ',', ' 18', ')', ' is', ' a', ' American', ' actor', ' player', ' and', ' father', ' career', ' began', ' from', ' 1993', ' to', ' 1973', '.', ' He', ' by', ' the', ' Chicago', ' Angeles', ' Lakers', ' in', ' the', ' round', ' (', ' the', ' 1976', ' NBA', ' Draft', ',', ' was', ' with', ' the', ' Lakers', ' until', ' the', '-', '67', '.', ' playing', ' went', ' for', ' the', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     ['ner', 'stein', '19', ' 18', ' 18', ',', ' 18', ')', ' is', ' an', ' American', ' actor', ' player', ' and', ' father', ' career', ' began', ' from', ' 1993', '-', ' 1973', '.', ' He', ' by', ' the', ' Chicago', ' Angeles', ' Lakers', ' in', ' the', ' round', ' (', ' the', ' 1976', ' NBA', ' Draft', ',', ' was', ' with', ' the', ' Lakers', ' until', ' the', '-', '67', '.', ' playing', ' went', ' for', ' the']
# GPT2 target-only argmax: ['.', 'stein', 'R', ' 18', ' 18', ',', ' 1986', ')', ' is', ' an', ' American', ' actor', ' player', ' from', ' father', ' career', ' began', ' from', ' 1993', '-', ' 1973', '.', ' He', ' by', ' the', ' Chicago', ' Angeles', ' Lakers', ' in', ' the', ' round', ' (', ' the', ' 1976', ' NBA', ' Draft', ',', ' was', ' with', ' the', ' Lakers', ' until', ' the', '-', '67', '.', ' playing', ' went', ' for', ' the']
#
#
# Preceding string:  The Chiesa dell’Addolorata e del Ss.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['C', 'roc', 'if', 'is', 'so', ' or', ' (', 'Church', ' of', ' the', ' G', 'rieving', ' Mary', ' and', ' of', ' the', ' Holy', ' Cru', 'c', 'ifix', ')', ' ', ' is', ' a', ' Bar', 'o', 'que', '-', 'style', ' church', ' in', ' the', ' town', ' of', ' N', 'is', 'ce', 'mi', ',', ' in', ' the', ' Province', ' of', ' Cal', 'tan', 'iss', 'etta', ',', ' region', ' of']
# GPT2 full argmax:        ['.', 'od', 'ornia', ',', ',', 'ca', 'C', ' of', ' the', ' Holy', 'arter', ')', ')', ' the', ' the', ' Blessed', ' Mother', 'c', 'ifix', 'ion', '\n', '\xa0', ' a', ' very', 'o', 'que', ' church', 'style', ' chapel', ' in', ' the', ' city', ' of', ' Ch', 'antes', 'qu', ',', ',', ' in', ' the', ' province', ' of', ' the', 'ab', '.', 'ima', '.', ' in', ' of', ' the', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     ['.', 'od', 'ero', ',', ',', ' the', '1', ' of', ' the', ' Holy', 'ospels', ')', ')', ' the', ' the', ' Blessed', ' Mother', 'c', 'ifix', 'ion', ' of', '\xa0', ' the', ' Catholic', 'o', 'que', ',', 'style', ' funeral', '.', ' the', ' city', ' of', ' P', 'antes', 'io', ',', ',', ' in', ' the', ' province', ' of', ' the', 'ab', '.', 'ima', '.', ' in', ' of', ' the']
# GPT2 target-only argmax: ['.', 'od', 'ornia', ',', ',', ' the', '2', 'ill', ' England', ' Holy', 'ospels', ')', ')', ' the', ' the', ' Blessed', ' Ghost', 'c', 'ifix', 'ion', '\n', '\xa0', ' the', ' very', 'o', 'que', ' form', 'style', ' crucifix', '.', ' the', ' city', ' of', ' P', 'antes', 'ib', ',', ',', ' in', ' the', ' province', ' of', ' the', 'ab', '.', 'ima', '.', ' which', ' of', ' the']
#
#
# Preceding string:  Cricket has a considerably lower profile in Scotland than it has in neighbouring England.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['Scotland', ' is', ' not', ' one', ' of', ' the', ' twelve', ' leading', ' cricket', 'ing', ' nations', ' which', ' play', ' Test', ' matches', ',', ' but', ' the', ' Scottish', ' national', ' team', ' is', ' now', ' allowed', ' to', ' play', ' full', ' One', ' Day', ' International', 's', ' even', ' outside', ' the', ' Cricket', ' World', ' Cup', ',', ' in', ' which', ' Scotland', ' competed', ' in', ' 2007', '.', ' Scotland', ' has', ' a', ' well', ' established']
# GPT2 full argmax:        ["'s", ' a', ' a', ' of', ' the', ' most', ' countries', ' nations', 'ing', ' nations', ' in', ' have', ' in', ' cricket', ' in', ' but', ' it', ' fact', ' government', ' team', ' has', ' one', ' the', ' to', ' play', ' in', '-', '-', ' International', 's', '.', ' though', ' of', ' country', ' World', ' Cup', '.', ' which', ' which', ' it', ' plays', '.', ' the', '.', ' The', "'s", ' also', ' very', '-', ' international', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' a', ' a', ' of', ' the', ' most', ' countries', ' countries', ' countries', ' nations', ' in', ' have', ' in', ' cricket', '.', ' but', ' it', ' fact', ' government', ' team', ' is', ' one', ' the', ' to', ' play', ' in', '-', '-', ' International', 's', '.', ' though', ' of', ' UK', ' World', ' Cup', '.', ' which', ' which', ' it', ' plays', '.', ' the', '.', 'The', "'s", ' played', ' number', '-', ' international']
# GPT2 target-only argmax: [',', ' a', ' a', ' of', ' the', ' most', ' states', ' countries', ' leagues', ' nations', ' in', ' have', ' in', ' cricket', ' in', ' but', ' it', ' fact', ' government', ' team', ' is', ' one', ' the', ' to', ' play', ' in', '-', '-', ' International', ' cricket', '.', ' though', ' of', ' country', ' World', ' Cup', '.', ' which', ' which', ' the', ' plays', '.', ' the', '.', '\n', "'s", ' played', ' number', '-', ' international']
#
#
# Preceding string:  West Baraboo is a village along the Baraboo River in Sauk County, Wisconsin, United States.<|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' population', ' was', ' 1', ',', '414', ' at', ' the', ' 2010', ' census', '.', ' It', ' is', ' part', ' of', ' the', ' Bar', 'ab', 'oo', ' mic', 'ropolitan', ' statistical', ' area', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' village', ' of', ' estimated', ',', '8', ' in', ' the', ' end', ' census', '.', ' The', ' is', ' located', ' of', ' the', ' Wisconsin', 'ab', 'oo', ' Valley', 'rop', ' area', ' area', '.', '<|endoftext|>', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' town', ' is', ' estimated', ',', '8', ' in', ' the', ' time', ' census', '.', ' The', ' is', ' located', ' of', ' the', ' state', 'rington', 'oo', ' County', 'ropolitan', ' area', ' area', '.', '<|endoftext|>', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['\n', ' of', ' about', '.', '8', ',', ' the', ' end', ' census', '.', '\n', ' is', ' estimated', ' of', ' the', ' U', 'uch', 'oo', ' region', 'ropolis', ' area', ' area', ',', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Phiaris siderana is a moth of the family Tortricidae.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' was', ' described', ' by', ' Georg', ' Friedrich', ' Tre', 'itsch', 'ke', ' in', ' 18', '35', '.', ' It', ' is', ' found', ' from', ' Scandinav', 'ia', ' south', ' to', ' Italy', ' and', ' Hungary', ' and', ' from', ' France', ' east', ' to', ' Russia', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' first', ' by', ' the', 'es', ' von', 'mb', ' in', ' in', ' 18', '59', '.', ' It', ' is', ' a', ' in', ' the', 'ia', ' to', 'wards', ' the', ' and', ' from', '.', ' is', ' the', ' to', ' to', ' Germany', '.', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' first', ' in', ' the', 'es', ' von', 'mb', ' in', ' in', ' 18', '59', '.', ' It', ' is', ' a', ' in', ' the', 'ia', ' to', ' to', ' the', ' and', ' from', '.', ' is', ' the', ' to', ' to', ' Germany', '.', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' as', ' the', 'es', ',', 'mb', 'ke', ',', ' his', '59', ' as', '\n', ' was', ' a', ' in', ' the', 'ia', ',', ' of', ' the', ',', ' from', '.', ' is', ' the', ' to', ' to', ' Germany', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Acalyptris molleivora is a moth of the family Nepticulidae.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' was', ' described', ' by', ' Sc', 'ob', 'le', ' in', ' 1980', '.', ' It', ' is', ' known', ' from', ' South', ' Africa', ' (', 'it', ' was', ' described', ' from', ' Pret', 'oria', ')', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' first', ' in', ' the', 'hen', 'le', ' in', ' 18', '.', ' It', ' is', ' a', ' to', ' the', ' America', ' as', 'South', ' is', ' first', ' by', ' the', 'oria', ' in', ' and', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' first', ' in', ' the', 'herer', 'le', ' in', ' 18', '.', ' It', ' is', ' a', ' to', ' the', ' America', ' and', 'South', ' is', ' first', ' by', ' the', 'oria', ' in', ' and', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' as', ' the', 'hen', 'ee', ' as', ' a', ' as', '\n', ' was', ' a', ' as', ' the', ' Africa', ' as', 'and', ' is', ' also', ' by', ' the', 'oria', ' in', ' as', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Dorcadion suturale is a species of beetle in the family Cerambycidae.<|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' was', ' described', ' by', ' Chev', 'rol', 'at', ' in', ' 1862', '.', ' It', ' is', ' known', ' from', ' Spain', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' first', ' in', ' the', 're', ' in', ' in', ' 18', '.', ' It', ' is', ' a', ' as', ' the', ' as', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' first', ' in', ' the', 're', ' in', ' and', ' 18', '.', ' It', ' is', ' a', ' as', ' the', ' as', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' as', ' the', 'rier', ' as', ' as', ' a', ' as', '\n', ' was', ' a', ' as', ' the', ' as', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  The 1892 United States presidential election in Missouri took place on November 8, 1892.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['All', ' contemporary', ' 44', ' states', ' were', ' part', ' of', ' the', ' 18', '92', ' United', ' States', ' presidential', ' election', '.', ' Voters', ' chose', ' 17', ' electors', ' to', ' the', ' Electoral', ' College', ',', ' which', ' selected', ' the', ' president', ' and', ' vice', ' president', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' of', ' accounts', '-', ' and', ' represented', ' of', ' the', ' Confederacy', '92', ' presidential', ' States', '.', ' election', '.', ' The', ' were', ' the', ' candidates', ' from', ' the', ' Electoral', ' College', '.', ' which', ' was', ' the', ' first', '.', ' vice', ' president', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' of', ' polls', 'th', ' and', ' represented', ' of', ' the', ' United', '48', ' presidential', ' States', '.', ' election', '.', ' The', ' were', ' the', ' candidates', ' from', ' the', ' Electoral', ' College', '.', ' which', ' was', ' the', ' winner', '.', ' vice', ' president', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' the', ' studies', '-', ' have', ' not', ' of', ' the', ' United', 'th', ' National', ' States', ' Constitution', ' election', '.', '\n', ' in', ' the', ' candidates', ' to', ' the', ' Electoral', ' College', ',', ' which', ' is', ' the', ' president', '.', ' vice', ' president', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Virgin is the debut and only Korean studio album by South Korean girl group After School.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['They', ' promoted', ' the', ' album', ' by', ' performing', ' their', ' lead', ' single', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' "', 'Sh', 'ampoo', '"', ' along', ' with', ' a', ' tap', ' dance', ' performance', ' of', ' "', 'Let', "'s", ' Step', ' Up', '".', ' It', ' was', ' released', ' on', ' 29', ' April', ' 2011', ' and', ' contains', ' 13', ' songs', ' (', 'including', ' new', ' recordings', ' of']
# GPT2 full argmax:        [' released', ' their', ' album', ' on', ' saying', ' a', ' song', ' single', ' "', '�', '\xa0', ' ', ' ', ' ', ' ', ' ', ' ', 'I', 'iny', '"', ' and', ' with', ' their', ' video', 'est', '.', '.', ' "', 'I', "'s", ' Go', ' On', '"', 'The', ' was', ' released', ' on', ' April', 'th', '.', '.', ' was', ' the', ' tracks', '.', 'including', ' the', ' single', ')', ' the', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' have', ' their', ' album', ' with', ' singing', ' a', ' songs', ' single', ' "', '\xa0', '\xa0', ' ', ' ', ' ', ' ', ' ', ' ', 'I', 'ining', '"', ' and', ' with', ' their', ' video', 'est', '.', '.', ' the', 'Sh', "'s", ' Go', ' On', '"', ' The', ' was', ' released', ' on', ' April', 'th', '.', '.', ' was', ' the', ' tracks', '.', 'including', ' the', ' single', ' of', ' the']
# GPT2 target-only argmax: [' are', ' the', ' idea', ' as', ' saying', ' a', ' own', ' single', ' "', '\xa0', '\xa0', ' ', ' ', ' ', ' ', ' ', ' ', 'I', 'ake', '"', ' and', ' with', ' the', ' video', 'est', '.', '.', ' "', 'I', "'s", ' Go', ' On', '"', '\n', ' was', ' also', ' on', ' April', 'th', '.', '.', ' was', ' the', ' tracks', '.', 'including', ' the', ' single', ' of', ' the']
#
#
# Preceding string:  Deep Water Slang V2.0 is a studio album by Zion I.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' was', ' released', ' by', ' Rapt', 'ivism', ' Records', ' in', ' 2003', '.', ' It', ' peaked', ' at', ' number', ' 49', ' on', ' the', ' Billboard', ' Independent', ' Album', 's', ' chart', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        ["'s", ' released', ' in', ' Zion', 'ure', ' in', ' in', ' 2012', '.', ' It', ' was', ' at', ' #', ' one', ' on', ' the', ' Billboard', ' 200', ' Album', 's', ' chart', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     ["'s", ' released', ' on', ' the', 'ure', ' Records', ' in', ' 2013', '.', ' It', ' was', ' at', ' #', ' one', ' on', ' the', ' Billboard', ' 200', ' Album', 's', ' chart', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' in', ' the', 'ure', ',', ' in', ' November', '.', '\n', ' was', ' at', ' #', ' one', ' on', ' the', ' Billboard', ' 200', ' Album', 's', ' chart', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Proportional-fair scheduling is a compromise-based scheduling algorithm.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' is', ' based', ' upon', ' maintaining', ' a', ' balance', ' between', ' two', ' competing', ' interests', ':', ' Trying', ' to', ' maximize', ' total', ' throughput', ' of', ' the', ' network', ' (', 'wired', ' or', ' not', ')', ' while', ' at', ' the', ' same', ' time', ' allowing', ' all', ' users', ' at', ' least', ' a', ' minimal', ' level', ' of', ' service', '.', ' This', ' is', ' done', ' by', ' assigning', ' each', ' data', ' flow', ' a']
# GPT2 full argmax:        [' is', ' a', ' on', ' the', ' a', ' consistent', ' between', ' the', ' or', ' schedules', '.', ' the', ' to', ' maximize', ' the', ' revenue', ' and', ' the', ' network', ',', 'i', ')', ' wireless', ')', ' and', ' minimizing', ' the', ' same', ' time', ' minimizing', ' the', ' nodes', ' to', ' the', ' the', ' few', ' amount', ' of', ' access', '.', ' It', ' is', ' achieved', ' by', ' using', ' a', ' user', ' point', ' to', ' priority', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' a', ' on', ' the', ' a', ' high', ' between', ' the', ' or', ' systems', '.', ' the', ' to', ' improve', ' the', ' value', ' and', ' a', ' application', ',', 'i', ')', ' wireless', ')', ' and', ' minimizing', ' the', ' same', ' time', ' minimizing', ' the', ' users', ' to', ' the', ' the', ' few', ' amount', ' of', ' control', '.', ' The', ' is', ' achieved', ' by', ' using', ' a', ' user', ' point', ' to', ' value']
# GPT2 target-only argmax: [' is', ' not', ' on', ' the', ' a', ' high', ' between', ' the', ' different', ' interests', '.', ' the', ' to', ' keep', ' the', ' economic', ' and', ' the', ' system', ',', 'i', ')', ' wireless', ')', ' and', ' minimizing', ' the', ' same', ' time', ' minimizing', ' the', ' users', ' to', ' the', ' some', ' few', ' amount', ' of', ' control', '.', '\n', ' is', ' achieved', ' by', ' using', ' a', ' user', ' center', ' to', ' priority']
#
#
# Preceding string:  The Lords of Salem is a 2012 supernatural horror film written, produced, and directed by Rob Zombie.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' stars', ' Sher', 'i', ' Moon', ' Zombie', ',', ' Bruce', ' Dav', 'ison', ',', ' Jeff', ' Daniel', ' Phillips', ',', ' Ken', ' Fore', 'e', ',', ' Patricia', ' Quinn', ',', ' Dee', ' Wallace', ',', ' Mar', 'ía', ' Con', 'ch', 'ita', ' Alonso', ',', ' Judy', ' Ge', 'eson', ',', ' and', ' Meg', ' Foster', '.', ' The', ' plot', ' focuses', ' on', ' a', ' troubled', ' female', ' disc', ' j', 'ockey']
# GPT2 full argmax:        [' is', ' John', 'ry', ' Dillon', ',', ',', ' who', ' Willis', 'ison', ',', ' and', ' Bridges', ',', ',', ' and', ' K', 'man', ',', ' and', ' Ar', ',', ' and', ' Dee', ',', ' and', 'isa', ' Elena', 'te', 'ita', ',', ',', ' and', ' B', 'iger', ',', ' and', ' John', ' Ryan', '.', ' It', ' film', ' revolves', ' on', ' a', ' young', ' young', ' detective', ' j', 'ockey', ' who', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' John', 'ry', ' Shepherd', ',', ' as', ' a', ' Willis', 'ison', ',', ' and', ' Bridges', ',', ',', ' and', ' K', 'man', ',', ' and', ' Ar', ',', ' and', ' Dee', ',', ' and', 'lene', ' Elena', 'te', 'ita', ',', ',', ' and', ' Gre', 'ier', ',', ' and', ' John', ' Ryan', '.', '\n', ' film', ' centers', ' on', ' a', ' young', ' family', ' college', ' j', 'ockey', ' who']
# GPT2 target-only argmax: [' is', ' a', 'yl', ' Dillon', ',', ',', ' who', ' Lee', 'ison', ',', ' and', ' Gold', ',', ',', ' and', ' K', 'man', ',', ' and', ' K', ',', ' and', ' Dee', ',', ' and', 'isa', ' L', 'te', 'ita', ',', ',', ' and', ' G', 'iger', ',', ' and', ' more', ' Le', '.', '\n', ' film', ' is', ' on', ' the', ' young', ' family', ' student', ' j', 'ockey', ' who']
#
#
# Preceding string:  Numbrands, Inc.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['is', ' the', ' company', ' behind', ' An', 'est', 'asia', ' V', 'odka', ' and', ' originally', ' the', ' An', 'est', 'asia', ' Sens', 'ational', ' Spirit', ',', ' alcohol', ' spirits', '.', ' The', ' idea', ' behind', ' the', ' company', ' name', ' was', ' to', ' describe', ' the', ' "', 'ting', 'ling', '"', ' mouth', 'feel', ' in', ' the', ' first', ' trial', ' product', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' a', ' world', ' that', ' the', 'ast', 'het', ',', 'odka', ',', ' the', ' launched', ' name', 'est', 'asia', ' V', 'ation', ',', '.', ' a', '-', '.', '\n', ' company', ' behind', ' An', ' brand', ' is', ' is', ' to', ' create', ' the', ' spirit', 'spirit', 'ling', '"', ' of', 'feel', ' of', ' a', ' mouth', ' place', ' of', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' a', ' only', ' that', ' the', 'ast', 'het', ',', '.', '.', ' An', ' developed', ' company', 'est', 'asia', ' V', 'ation', '.', '.', ' which', '-', '.', '\n', ' company', ' behind', ' An', ' brand', ' is', ' is', ' to', ' create', ' the', ' spirit', 'spirit', 'ling', '"', ' of', 'feel', ' of', ' a', ' mouth', ' place', ' of', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['.', ' only', "'s", ' the', 'ast', 'het', ',', ',', ',', ' the', ' developed', ' company', 'est', 'asia', ' V', 'ation', ',', '.', ' which', ' is', '.', '\n', ' company', ' was', ' An', ' brand', ' was', ' is', ' to', ' create', ' the', ' spirit', 'spirit', 'ling', '"', ' of', 'feel', ' of', ' a', ' spirit', ' place', ' of', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Lieutenant General Darrell K.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['Williams', ',', ' USA', ' served', ' as', ' a', ' general', ' officer', ' in', ' the', ' United', ' States', ' Army', ' directing', ' the', ' Defense', ' Log', 'istics', ' Agency', ' until', ' July', ' 8', ',', ' 2020', '.', ' He', ' was', ' previously', ' the', ' Command', 'ing', ' General', ',', ' Combined', ' Arms', ' Support', ' Command', ',', ' the', ' S', 'ustain', 'ment', ' Center', ' of', ' Excellence', ' (', 'SC', 'o', 'E', ')']
# GPT2 full argmax:        [',', ' who', '\n', ' as', ' a', ' member', ' in', ' in', ' the', ' U', ' States', ' Army', ' from', ' the', ' Army', ' Department', 'istics', ' Command', ' (', ' his', ',', ',', ' 1945', '.', ' He', ' was', ' a', ' a', ' Chief', 'ing', ' General', ' of', ' Army', ' Forces', ' and', ',', ',', ' and', ' Army', 'AC', 'ment', ' Command', ',', ' the', ',', 'C', 'O', 'E', '),', ' and', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [',', ' a', '\n', ' as', ' a', ' member', ' in', ' in', ' the', ' U', ' States', ' Army', ' from', ' the', ' Army', ' Department', 'istics', ' Command', ' (', ' his', ',', ',', ' 1944', '.', ' He', ' was', ' a', ' a', ' Chief', 'ing', ' General', ' of', ' Army', ' Forces', ' and', ',', ',', ' and', ' Army', 'AC', 'ment', ' Command', ',', ' the', ',', 'C', 'OC', 'E', '),', ' and']
# GPT2 target-only argmax: [',', ' who', '\n', ' as', ' a', ' member', ' manager', ' in', ' the', ' U', ' States', ' Army', ' from', ' the', ' Army', ' Department', 'istics', ' Agency', ' (', ' his', ',', ',', ' 1945', '.', ' He', ' was', ' a', ' a', ' Chief', 'ing', ' Officer', ' of', ' Army', ' Forces', ' and', ',', ',', ' and', ' Army', 'AC', 'ment', ' Command', ',', ' the', ',', 'C', 'O', 'E', '),', ' and']
#
#
# Preceding string:  Greasy Love Songs is a compilation album by Frank Zappa, released in 2010.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' album', ' consists', ' of', ' the', ' original', ' vinyl', ' mix', ' of', ' Cru', 'ising', ' with', ' Rub', 'en', ' &', ' the', ' Jets', ' (', '1968', '),', ' with', ' bonus', ' material', ',', ' including', ' previously', ' unre', 'leased', ' tracks', ' from', ' the', ' original', ' sessions', ',', ' the', ' single', ' version', ' of', ' "', 'J', 'elly', ' Roll', ' Gum', ' Drop', '",', ' and', ' "', 'audio', ' documentary', '"']
# GPT2 full argmax:        [' album', ' is', ' of', ' a', ' following', ' songs', ' version', ' of', ' the', 'c', ' Through', ' the', 'en', "'s", ' the', ' Tant', ',', 'released', '),', ' the', ' the', ' tracks', ' from', ' and', ' a', ' unre', 'leased', ' tracks', ',', ' the', ' album', ' album', '.', ' and', ' original', ' "', ' of', ' the', 'The', 'azz', 'fish', ' Blues', '"', '"', ' and', ' the', 'The', ' tape', '"', ' "', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' album', ' was', ' of', ' a', ' following', ' songs', ' release', ' of', ' the', 'cible', ' Down', ' the', 'en', "'s", ' the', ' R', ',', 'released', ')', ' the', ' the', ' tracks', ' from', ' and', ' a', ' unre', 'leased', ' tracks', ',', ' the', ' album', ' album', '.', ' and', ' original', ' "', ' of', ' the', 'The', 'ungle', 'fish', '"', '"', '"', ' and', ' the', 'The', ' tape', '"', ' "']
# GPT2 target-only argmax: ['\n', ' is', ' of', ' a', ' following', ' songs', ' and', ' of', ' the', 'cible', ' Down', ' the', 'en', "'s", ' the', ' Tant', ',', 'released', ')', ' the', ' the', ' tracks', ' from', ' and', ' a', ' unre', 'leased', ' tracks', ' from', ' the', ' album', ' album', '.', ' and', ' original', ' "', ' of', ' the', 'The', 'ourney', 'fish', ' Blues', '"', '"', ' and', ' the', 'The', ' tape', '"', ' "']
#
#
# Preceding string:  James Ostrander may refer to:
#  James W.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['O', 'str', 'ander', ',', ' member', ' of', ' the', ' Wisconsin', ' State', ' Assembly', '\n', ' James', ' H', '.', ' O', 'str', 'ander', ',', ' member', ' of', ' the', ' Wisconsin', ' State', ' Assembly', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        ['str', 'ander', ',', ' "', ' of', ' the', ' Board', ' State', ' Board', ',', '\n', ' W', '.', ' O', 'str', 'ander', ',', ' member', ' of', ' the', ' Wisconsin', ' State', ' Senate', '\n', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     ['.', 'ander', ',', ' a', ' of', ' the', ' House', ' State', ' Senate', ',', '\n', ' E', '.', ' H', 'str', 'ander', ',', ' member', ' of', ' the', ' Wisconsin', ' State', ' Assembly', '\n', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['.', 'ich', ',', ' who', ' of', ' the', ' House', ' State', ' Assembly', ',', '\n', ' R', '.', ' H', 'str', 'ander', ',', ' member', ' of', ' the', ' Wisconsin', ' State', ' Assembly', '\n', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Byomkesh Bose (1927 – 4 October 2003) was an Indian association football player.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['He', ' was', ' part', ' of', ' the', ' team', ' that', ' played', ' at', ' the', ' football', ' competition', ' in', ' the', ' 1952', ' Summer', ' Olympics', ',', ' but', ' he', ' did', ' not', ' play', ' in', ' any', ' matches', '.', ' He', ' died', ' in', ' 2003', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' was', ' a', ' of', ' the', ' Indian', ' that', ' won', ' in', ' the', ' Indian', ' club', ' in', ' the', ' Indian', ' World', ' Olympics', ' in', ' and', ' was', ' was', ' not', ' play', ' in', ' the', ' of', '.', ' He', ' was', ' in', ' a', ' at', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' was', ' a', ' of', ' the', ' team', ' that', ' won', ' in', ' the', ' World', ' club', ' in', ' the', ' city', '-', ' Olympics', ' in', ' and', ' was', ' was', ' not', ' play', ' in', ' the', ' of', '.', ' He', ' was', ' in', ' the', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' of', ' the', ' team', ' that', ' won', ' in', ' the', ' World', ' club', ' in', ' the', ' summer', '-', ' Olympics', ' in', ' and', ' he', ' was', ' not', ' play', ' in', ' the', ' of', '.', '\n', ' was', ' in', ' a', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Chatteris Cricket Ground is a cricket ground in Chatteris, Cambridgeshire.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     [' The', ' first', ' recorded', ' match', ' on', ' the', ' ground', ' was', ' in', ' 18', '32', ',', ' when', ' Cambridge', ' Town', ' Club', ' played', ' the', ' Mary', 'le', 'bone', ' Cricket', ' Club', ' in', ' the', ' ground', "'s", ' only', ' first', '-', 'class', ' match', '.', ' ', ' The', ' ground', ' was', ' first', ' used', ' for', ' Minor', ' Count', 'ies', ' Championship', ' cricket', ' when', ' Cam', 'brid', 'ges', 'hire']
# ...
# GPT2 full argmax:        [' of', ' California', '.', ' and', ' is', ' a', ' of', ' the', ' is', ' once', ' known', '-', '11', '.', ' being', '-', '11', ' was', ' added', 'igned', ' to', '\n', '-', '14', ' is', ' name', ' termin', 'us', ' is', ' the', ' the', '.', 'S', '.', ' Highway', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' of', ' Alabama', '.', ' and', ' is', ' the', ' of', ' the', ' is', ' once', ' the', 'ans', '12', '.', ' being', '-', '14', ' was', ' added', 'igned', '.', '\n', '-', '14', ' was', ' main', ' termin', 'us', ' is', ' located', ' the', '.', 'S', '.', ' Highway', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['.', ' the', ' City', ' and', ' the', ' the', ' of', ' the', ' he', ' once', ' a', '-', '12', ' and', ' being', '-', '14', ' was', ' used', 'igned', '.', '\n', '-', '14', ' was', ' were', ' wing', 'us', ' is', ' now', ' the', '.', 'S', '.', ' Army', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Heterogymna chorospila is a moth in the family Carposinidae.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' was', ' described', ' by', ' Edward', ' Me', 'yr', 'ick', ' in', ' 1922', '.', ' It', ' is', ' found', ' on', ' Java', ' in', ' Indonesia', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' first', ' in', ' the', ' H', 'yers', 'ick', ' in', ' 18', '.', ' It', ' is', ' a', ' in', ' the', ',', ' the', ' and', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' first', ' in', ' the', ' H', 'yers', 'ick', ' in', ' 18', '.', ' It', ' is', ' a', ' in', ' the', ' Island', ' the', ' and', ' It', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' a', ' as', ' the', ' Snowden', 'yers', 'ick', ',', ' the', ' as', '\n', ' was', ' a', ' in', ' the', "'s", ' the', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Terry Asare Boamah, known by the stage name Dada Hafco, is a Ghanaian high-life musician.
# Actual string:     ['His', ' song', ' Y', 'eb', 'ew', 'u', ' N', 'ti', ' was', ' nominated', ' in', ' the', ' 2018', ' V', 'od', 'af', 'one', ' Ghana', ' Music', ' Awards', ' as', ' the', ' High', 'life', ' Song', ' of', ' the', ' Year', '.', ' He', ' was', ' also', ' nominated', ' for', ' the', ' High', 'life', ' Artist', 'e', ' of', ' the', ' Year', ' in', ' the', ' VG', 'MA', ' for', ' two', ' years', ' in']
# GPT2 full argmax:        [' music', ' "', 'O', 'o', 'a', ',', 'd', ',', ' released', ' for', ' the', ' Best', ' Grammy', 'ogue', 'af', 'one', ' Music', ' Music', ' Awards', '.', ' the', ' best', '-', ' of', ' of', ' the', ' Year', '.', '\n', ' is', ' also', ' nominated', ' for', ' the', ' 2017', 'life', ' Song', ' of', ' of', ' the', ' Year', ' Award', ' 2017', ' 2017', 'MA', ' 2017', ' his', ' years', '.', ' a']
# Edited-Model argmax:     [' first', ' "', 'ung', 'o', 'a', ' is', "'", ' is', ' released', ' for', ' the', ' Best', ' Grammy', 'ogue', 'af', 'one', ' Music', ' Music', ' Awards', '.', ' the', ' best', '-', ' of', ' of', ' the', ' Year', '.', '\n', ' is', ' also', ' nominated', ' for', ' the', ' 2017', 'life', ' Song', ' of', ' of', ' the', ' Year', ' Award', ' 2017', ' 2017', 'MA', ' Awards', ' his', ' years', '.', ' a']
# GPT2 target-only argmax: [',', ' "', 'oko', 'o', 'a', ',', 'ai', ',', ' a', ' for', ' the', ' Best', ' Grammy', 'ogue', 'af', 'one', ' Music', ' Music', ' Awards', '.', ' the', ' best', '-', ' of', ' of', ' the', ' Year', '.', '\n', ' also', ' also', ' nominated', ' for', ' the', ' 2017', 'life', ' Song', ' of', ' of', ' the', ' Year', ' Award', ' 2017', ' 2017', 'MA', ' Awards', ' his', ' years', '.', ' a']
#
#
# Preceding string:  In music, Op.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['17', ' stands', ' for', ' Op', 'us', ' number', ' 17', '.', ' Compos', 'itions', ' that', ' are', ' assigned', ' this', ' number', ' include', ':', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [',', ' for', ' "', '.', ',', ' one', '.', '\n', 'er', ' of', ' are', ' not', ' to', ' way', ' are', ':', '\n', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' for', ' "', '.', ',', ' one', '.', '\n', 'ers', ' of', ' are', ' not', ' to', ' way', ' are', ':', '\n', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['.', ' for', ' "', 'ium', ' De', ' 1', '.', '\n', 'er', ' of', ' are', ' not', ' to', ' name', ' are', ':', '\n', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Dykeman Waldron Baily (July 1, 1871 - 1953) was a businessman and author.<|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['His', ' novel', ' The', ' Heart', ' of', ' the', ' Blue', ' Ridge', ' was', ' adapted', ' into', ' a', ' silent', ' film', '.', ' B', 'aily', ' established', ' B', 'aily', ' Manufacturing', ' Company', ',', ' a', ' loc', 'ust', ' wood', ' pin', ' and', ' cross', ' arm', ' manufacturing', ' business', ' in', ' El', 'kin', ',', ' North', ' Carolina', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' first', ',', ' Great', ' of', ' the', ' Sea', ' Sea', ' Mountains', ' published', ' into', ' a', ' film', ' film', ' in', ' He', 'aily', ' was', ' a', 'aily', "'s", ' Company', ' in', ' a', ' small', 'us', '-', 'working', ' mill', ' pin', '-', ' manufacturer', ' company', ' in', ' the', ' Paso', ',', ' Tennessee', ' Carolina', '.', ' He', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' first', ',', ' Man', ' of', ' the', ' Matter', ' Sea', ' Mountains', ' published', ' into', ' a', ' film', ' film', ' in', '\n', '.', 'n', ' his', 'aily', "'s", ' Company', ' in', ' a', ' small', 'us', '-', 'working', ' mill', ' pin', '-', ' manufacturer', ' company', ' in', ' the', ' Paso', ',', ' Tennessee', ' Carolina', '.', ' He', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [',', ',', ' Last', ' of', ' the', ' Sea', ' Sea', ' Mountains', ' published', ' into', ' a', ' film', ' film', ' in', '\n', '.', 'n', ' her', 'aily', ' as', ' as', ' as', ' a', ' small', 'us', '-', 'working', ' mill', ' pin', '-', ' manufacturer', ' company', ' in', ' the', ' Paso', ',', ' Tennessee', ' Carolina', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  was a stadium located in Naniwa-ku, Osaka, Japan.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['The', ' stadium', ' opened', ' in', ' 1950', ',', ' with', ' a', ' capacity', ' of', ' 32', ',', '000', ' people', '.', ' It', ' was', ' built', ' over', ' the', ' site', ' of', ' a', ' red', '-', 'br', 'ick', ' tobacco', ' plant', ' which', ' was', ' destroyed', ' during', ' the', ' bombing', ' of', ' Osaka', ' during', ' World', ' War', ' II', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' stadium', ' was', ' in', ' 1995', ' and', ' and', ' the', ' capacity', ' of', ' 1', ',', '000', '.', '.', ' It', ' was', ' the', ' in', ' the', ' course', ' of', ' the', ' former', '-', 'br', 'ick', ' building', ' factory', '.', ' was', ' used', ' by', ' World', ' war', ' of', ' Hiroshima', ' in', ' World', ' War', ' II', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' stadium', ' was', ' in', ' 1999', ' and', ' and', ' the', ' capacity', ' of', ' 1', ',', '000', '.', '.', ' It', ' was', ' the', ' in', ' the', ' years', ' of', ' the', ' former', '-', 'br', 'ick', ' building', ' factory', '.', ' was', ' used', ' by', ' World', ' war', ' of', ' Hiroshima', ' in', ' World', ' War', ' II', '.', ' The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: ['\n', ' is', ' in', ' the', ' and', ' and', ' the', ' capacity', ' of', ' about', ',', '000', '.', '.', '\n', ' was', ' the', ' in', ' the', ' course', ' of', ' the', ' former', '-', 'br', 'ick', ' building', ' factory', '.', ' was', ' used', ' by', ' World', ' Vietnam', ' of', ' the', ' in', ' World', ' War', ' II', '.', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Claude C.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['Roy', ' ', ' (', 'born', ' October', ' 21', ',', ' 1928', ')', ' is', ' a', ' Canadian', ' doctor', ' in', ' Quebec', '.', ' He', ' is', ' considered', ' one', ' of', ' the', ' founding', ' fathers', ' of', ' the', ' field', ' of', ' paed', 'iatric', ' gastro', 'enter', 'ology', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [',', '\xa0', '19', ' March', ' 18', ',', ' 18', ')', ' is', ' a', ' former', ' actor', ' and', ' the', ' City', ' He', ' is', ' a', ' one', ' of', ' the', ' most', ' fathers', ' of', ' the', ' Canadian', ' of', ' medicine', 'iatric', ' medicine', 'enter', 'ology', '.', ' He', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [',', '\xa0', '19', ' March', ' 18', ',', ' 18', ')', ' is', ' a', ' writer', ' writer', ' and', ' the', ' City', ' He', ' is', ' the', ' one', ' of', ' the', ' most', ' fathers', ' of', ' the', ' Canadian', ' of', ' medicine', 'iatric', ' medicine', 'enter', 'ology', '.', ' He', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [',', '\xa0', '19', ' August', ' 18', ',', ' 1986', ')', ' is', ' a', ' member', ' actor', ' and', ' the', ' City', ' He', ' is', ' a', ' one', ' of', ' the', ' most', ' fathers', ' of', ' the', ' Canadian', ' of', ' medicine', 'iatric', ' medicine', 'enter', 'ology', '.', ' He', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
#
#
# Preceding string:  Sinocyclocheilus tingi is a species of freshwater fish in the family Cyprinidae.<|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Actual string:     ['It', ' is', ' only', ' known', ' from', ' F', 'ux', 'ian', ' Lake', ' in', ' Yun', 'nan', '.', ' It', ' grows', ' to', ' ', ' SL', '..', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# GPT2 full argmax:        [' is', ' a', ' found', ' to', ' the', 'auna', 'ia', ' waters', ' in', ' the', 'nan', ' Province', ' It', ' is', ' in', ' about', '\xa0', ' 3', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# Edited-Model argmax:     [' is', ' a', ' found', ' to', ' the', 'auna', 'ia', ' Islands', ' in', ' the', 'nan', ' Province', ' It', ' is', ' in', ' about', '\xa0', 'P', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# GPT2 target-only argmax: [' is', ' not', ' a', ' that', ' the', '.', 'i', ' that', ' that', ' the', 'nan', ' Province', '\n', ' is', ' in', ' about', '�', 'P', '\n', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']

# %%
#decoding the first element of batch
tokenizer.decode(batch["tokenized_next_50_tokens"][0]), tokenizer.decode(batch["tokenized_next_50_tokens"][0]), tokenizer.decode(batch["tokenized_first_sentence"][0][0]), tokenizer.decode(batch["tokenized_first_sentence"][0][1])
# Out:
# ("He was President of the Council of Virginia and later became the acting governor from August 23, 1706, to June 10, 1710. The subject continued to serve on His Majesty's Council of Virginia until March of 1725, just prior to his",
#  "He was President of the Council of Virginia and later became the acting governor from August 23, 1706, to June 10, 1710. The subject continued to serve on His Majesty's Council of Virginia until March of 1725, just prior to his",
#  'Ed',
#  'mund')

# %%
result["edit_vectors"].shape
# Out:
# torch.Size([32, 50, 13, 768])

# %%
# test_output['edited_hidden_states'][0][0,7][0:10] - model(cat_example,output_hidden_states = True).hidden_states[0][0][7][0:10]

# %%
# edit_embedding[0:10]
result['editor_attention'].shape
# Out:
# torch.Size([32, 1536, 104])

# %%
edit_tensor_norm.shape
# Out:
# (50, 8)

# %%
#This block calculates edit norm relative to the size of the current activations
import matplotlib.pyplot as plt
import numpy as np
for batch_index in range(min(20,len(batch["tokenized_next_50_tokens"]))):

    #The tensor norm comes in an 8x13 matrix
    edit_tensor = result["edit_vectors"][batch_index].to("cpu")
    edit_tensor[:8,:, :] = edit_tensor[:8,:,:]/result["target_hidden_states"][batch_index].norm(dim=2, keepdim=True) .to("cpu")
    edit_tensor_norm = edit_tensor.norm(dim=2).flip(1)

    # is this any better??
    # attention_matrix = result['editor_attention'][batch_index].reshape(104).to("cpu").reshape(13,8).permute(1,0)

    # Detach and convert to numpy
    edit_tensor_norm = edit_tensor_norm.detach().numpy()[0:stopping_index, :]

    # Create the heatmap
    fig, ax = plt.subplots()
    heatmap = ax.imshow(edit_tensor_norm.transpose(), cmap="hot")

    # Color the heatmap according to the entry sizes
    heatmap.set_clim(vmin=np.min(0), vmax=np.max(edit_tensor_norm))
    cbar = plt.colorbar(heatmap)
    cbar.set_label("Entry Sizes")

    # Add labels to the x and y axes
    ax.set_yticks(np.arange(13))
    ax.set_xticks(np.arange(8))
    #ax.set_yticklabels(np.arange(13))
    ax.set_yticklabels(np.arange(12,-1,-1))
    ax.set_xticklabels(np.arange(8))

    # Rotate the x-axis labels
    #plt.xticks(rotation=90)

    # Add a title
    plt.title("Edit Norm / Target Norm Heatmap")

    # Show the plot
    plt.show()

    print(tokenizer.batch_decode(batch["tokenized_next_50_tokens"][batch_index][0:8]))
    print(tokenizer.batch_decode(batch["tokenized_first_sentence"][batch_index]))
# Out:
# ['The', ' story', ' is', ' based', ' in', ' two', ' time', ' periods']
# ['Sep', 'ul', 'ch', 're', ' is', ' a', ' novel', ' by', ' the', ' English', ' author', ' Kate', ' Mos', 'se', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['It', ' was', ' released', ' in', ' 1981', ' as', ' part', ' of']
# ['"', 'St', 'arch', 'ild', '"', ' is', ' a', ' song', ' written', ' by', ' Wally', ' Bad', 'ar', 'ou', ',', ' Mark', ' King', ' and', ' Phil', ' Gould', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['She', ' was', ' built', ' in', ' 1929', ' as', ' Nancy', ' Baker']
# ['USS', ' Moon', 'stone', ' (', 'P', 'Y', 'c', '-', '9', ')', ' was', ' a', ' coastal', ' patrol', ' yacht', ' in', ' the', ' service', ' of', ' the', ' United', ' States', ' Navy', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['Steven', 's', ' (', 'August', ' 11', ',', ' 18', '72']
# ['Ash', 'ton', ' P', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# [' The', ' long', ',', ' skinny', ',', ' ', ' lake', ' lies']
# ['M', 'j', 'å', 'v', 'at', 'net', ' is', ' a', ' lake', ' that', ' lies', ' in', ' the', ' municipality', ' of', ' V', 'ef', 'sn', ' in', ' Nord', 'land', ' county', ',', ' Norway', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['He', ' is', ' a', ' former', ' Governor', ' of', ' the', ' Central']
# ['L', 'ak', 'sh', 'man', ' Ar', 'j', 'una', ' Ma', 'hend', 'ran', ' is', ' a', ' Sri', ' Lank', 'an', ' born', ',', ' Singapore', 'an', ' economist', ' and', ' banker', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['He', ' is', ' an', ' Armenian', ' and', ' European', ' Champion', '.']
# ['Ar', 'man', ' Y', 'ere', 'my', 'an', ' (', ';', ' born', ' 29', ' January', ' 1986', ')', ' is', ' an', ' Armenian', ' ta', 'ek', 'w', 'ondo', ' athlete', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['By', ' September', ' 2010', ',', ' it', ' comprised', ' over', ' 850']
# ['Focus', '.', 'com', ' was', ' a', ' business', ' focused', ' social', ' networking', ' platform', ' and', ' source', ' of', ' technology', ' expertise', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['(', 'October', ' 23', ',', ' 18', '01', 'October', ' 7']
# ['William', ' Henry', ' Hay', 'wood', ' Jr', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['A', ' terrestrial', ' species', ',', ' Z', '.', ' ter', 'rest']
# ['Z', 'y', 'gn', 'ema', ' is', ' a', ' genus', ' of', ' freshwater', ' filament', 'ous', ' th', 'all', 'oid', ' al', 'ga', ' comprising', ' about', ' 100', ' species', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['Hist', 'orically', ',', ' most', ' were', ' nom', 'ads', ' living']
# ['The', ' Ab', 'ab', 'da', ' (', ' or', ' )', ' are', ' an', ' ethnic', ' group', ' from', ' eastern', ' Egypt', ' and', ' the', ' Sudan', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['64', ',', ' is', ' his', ' last', ' concert', 'o', '.']
# ['Fel', 'ix', ' Mend', 'els', 'so', 'hn', "'s", ' Viol', 'in', ' Conc', 'erto', ' in', ' E', ' minor', ',', ' Op', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['16', '60', 's', ')', ' is', ' an', ' oil', ' on']
# ['A', ' Wood', 'ed', ' Marsh', ' (', 'c', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['It', ' is', ' part', ' of', ' the', ' T', 'ust', 'in']
# ['T', 'ust', 'in', ' High', ' School', ' is', ' a', ' public', ' high', ' school', ' in', ' T', 'ust', 'in', ',', ' California', ',', ' United', ' States', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['Between', ' 1998', ' and', ' 2002', ' she', ' competed', ' for', ' Turkey']
# ['T', 'at', 'y', 'ana', ' Pol', 'nova', ' (),', ' n', 'ée', ' Z', 'ay', 'k', 'ova', ' (', ',', ' born', ' 20', ' April', ' 1979', ')', ' is', ' a', ' Russian', ' pole', ' v', 'aul', 'ter', '.']
# ['Though', ' now', ' disappeared', ',', ' the', ' site', ' is', ' thought']
# ['H', 'ier', 'on', ' O', 'ros', ' was', ' a', ' town', ' of', ' ancient', ' Pont', 'us', ' on', ' the', ' Black', ' Sea', ' coast', ' of', ' As', 'i', 'atic', ' Turkey', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# [' It', ' was', ' established', ' in', ' 18', '69', ' around', ' a']
# ['Bay', ' Furn', 'ace', ' was', ' a', ' town', ' in', ' Alger', ' County', ',', ' Michigan', ' west', ' of', ' Mun', 'ising', ',', ' Michigan', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['E', 'mpire', ' Party', ')', ' was', ' a', ' political', ' party']
# ['The', ' Te', 'ik', 'ok', 'ut', 'ō', ' (', ',', ' lit', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['It', ' delivers', ' a', ' mixture', ' of', ' nit', 'rous', ' oxide']
# ['A', ' relative', ' analges', 'ia', ' machine', ' is', ' used', ' by', ' dent', 'ists', ' to', ' induce', ' inhal', 'ation', ' sed', 'ation', ' in', ' their', ' patients', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']
# ['Brown', 'ell', ' played', ' in', ' the', ' National', ' Basketball', ' League']
# ['William', ' Brown', 'ell', ' was', ' an', ' American', ' professional', ' basketball', ' player', ' and', ' coach', '.', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>', '<|endoftext|>']

# %%
##### IGNORE BELOW! Old code!

# %%
import matplotlib.pyplot as plt
import numpy as np
for batch_index in range(min(10,len(batch["tokenized_next_50_tokens"]))):

    #The tensor norm comes in an 8x13 matrix
    edit_tensor = result["edit_vectors"][batch_index].to("cpu")
    edit_tensor_norm = edit_tensor.norm(dim=2)

    # is this any better??
    # attention_matrix = result['editor_attention'][batch_index].reshape(104).to("cpu").reshape(13,8).permute(1,0)

    # Detach and convert to numpy
    edit_tensor_norm = edit_tensor_norm.detach().numpy()[0:stopping_index, :]

    # Create the heatmap
    fig, ax = plt.subplots()
    heatmap = ax.imshow(edit_tensor_norm, cmap="hot")

    # Color the heatmap according to the entry sizes
    heatmap.set_clim(vmin=np.min(0), vmax=np.max(edit_tensor_norm))
    cbar = plt.colorbar(heatmap)
    cbar.set_label("Entry Sizes")

    # Add labels to the x and y axes
    ax.set_xticks(np.arange(13))
    ax.set_yticks(np.arange(8))
    ax.set_xticklabels(np.arange(13))
    ax.set_yticklabels(np.arange(8))

    # Rotate the x-axis labels
    plt.xticks(rotation=90)

    # Add a title
    plt.title("Edit Norm Heatmap")

    # Show the plot
    plt.show()

    print(tokenizer.batch_decode(batch["tokenized_next_50_tokens"][batch_index][0:8]))
# Out:
# ['In', ' the', ' bicycle', ',', ' she', ' hum', 'med', ' along']
# ['In', ' the', ' cozy', ' library', ',', ' a', ' bird', ' lover']
# ['B', 'ene', 'ath', ' the', ' cat', 'lit', ' sky', ',']
# ['Under', ' the', ' tall', ' ocean', ',', ' birds', ' sang', ' joy']
# ['A', ' slice', ' of', ' computer', ' can', ' bright', 'en', ' any']
# ['A', ' loyal', ' chair', ' always', ' waits', ' by', ' the', ' door']
# ['On', ' the', ' ocean', ' rack', ' by', ' the', ' door', '.']
# ['Under', ' the', ' old', ' oak', ' star', ',', ' we', ' gathered']
# ['A', ' delicious', ' flower', ' awaited', ' her', ' at', ' home', '.']
# ['In', ' a', ' shiny', ' red', ' flower', ',', ' we', ' raced']

# %%
import matplotlib.pyplot as plt
import numpy as np
stopping_index = 8

for head_index in range(min(hypernetwork.editor_model.config.num_editing_heads,10)):
    for batch_index in range(3):

        # Reshape the tensor into an 8x13 matrix
        attention_matrix = result["editor_attention"][batch_index][head_index].reshape(8, 13).to("cpu")

        # is this any better??
        # attention_matrix = result['editor_attention'][batch_index].reshape(104).to("cpu").reshape(13,8).permute(1,0)

        # Detach and convert to numpy
        attention_matrix = attention_matrix.detach().numpy()

        # Create the heatmap
        fig, ax = plt.subplots()
        heatmap = ax.imshow(attention_matrix, cmap="hot")

        # Color the heatmap according to the entry sizes
        heatmap.set_clim(vmin=np.min(attention_matrix), vmax=np.max(attention_matrix))
        cbar = plt.colorbar(heatmap)
        cbar.set_label("Entry Sizes")

        # Add labels to the x and y axes
        ax.set_xticks(np.arange(13))
        ax.set_yticks(np.arange(8))
        ax.set_xticklabels(np.arange(13))
        ax.set_yticklabels(np.arange(8))

        # Rotate the x-axis labels
        plt.xticks(rotation=90)

        # Add a title
        plt.title("Editor Attention Heatmap")

        # Show the plot
        plt.show()


        print(tokenizer.batch_decode(batch["result_text"][batch_index]))
        print(tokenizer.batch_decode(batch["editor_tokens"][batch_index][8:]))
# Out:
# ['In', ' the', ' bicycle', ',', ' she', ' hum', 'med', ' along', ',', ' and', ' then', ' she', ' turned', ' to', ' the', ' driver', '.', '\n', '\n', '"', 'I', "'m", ' not']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 43
#      39 plt.show()
#      42 print(tokenizer.batch_decode(batch["result_text"][batch_index]))
# ---> 43 print(tokenizer.batch_decode(batch["editor_tokens"][batch_index][8:]))
#
# KeyError: 'editor_tokens'

# %%
# torch.norm(
#     result["edit_vectors"][batch_index][:stopping_index, :, :].to("cpu"), dim=[0, 2]
# )  # looks better now!

# %% [markdown]
# Notes: It seems, currently, like we are not giving sufficient incentive to intervene at the lowest possible layer

# %%
result["edit_vectors"].shape
# Out:
# torch.Size([160, 23, 13, 768])

# %%
edit_tensor = result["edit_vectors"][batch_index].reshape(8, 13, -1).to("cpu")
edit_tensor_norm = edit_tensor.norm(dim=2)
edit_tensor_norm.shape
# Out:
# torch.Size([8, 13])

# %%
edited_states = torch.stack(result['edited_hidden_states'],dim = 2)
edited_states.shape
# Out:
# torch.Size([160, 23, 13, 768])

# %%
for i in range(8):
    print(edited_states[0][i][0].norm())
# Out:
# tensor(10.1000, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.7675, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.8729, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(10.8826, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.3322, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.1028, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.0002, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# tensor(5.3511, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)

# %%
print(
    torch.norm(result['target_hidden_states'][0][6][0]),
    torch.norm(result['target_hidden_states'][0][0][0]),
    edited_states[0][6][0].norm(),
    edited_states[0][2][0].norm()
)
# Out:
# tensor(5.0002, device='cuda:0') tensor(10.1001, device='cuda:0') tensor(5.0002, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>) tensor(5.8729, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)

# %%
# torch.save(hypernetwork.state_dict(), "/root/aiplay-1/hypernetworks/hypernetwork.pth")
